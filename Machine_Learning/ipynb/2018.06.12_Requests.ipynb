# %% [markdown]
# ### 《Python机器学习时间指南》[美]Alexander T. Combs著.黄申.翻译.人民邮电出版社.201705
# * [Alexander T. Combs's GitHub](https://github.com/acombs)

# %% [markdown]
# > Python Requests库的交互实例，P4

# %%
import requests

# %%
r = requests.get(r'https://api.github.com/users/bitbyte27/starred')

# %%
r.json()
# Out:
# [{u'archive_url': u'https://api.github.com/repos/bbfamily/abu/{archive_format}{/ref}',
#   u'archived': False,
#   u'assignees_url': u'https://api.github.com/repos/bbfamily/abu/assignees{/user}',
#   u'blobs_url': u'https://api.github.com/repos/bbfamily/abu/git/blobs{/sha}',
#   u'branches_url': u'https://api.github.com/repos/bbfamily/abu/branches{/branch}',
#   u'clone_url': u'https://github.com/bbfamily/abu.git',
#   u'collaborators_url': u'https://api.github.com/repos/bbfamily/abu/collaborators{/collaborator}',
#   u'comments_url': u'https://api.github.com/repos/bbfamily/abu/comments{/number}',
#   u'commits_url': u'https://api.github.com/repos/bbfamily/abu/commits{/sha}',
#   u'compare_url': u'https://api.github.com/repos/bbfamily/abu/compare/{base}...{head}',
#   u'contents_url': u'https://api.github.com/repos/bbfamily/abu/contents/{+path}',
#   u'contributors_url': u'https://api.github.com/repos/bbfamily/abu/contributors',
#   u'created_at': u'2016-09-19T15:31:53Z',
#   u'default_branch': u'master',
#   u'deployments_url': u'https://api.github.com/repos/bbfamily/abu/deployments',
#   u'description': u'\u963f\u5e03\u91cf\u5316\u4ea4\u6613\u7cfb\u7edf(\u80a1\u7968\uff0c\u671f\u6743\uff0c\u671f\u8d27\uff0c\u6bd4\u7279\u5e01\uff0c\u673a\u5668\u5b66\u4e60) \u57fa\u4e8epython\u7684\u5f00\u6e90\u91cf\u5316\u4ea4\u6613\uff0c\u91cf\u5316\u6295\u8d44\u67b6\u6784',
#   u'downloads_url': u'https://api.github.com/repos/bbfamily/abu/downloads',
#   u'events_url': u'https://api.github.com/repos/bbfamily/abu/events',
#   u'fork': False,
#   u'forks': 845,
#   u'forks_count': 845,
#   u'forks_url': u'https://api.github.com/repos/bbfamily/abu/forks',
#   u'full_name': u'bbfamily/abu',
#   u'git_commits_url': u'https://api.github.com/repos/bbfamily/abu/git/commits{/sha}',
#   u'git_refs_url': u'https://api.github.com/repos/bbfamily/abu/git/refs{/sha}',
#   u'git_tags_url': u'https://api.github.com/repos/bbfamily/abu/git/tags{/sha}',
#   u'git_url': u'git://github.com/bbfamily/abu.git',
#   u'has_downloads': True,
#   u'has_issues': True,
#   u'has_pages': False,
#   u'has_projects': True,
#   u'has_wiki': True,
#   u'homepage': u'http://www.abuquant.com/',
#   u'hooks_url': u'https://api.github.com/repos/bbfamily/abu/hooks',
#   u'html_url': u'https://github.com/bbfamily/abu',
#   u'id': 68619379,
#   u'issue_comment_url': u'https://api.github.com/repos/bbfamily/abu/issues/comments{/number}',
#   u'issue_events_url': u'https://api.github.com/repos/bbfamily/abu/issues/events{/number}',
#   u'issues_url': u'https://api.github.com/repos/bbfamily/abu/issues{/number}',
#   u'keys_url': u'https://api.github.com/repos/bbfamily/abu/keys{/key_id}',
#   u'labels_url': u'https://api.github.com/repos/bbfamily/abu/labels{/name}',
#   u'language': u'Python',
#   u'languages_url': u'https://api.github.com/repos/bbfamily/abu/languages',
#   u'license': {u'key': u'gpl-3.0',
#    u'name': u'GNU General Public License v3.0',
#    u'node_id': u'MDc6TGljZW5zZTk=',
#    u'spdx_id': u'GPL-3.0',
#    u'url': u'https://api.github.com/licenses/gpl-3.0'},
#   u'merges_url': u'https://api.github.com/repos/bbfamily/abu/merges',
#   u'milestones_url': u'https://api.github.com/repos/bbfamily/abu/milestones{/number}',
#   u'mirror_url': None,
#   u'name': u'abu',
#   u'node_id': u'MDEwOlJlcG9zaXRvcnk2ODYxOTM3OQ==',
#   u'notifications_url': u'https://api.github.com/repos/bbfamily/abu/notifications{?since,all,participating}',
#   u'open_issues': 0,
#   u'open_issues_count': 0,
#   u'owner': {u'avatar_url': u'https://avatars2.githubusercontent.com/u/6149331?v=4',
#    u'events_url': u'https://api.github.com/users/bbfamily/events{/privacy}',
#    u'followers_url': u'https://api.github.com/users/bbfamily/followers',
#    u'following_url': u'https://api.github.com/users/bbfamily/following{/other_user}',
#    u'gists_url': u'https://api.github.com/users/bbfamily/gists{/gist_id}',
#    u'gravatar_id': u'',
#    u'html_url': u'https://github.com/bbfamily',
#    u'id': 6149331,
#    u'login': u'bbfamily',
#    u'node_id': u'MDQ6VXNlcjYxNDkzMzE=',
#    u'organizations_url': u'https://api.github.com/users/bbfamily/orgs',
#    u'received_events_url': u'https://api.github.com/users/bbfamily/received_events',
#    u'repos_url': u'https://api.github.com/users/bbfamily/repos',
#    u'site_admin': False,
#    u'starred_url': u'https://api.github.com/users/bbfamily/starred{/owner}{/repo}',
#    u'subscriptions_url': u'https://api.github.com/users/bbfamily/subscriptions',
#    u'type': u'User',
#    u'url': u'https://api.github.com/users/bbfamily'},
#   u'private': False,
#   u'pulls_url': u'https://api.github.com/repos/bbfamily/abu/pulls{/number}',
#   u'pushed_at': u'2018-03-30T16:01:13Z',
#   u'releases_url': u'https://api.github.com/repos/bbfamily/abu/releases{/id}',
#   u'size': 92741,
#   u'ssh_url': u'git@github.com:bbfamily/abu.git',
#   u'stargazers_count': 2165,
#   u'stargazers_url': u'https://api.github.com/repos/bbfamily/abu/stargazers',
#   u'statuses_url': u'https://api.github.com/repos/bbfamily/abu/statuses/{sha}',
#   u'subscribers_url': u'https://api.github.com/repos/bbfamily/abu/subscribers',
#   u'subscription_url': u'https://api.github.com/repos/bbfamily/abu/subscription',
#   u'svn_url': u'https://github.com/bbfamily/abu',
#   u'tags_url': u'https://api.github.com/repos/bbfamily/abu/tags',
#   u'teams_url': u'https://api.github.com/repos/bbfamily/abu/teams',
#   u'trees_url': u'https://api.github.com/repos/bbfamily/abu/git/trees{/sha}',
#   u'updated_at': u'2018-06-12T06:42:12Z',
#   u'url': u'https://api.github.com/repos/bbfamily/abu',
#   u'watchers': 2165,
#   u'watchers_count': 2165},
#  {u'archive_url': u'https://api.github.com/repos/carefree0910/MachineLearning/{archive_format}{/ref}',
#   u'archived': False,
#   u'assignees_url': u'https://api.github.com/repos/carefree0910/MachineLearning/assignees{/user}',
#   u'blobs_url': u'https://api.github.com/repos/carefree0910/MachineLearning/git/blobs{/sha}',
#   u'branches_url': u'https://api.github.com/repos/carefree0910/MachineLearning/branches{/branch}',
#   u'clone_url': u'https://github.com/carefree0910/MachineLearning.git',
#   u'collaborators_url': u'https://api.github.com/repos/carefree0910/MachineLearning/collaborators{/collaborator}',
#   u'comments_url': u'https://api.github.com/repos/carefree0910/MachineLearning/comments{/number}',
#   u'commits_url': u'https://api.github.com/repos/carefree0910/MachineLearning/commits{/sha}',
#   u'compare_url': u'https://api.github.com/repos/carefree0910/MachineLearning/compare/{base}...{head}',
#   u'contents_url': u'https://api.github.com/repos/carefree0910/MachineLearning/contents/{+path}',
#   u'contributors_url': u'https://api.github.com/repos/carefree0910/MachineLearning/contributors',
#   u'created_at': u'2016-09-18T09:37:01Z',
#   u'default_branch': u'master',
#   u'deployments_url': u'https://api.github.com/repos/carefree0910/MachineLearning/deployments',
#   u'description': u'Machine learning algorithms implemented by pure numpy',
#   u'downloads_url': u'https://api.github.com/repos/carefree0910/MachineLearning/downloads',
#   u'events_url': u'https://api.github.com/repos/carefree0910/MachineLearning/events',
#   u'fork': False,
#   u'forks': 308,
#   u'forks_count': 308,
#   u'forks_url': u'https://api.github.com/repos/carefree0910/MachineLearning/forks',
#   u'full_name': u'carefree0910/MachineLearning',
#   u'git_commits_url': u'https://api.github.com/repos/carefree0910/MachineLearning/git/commits{/sha}',
#   u'git_refs_url': u'https://api.github.com/repos/carefree0910/MachineLearning/git/refs{/sha}',
#   u'git_tags_url': u'https://api.github.com/repos/carefree0910/MachineLearning/git/tags{/sha}',
#   u'git_url': u'git://github.com/carefree0910/MachineLearning.git',
#   u'has_downloads': True,
#   u'has_issues': True,
#   u'has_pages': False,
#   u'has_projects': True,
#   u'has_wiki': True,
#   u'homepage': u'',
#   u'hooks_url': u'https://api.github.com/repos/carefree0910/MachineLearning/hooks',
#   u'html_url': u'https://github.com/carefree0910/MachineLearning',
#   u'id': 68511643,
#   u'issue_comment_url': u'https://api.github.com/repos/carefree0910/MachineLearning/issues/comments{/number}',
#   u'issue_events_url': u'https://api.github.com/repos/carefree0910/MachineLearning/issues/events{/number}',
#   u'issues_url': u'https://api.github.com/repos/carefree0910/MachineLearning/issues{/number}',
#   u'keys_url': u'https://api.github.com/repos/carefree0910/MachineLearning/keys{/key_id}',
#   u'labels_url': u'https://api.github.com/repos/carefree0910/MachineLearning/labels{/name}',
#   u'language': u'Jupyter Notebook',
#   u'languages_url': u'https://api.github.com/repos/carefree0910/MachineLearning/languages',
#   u'license': {u'key': u'mit',
#    u'name': u'MIT License',
#    u'node_id': u'MDc6TGljZW5zZTEz',
#    u'spdx_id': u'MIT',
#    u'url': u'https://api.github.com/licenses/mit'},
#   u'merges_url': u'https://api.github.com/repos/carefree0910/MachineLearning/merges',
#   u'milestones_url': u'https://api.github.com/repos/carefree0910/MachineLearning/milestones{/number}',
#   u'mirror_url': None,
#   u'name': u'MachineLearning',
#   u'node_id': u'MDEwOlJlcG9zaXRvcnk2ODUxMTY0Mw==',
#   u'notifications_url': u'https://api.github.com/repos/carefree0910/MachineLearning/notifications{?since,all,participating}',
#   u'open_issues': 0,
#   u'open_issues_count': 0,
#   u'owner': {u'avatar_url': u'https://avatars1.githubusercontent.com/u/15677328?v=4',
#    u'events_url': u'https://api.github.com/users/carefree0910/events{/privacy}',
#    u'followers_url': u'https://api.github.com/users/carefree0910/followers',
#    u'following_url': u'https://api.github.com/users/carefree0910/following{/other_user}',
#    u'gists_url': u'https://api.github.com/users/carefree0910/gists{/gist_id}',
#    u'gravatar_id': u'',
#    u'html_url': u'https://github.com/carefree0910',
#    u'id': 15677328,
#    u'login': u'carefree0910',
#    u'node_id': u'MDQ6VXNlcjE1Njc3MzI4',
#    u'organizations_url': u'https://api.github.com/users/carefree0910/orgs',
#    u'received_events_url': u'https://api.github.com/users/carefree0910/received_events',
#    u'repos_url': u'https://api.github.com/users/carefree0910/repos',
#    u'site_admin': False,
#    u'starred_url': u'https://api.github.com/users/carefree0910/starred{/owner}{/repo}',
#    u'subscriptions_url': u'https://api.github.com/users/carefree0910/subscriptions',
#    u'type': u'User',
#    u'url': u'https://api.github.com/users/carefree0910'},
#   u'private': False,
#   u'pulls_url': u'https://api.github.com/repos/carefree0910/MachineLearning/pulls{/number}',
#   u'pushed_at': u'2018-06-12T02:56:14Z',
#   u'releases_url': u'https://api.github.com/repos/carefree0910/MachineLearning/releases{/id}',
#   u'size': 54789,
#   u'ssh_url': u'git@github.com:carefree0910/MachineLearning.git',
#   u'stargazers_count': 428,
#   u'stargazers_url': u'https://api.github.com/repos/carefree0910/MachineLearning/stargazers',
#   u'statuses_url': u'https://api.github.com/repos/carefree0910/MachineLearning/statuses/{sha}',
#   u'subscribers_url': u'https://api.github.com/repos/carefree0910/MachineLearning/subscribers',
#   u'subscription_url': u'https://api.github.com/repos/carefree0910/MachineLearning/subscription',
#   u'svn_url': u'https://github.com/carefree0910/MachineLearning',
#   u'tags_url': u'https://api.github.com/repos/carefree0910/MachineLearning/tags',
#   u'teams_url': u'https://api.github.com/repos/carefree0910/MachineLearning/teams',
#   u'trees_url': u'https://api.github.com/repos/carefree0910/MachineLearning/git/trees{/sha}',
#   u'updated_at': u'2018-06-12T03:20:22Z',
#   u'url': u'https://api.github.com/repos/carefree0910/MachineLearning',
#   u'watchers': 428,
#   u'watchers_count': 428},
#  {u'archive_url': u'https://api.github.com/repos/apachecn/MachineLearning/{archive_format}{/ref}',
#   u'archived': False,
#   u'assignees_url': u'https://api.github.com/repos/apachecn/MachineLearning/assignees{/user}',
#   u'blobs_url': u'https://api.github.com/repos/apachecn/MachineLearning/git/blobs{/sha}',
#   u'branches_url': u'https://api.github.com/repos/apachecn/MachineLearning/branches{/branch}',
#   u'clone_url': u'https://github.com/apachecn/MachineLearning.git',
#   u'collaborators_url': u'https://api.github.com/repos/apachecn/MachineLearning/collaborators{/collaborator}',
#   u'comments_url': u'https://api.github.com/repos/apachecn/MachineLearning/comments{/number}',
#   u'commits_url': u'https://api.github.com/repos/apachecn/MachineLearning/commits{/sha}',
#   u'compare_url': u'https://api.github.com/repos/apachecn/MachineLearning/compare/{base}...{head}',
#   u'contents_url': u'https://api.github.com/repos/apachecn/MachineLearning/contents/{+path}',
#   u'contributors_url': u'https://api.github.com/repos/apachecn/MachineLearning/contributors',
#   u'created_at': u'2017-02-25T08:53:02Z',
#   u'default_branch': u'dev',
#   u'deployments_url': u'https://api.github.com/repos/apachecn/MachineLearning/deployments',
#   u'description': u'Machine Learning in Action\uff08\u673a\u5668\u5b66\u4e60\u5b9e\u6218\uff09',
#   u'downloads_url': u'https://api.github.com/repos/apachecn/MachineLearning/downloads',
#   u'events_url': u'https://api.github.com/repos/apachecn/MachineLearning/events',
#   u'fork': False,
#   u'forks': 1616,
#   u'forks_count': 1616,
#   u'forks_url': u'https://api.github.com/repos/apachecn/MachineLearning/forks',
#   u'full_name': u'apachecn/MachineLearning',
#   u'git_commits_url': u'https://api.github.com/repos/apachecn/MachineLearning/git/commits{/sha}',
#   u'git_refs_url': u'https://api.github.com/repos/apachecn/MachineLearning/git/refs{/sha}',
#   u'git_tags_url': u'https://api.github.com/repos/apachecn/MachineLearning/git/tags{/sha}',
#   u'git_url': u'git://github.com/apachecn/MachineLearning.git',
#   u'has_downloads': True,
#   u'has_issues': True,
#   u'has_pages': False,
#   u'has_projects': True,
#   u'has_wiki': False,
#   u'homepage': u'http://ml.apachecn.org/mlia',
#   u'hooks_url': u'https://api.github.com/repos/apachecn/MachineLearning/hooks',
#   u'html_url': u'https://github.com/apachecn/MachineLearning',
#   u'id': 83119431,
#   u'issue_comment_url': u'https://api.github.com/repos/apachecn/MachineLearning/issues/comments{/number}',
#   u'issue_events_url': u'https://api.github.com/repos/apachecn/MachineLearning/issues/events{/number}',
#   u'issues_url': u'https://api.github.com/repos/apachecn/MachineLearning/issues{/number}',
#   u'keys_url': u'https://api.github.com/repos/apachecn/MachineLearning/keys{/key_id}',
#   u'labels_url': u'https://api.github.com/repos/apachecn/MachineLearning/labels{/name}',
#   u'language': u'Python',
#   u'languages_url': u'https://api.github.com/repos/apachecn/MachineLearning/languages',
#   u'license': {u'key': u'gpl-3.0',
#    u'name': u'GNU General Public License v3.0',
#    u'node_id': u'MDc6TGljZW5zZTk=',
#    u'spdx_id': u'GPL-3.0',
#    u'url': u'https://api.github.com/licenses/gpl-3.0'},
#   u'merges_url': u'https://api.github.com/repos/apachecn/MachineLearning/merges',
#   u'milestones_url': u'https://api.github.com/repos/apachecn/MachineLearning/milestones{/number}',
#   u'mirror_url': None,
#   u'name': u'MachineLearning',
#   u'node_id': u'MDEwOlJlcG9zaXRvcnk4MzExOTQzMQ==',
#   u'notifications_url': u'https://api.github.com/repos/apachecn/MachineLearning/notifications{?since,all,participating}',
#   u'open_issues': 2,
#   u'open_issues_count': 2,
#   u'owner': {u'avatar_url': u'https://avatars3.githubusercontent.com/u/24802038?v=4',
#    u'events_url': u'https://api.github.com/users/apachecn/events{/privacy}',
#    u'followers_url': u'https://api.github.com/users/apachecn/followers',
#    u'following_url': u'https://api.github.com/users/apachecn/following{/other_user}',
#    u'gists_url': u'https://api.github.com/users/apachecn/gists{/gist_id}',
#    u'gravatar_id': u'',
#    u'html_url': u'https://github.com/apachecn',
#    u'id': 24802038,
#    u'login': u'apachecn',
#    u'node_id': u'MDEyOk9yZ2FuaXphdGlvbjI0ODAyMDM4',
#    u'organizations_url': u'https://api.github.com/users/apachecn/orgs',
#    u'received_events_url': u'https://api.github.com/users/apachecn/received_events',
#    u'repos_url': u'https://api.github.com/users/apachecn/repos',
#    u'site_admin': False,
#    u'starred_url': u'https://api.github.com/users/apachecn/starred{/owner}{/repo}',
#    u'subscriptions_url': u'https://api.github.com/users/apachecn/subscriptions',
#    u'type': u'Organization',
#    u'url': u'https://api.github.com/users/apachecn'},
#   u'private': False,
#   u'pulls_url': u'https://api.github.com/repos/apachecn/MachineLearning/pulls{/number}',
#   u'pushed_at': u'2018-06-11T08:35:50Z',
#   u'releases_url': u'https://api.github.com/repos/apachecn/MachineLearning/releases{/id}',
#   u'size': 140289,
#   u'ssh_url': u'git@github.com:apachecn/MachineLearning.git',
#   u'stargazers_count': 4438,
#   u'stargazers_url': u'https://api.github.com/repos/apachecn/MachineLearning/stargazers',
#   u'statuses_url': u'https://api.github.com/repos/apachecn/MachineLearning/statuses/{sha}',
#   u'subscribers_url': u'https://api.github.com/repos/apachecn/MachineLearning/subscribers',
#   u'subscription_url': u'https://api.github.com/repos/apachecn/MachineLearning/subscription',
#   u'svn_url': u'https://github.com/apachecn/MachineLearning',
#   u'tags_url': u'https://api.github.com/repos/apachecn/MachineLearning/tags',
#   u'teams_url': u'https://api.github.com/repos/apachecn/MachineLearning/teams',
#   u'trees_url': u'https://api.github.com/repos/apachecn/MachineLearning/git/trees{/sha}',
#   u'updated_at': u'2018-06-12T06:24:13Z',
#   u'url': u'https://api.github.com/repos/apachecn/MachineLearning',
#   u'watchers': 4438,
#   u'watchers_count': 4438},
#  {u'archive_url': u'https://api.github.com/repos/phodal/growth-ebook/{archive_format}{/ref}',
#   u'archived': False,
#   u'assignees_url': u'https://api.github.com/repos/phodal/growth-ebook/assignees{/user}',
#   u'blobs_url': u'https://api.github.com/repos/phodal/growth-ebook/git/blobs{/sha}',
#   u'branches_url': u'https://api.github.com/repos/phodal/growth-ebook/branches{/branch}',
#   u'clone_url': u'https://github.com/phodal/growth-ebook.git',
#   u'collaborators_url': u'https://api.github.com/repos/phodal/growth-ebook/collaborators{/collaborator}',
#   u'comments_url': u'https://api.github.com/repos/phodal/growth-ebook/comments{/number}',
#   u'commits_url': u'https://api.github.com/repos/phodal/growth-ebook/commits{/sha}',
#   u'compare_url': u'https://api.github.com/repos/phodal/growth-ebook/compare/{base}...{head}',
#   u'contents_url': u'https://api.github.com/repos/phodal/growth-ebook/contents/{+path}',
#   u'contributors_url': u'https://api.github.com/repos/phodal/growth-ebook/contributors',
#   u'created_at': u'2016-02-21T14:37:32Z',
#   u'default_branch': u'gh-pages',
#   u'deployments_url': u'https://api.github.com/repos/phodal/growth-ebook/deployments',
#   u'description': u'Growth Engineering: The Definitive Guide\u3002\u5168\u6808\u589e\u957f\u5de5\u7a0b\u5e08\u6307\u5357',
#   u'downloads_url': u'https://api.github.com/repos/phodal/growth-ebook/downloads',
#   u'events_url': u'https://api.github.com/repos/phodal/growth-ebook/events',
#   u'fork': False,
#   u'forks': 1108,
#   u'forks_count': 1108,
#   u'forks_url': u'https://api.github.com/repos/phodal/growth-ebook/forks',
#   u'full_name': u'phodal/growth-ebook',
#   u'git_commits_url': u'https://api.github.com/repos/phodal/growth-ebook/git/commits{/sha}',
#   u'git_refs_url': u'https://api.github.com/repos/phodal/growth-ebook/git/refs{/sha}',
#   u'git_tags_url': u'https://api.github.com/repos/phodal/growth-ebook/git/tags{/sha}',
#   u'git_url': u'git://github.com/phodal/growth-ebook.git',
#   u'has_downloads': True,
#   u'has_issues': True,
#   u'has_pages': True,
#   u'has_projects': True,
#   u'has_wiki': True,
#   u'homepage': u'http://growth.phodal.com/',
#   u'hooks_url': u'https://api.github.com/repos/phodal/growth-ebook/hooks',
#   u'html_url': u'https://github.com/phodal/growth-ebook',
#   u'id': 52210728,
#   u'issue_comment_url': u'https://api.github.com/repos/phodal/growth-ebook/issues/comments{/number}',
#   u'issue_events_url': u'https://api.github.com/repos/phodal/growth-ebook/issues/events{/number}',
#   u'issues_url': u'https://api.github.com/repos/phodal/growth-ebook/issues{/number}',
#   u'keys_url': u'https://api.github.com/repos/phodal/growth-ebook/keys{/key_id}',
#   u'labels_url': u'https://api.github.com/repos/phodal/growth-ebook/labels{/name}',
#   u'language': u'HTML',
#   u'languages_url': u'https://api.github.com/repos/phodal/growth-ebook/languages',
#   u'license': {u'key': u'other',
#    u'name': u'Other',
#    u'node_id': u'MDc6TGljZW5zZTA=',
#    u'spdx_id': None,
#    u'url': None},
#   u'merges_url': u'https://api.github.com/repos/phodal/growth-ebook/merges',
#   u'milestones_url': u'https://api.github.com/repos/phodal/growth-ebook/milestones{/number}',
#   u'mirror_url': None,
#   u'name': u'growth-ebook',
#   u'node_id': u'MDEwOlJlcG9zaXRvcnk1MjIxMDcyOA==',
#   u'notifications_url': u'https://api.github.com/repos/phodal/growth-ebook/notifications{?since,all,participating}',
#   u'open_issues': 0,
#   u'open_issues_count': 0,
#   u'owner': {u'avatar_url': u'https://avatars1.githubusercontent.com/u/472311?v=4',
#    u'events_url': u'https://api.github.com/users/phodal/events{/privacy}',
#    u'followers_url': u'https://api.github.com/users/phodal/followers',
#    u'following_url': u'https://api.github.com/users/phodal/following{/other_user}',
#    u'gists_url': u'https://api.github.com/users/phodal/gists{/gist_id}',
#    u'gravatar_id': u'',
#    u'html_url': u'https://github.com/phodal',
#    u'id': 472311,
#    u'login': u'phodal',
#    u'node_id': u'MDQ6VXNlcjQ3MjMxMQ==',
#    u'organizations_url': u'https://api.github.com/users/phodal/orgs',
#    u'received_events_url': u'https://api.github.com/users/phodal/received_events',
#    u'repos_url': u'https://api.github.com/users/phodal/repos',
#    u'site_admin': False,
#    u'starred_url': u'https://api.github.com/users/phodal/starred{/owner}{/repo}',
#    u'subscriptions_url': u'https://api.github.com/users/phodal/subscriptions',
#    u'type': u'User',
#    u'url': u'https://api.github.com/users/phodal'},
#   u'private': False,
#   u'pulls_url': u'https://api.github.com/repos/phodal/growth-ebook/pulls{/number}',
#   u'pushed_at': u'2018-01-14T23:53:26Z',
#   u'releases_url': u'https://api.github.com/repos/phodal/growth-ebook/releases{/id}',
#   u'size': 17558,
#   u'ssh_url': u'git@github.com:phodal/growth-ebook.git',
#   u'stargazers_count': 6056,
#   u'stargazers_url': u'https://api.github.com/repos/phodal/growth-ebook/stargazers',
#   u'statuses_url': u'https://api.github.com/repos/phodal/growth-ebook/statuses/{sha}',
#   u'subscribers_url': u'https://api.github.com/repos/phodal/growth-ebook/subscribers',
#   u'subscription_url': u'https://api.github.com/repos/phodal/growth-ebook/subscription',
#   u'svn_url': u'https://github.com/phodal/growth-ebook',
#   u'tags_url': u'https://api.github.com/repos/phodal/growth-ebook/tags',
#   u'teams_url': u'https://api.github.com/repos/phodal/growth-ebook/teams',
#   u'trees_url': u'https://api.github.com/repos/phodal/growth-ebook/git/trees{/sha}',
#   u'updated_at': u'2018-06-11T14:09:30Z',
#   u'url': u'https://api.github.com/repos/phodal/growth-ebook',
#   u'watchers': 6056,
#   u'watchers_count': 6056},
#  {u'archive_url': u'https://api.github.com/repos/xingbuxing/TA-Lib-in-chinese/{archive_format}{/ref}',
#   u'archived': False,
#   u'assignees_url': u'https://api.github.com/repos/xingbuxing/TA-Lib-in-chinese/assignees{/user}',
#   u'blobs_url': u'https://api.github.com/repos/xingbuxing/TA-Lib-in-chinese/git/blobs{/sha}',
#   u'branches_url': u'https://api.github.com/repos/xingbuxing/TA-Lib-in-chinese/branches{/branch}',
#   u'clone_url': u'https://github.com/xingbuxing/TA-Lib-in-chinese.git',
#   u'collaborators_url': u'https://api.github.com/repos/xingbuxing/TA-Lib-in-chinese/collaborators{/collaborator}',
#   u'comments_url': u'https://api.github.com/repos/xingbuxing/TA-Lib-in-chinese/comments{/number}',
#   u'commits_url': u'https://api.github.com/repos/xingbuxing/TA-Lib-in-chinese/commits{/sha}',
#   u'compare_url': u'https://api.github.com/repos/xingbuxing/TA-Lib-in-chinese/compare/{base}...{head}',
#   u'contents_url': u'https://api.github.com/repos/xingbuxing/TA-Lib-in-chinese/contents/{+path}',
#   u'contributors_url': u'https://api.github.com/repos/xingbuxing/TA-Lib-in-chinese/contributors',
#   u'created_at': u'2017-07-29T00:23:32Z',
#   u'default_branch': u'master',
#   u'deployments_url': u'https://api.github.com/repos/xingbuxing/TA-Lib-in-chinese/deployments',
#   u'description': u'\u4e2d\u6587\u7248TA-Lib\u5e93\u4f7f\u7528\u6559\u7a0b',
#   u'downloads_url': u'https://api.github.com/repos/xingbuxing/TA-Lib-in-chinese/downloads',
#   u'events_url': u'https://api.github.com/repos/xingbuxing/TA-Lib-in-chinese/events',
#   u'fork': False,
#   u'forks': 62,
#   u'forks_count': 62,
#   u'forks_url': u'https://api.github.com/repos/xingbuxing/TA-Lib-in-chinese/forks',
#   u'full_name': u'xingbuxing/TA-Lib-in-chinese',
#   u'git_commits_url': u'https://api.github.com/repos/xingbuxing/TA-Lib-in-chinese/git/commits{/sha}',
#   u'git_refs_url': u'https://api.github.com/repos/xingbuxing/TA-Lib-in-chinese/git/refs{/sha}',
#   u'git_tags_url': u'https://api.github.com/repos/xingbuxing/TA-Lib-in-chinese/git/tags{/sha}',
#   u'git_url': u'git://github.com/xingbuxing/TA-Lib-in-chinese.git',
#   u'has_downloads': True,
#   u'has_issues': True,
#   u'has_pages': False,
#   u'has_projects': True,
#   u'has_wiki': True,
#   u'homepage': None,
#   u'hooks_url': u'https://api.github.com/repos/xingbuxing/TA-Lib-in-chinese/hooks',
#   u'html_url': u'https://github.com/xingbuxing/TA-Lib-in-chinese',
#   u'id': 98697419,
#   u'issue_comment_url': u'https://api.github.com/repos/xingbuxing/TA-Lib-in-chinese/issues/comments{/number}',
#   u'issue_events_url': u'https://api.github.com/repos/xingbuxing/TA-Lib-in-chinese/issues/events{/number}',
#   u'issues_url': u'https://api.github.com/repos/xingbuxing/TA-Lib-in-chinese/issues{/number}',
#   u'keys_url': u'https://api.github.com/repos/xingbuxing/TA-Lib-in-chinese/keys{/key_id}',
#   u'labels_url': u'https://api.github.com/repos/xingbuxing/TA-Lib-in-chinese/labels{/name}',
#   u'language': u'Jupyter Notebook',
#   u'languages_url': u'https://api.github.com/repos/xingbuxing/TA-Lib-in-chinese/languages',
#   u'license': None,
#   u'merges_url': u'https://api.github.com/repos/xingbuxing/TA-Lib-in-chinese/merges',
#   u'milestones_url': u'https://api.github.com/repos/xingbuxing/TA-Lib-in-chinese/milestones{/number}',
#   u'mirror_url': None,
#   u'name': u'TA-Lib-in-chinese',
#   u'node_id': u'MDEwOlJlcG9zaXRvcnk5ODY5NzQxOQ==',
#   u'notifications_url': u'https://api.github.com/repos/xingbuxing/TA-Lib-in-chinese/notifications{?since,all,participating}',
#   u'open_issues': 8,
#   u'open_issues_count': 8,
#   u'owner': {u'avatar_url': u'https://avatars2.githubusercontent.com/u/30513600?v=4',
#    u'events_url': u'https://api.github.com/users/xingbuxing/events{/privacy}',
#    u'followers_url': u'https://api.github.com/users/xingbuxing/followers',
#    u'following_url': u'https://api.github.com/users/xingbuxing/following{/other_user}',
#    u'gists_url': u'https://api.github.com/users/xingbuxing/gists{/gist_id}',
#    u'gravatar_id': u'',
#    u'html_url': u'https://github.com/xingbuxing',
#    u'id': 30513600,
#    u'login': u'xingbuxing',
#    u'node_id': u'MDQ6VXNlcjMwNTEzNjAw',
#    u'organizations_url': u'https://api.github.com/users/xingbuxing/orgs',
#    u'received_events_url': u'https://api.github.com/users/xingbuxing/received_events',
#    u'repos_url': u'https://api.github.com/users/xingbuxing/repos',
#    u'site_admin': False,
#    u'starred_url': u'https://api.github.com/users/xingbuxing/starred{/owner}{/repo}',
#    u'subscriptions_url': u'https://api.github.com/users/xingbuxing/subscriptions',
#    u'type': u'User',
#    u'url': u'https://api.github.com/users/xingbuxing'},
#   u'private': False,
#   u'pulls_url': u'https://api.github.com/repos/xingbuxing/TA-Lib-in-chinese/pulls{/number}',
#   u'pushed_at': u'2017-09-03T13:54:58Z',
#   u'releases_url': u'https://api.github.com/repos/xingbuxing/TA-Lib-in-chinese/releases{/id}',
#   u'size': 3022,
#   u'ssh_url': u'git@github.com:xingbuxing/TA-Lib-in-chinese.git',
#   u'stargazers_count': 75,
#   u'stargazers_url': u'https://api.github.com/repos/xingbuxing/TA-Lib-in-chinese/stargazers',
#   u'statuses_url': u'https://api.github.com/repos/xingbuxing/TA-Lib-in-chinese/statuses/{sha}',
#   u'subscribers_url': u'https://api.github.com/repos/xingbuxing/TA-Lib-in-chinese/subscribers',
#   u'subscription_url': u'https://api.github.com/repos/xingbuxing/TA-Lib-in-chinese/subscription',
#   u'svn_url': u'https://github.com/xingbuxing/TA-Lib-in-chinese',
#   u'tags_url': u'https://api.github.com/repos/xingbuxing/TA-Lib-in-chinese/tags',
#   u'teams_url': u'https://api.github.com/repos/xingbuxing/TA-Lib-in-chinese/teams',
#   u'trees_url': u'https://api.github.com/repos/xingbuxing/TA-Lib-in-chinese/git/trees{/sha}',
#   u'updated_at': u'2018-06-12T06:01:01Z',
#   u'url': u'https://api.github.com/repos/xingbuxing/TA-Lib-in-chinese',
#   u'watchers': 75,
#   u'watchers_count': 75}]
