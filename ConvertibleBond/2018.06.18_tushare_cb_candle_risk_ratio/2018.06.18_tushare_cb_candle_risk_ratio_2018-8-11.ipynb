# %% [markdown]
# ## tushare_cb_candle_risk_ratio（2018-8-11）

# %%
import pandas as pd
import tushare as ts
import Candle
import CB_Transaction_Data as cbtd
import time
# 确定tushare的版本
ts.__version__
# Out:
# '1.1.5'

# %%
# 创建api连接
cons = ts.get_apis()

# %%
# 设置显示K线的时间区间
stadate = '2018-05-01'
Now_Date = time.strftime('%Y-%m-%d',time.localtime(time.time()))
enddate = pd.to_datetime(Now_Date)

# %% [markdown]
# [蓝标转债](#蓝标转债123001)、[辉丰转债](#辉丰转债128012)、[洪涛转债](#洪涛转债128013)、[航信转债](#航信转债110031)、[海印转债](#海印转债127003)、[光大转债](#光大转债113011)、[模塑转债](#模塑转债127004)、[江南转债](#江南转债113010)、[电气转债](#电气转债113008)、[格力转债](#格力转债110030)、[久其转债](#久其转债128015)、[嘉澳转债](#嘉澳转债113502)、[小康转债](#小康转债113016)、[时达转债](#时达转债128018)、[骆驼转债](#骆驼转债113012)、[蒙电转债](#蒙电转债110041)、[吉视转债](#吉视转债113017)、[迪龙转债](#迪龙转债128033)、[永东转债](#永东转债128014)、[众兴转债](#众兴转债128026)、[水晶转债](#水晶转债128020)、[亚太转债](#亚太转债128023)、[久立转2](#久立转2128019)、[双环转债](#双环转债128032)、[江银转债](#江银转债128034)、[无锡转债](#无锡转债110043)、[金农转债](#金农转债128036)、[岩土转债](#岩土转债128037)

# %% [markdown]
# ### 蓝标转债123001

# %%
lanbiao = ts.bar('123001', conn=cons)
lanbiao.head()
# Out:
#               code   open   close    high     low    vol      amount
# datetime
# 2018-08-10  123001  88.18  88.596  88.620  88.100  256.0  22672174.0
# 2018-08-09  123001  87.71  87.936  87.999  87.700  256.0  22572382.0
# 2018-08-08  123001  88.00  87.825  88.000  87.700  112.0   9842979.0
# 2018-08-07  123001  87.85  87.890  88.293  87.839  208.0  18352430.0
# 2018-08-06  123001  88.08  87.850  88.170  87.830  100.0   8881267.0

# %%
lanbiao['date'] = lanbiao.index
lanbiao['volume'] = lanbiao['vol']*100
Candle_lanbiao = Candle.Candle_plot(lanbiao, stadate, enddate)

# %%
cbtd.lanbiao_CB_TD.tail()
# Out:
#          发生日期    业务名称    证券代码  证券名称   成交均价  成交数量   成交金额  股份余额   手续费    发生金额  \
# 45 2018-05-11  证券买入清算  123001  蓝标转债  94.40    10  944.0   120  0.19 -944.19
# 46 2018-05-24  证券买入清算  123001  蓝标转债  92.92    10  929.2   130  0.19 -929.39
# 47 2018-05-29  证券买入清算  123001  蓝标转债  90.00    10  900.0   140  0.18 -900.18
# 48 2018-05-31  证券买入清算  123001  蓝标转债  87.37    10  873.7   150  0.17 -873.87
# 49 2018-07-25  证券卖出清算  123001  蓝标转债  90.78   -10  907.8   140  0.18  907.62
#
#         成本    到期本息   到期利率%  到期年化%
# 45  99.885  109.84  16.356  4.540
# 46  99.350  109.84  18.209  5.105
# 47  98.684  109.84  22.044  6.204
# 48  97.931  109.84  25.718  7.249
# 49  98.443    0.00   0.000  0.000

# %%
cbtd.lanbiao_CB_TD_cost
# Out:
#           持仓金额   成交数量    持仓成本         起息日    剩余年限    证券代码   成交金额  买卖数量  \
# 蓝标转债  13781.99  140.0  98.443  2015-12-18  3年127天  123001  90.78   -10
#
#            交易时间    到期本息   到期利率%  到期年化%  锁仓张数
# 蓝标转债 2018-07-25  109.84  11.578  3.408    30

# %% [markdown]
# ### 辉丰转债128012

# %%
huifeng = ts.bar('128012', conn=cons)
huifeng.head()
# Out:
#               code    open   close    high     low    vol      amount
# datetime
# 2018-08-10  128012  74.231  74.985  75.200  74.080  220.0  16546283.0
# 2018-08-09  128012  73.846  74.231  74.398  73.846  161.0  11971986.0
# 2018-08-08  128012  74.297  73.831  74.476  73.760   81.0   6044680.0
# 2018-08-07  128012  73.710  74.290  74.500  73.710  192.0  14299968.0
# 2018-08-06  128012  74.855  73.590  74.855  73.000  175.0  12931583.0

# %%
huifeng['date'] = huifeng.index
huifeng['volume'] = huifeng['vol']*100
Candle_huifeng = Candle.Candle_plot(huifeng, stadate, enddate)

# %%
cbtd.huifeng_CB_TD.tail()
# Out:
#          发生日期    业务名称    证券代码  证券名称   成交均价  成交数量   成交金额  股份余额   手续费    发生金额  \
# 50 2018-04-23  证券买入清算  128012  辉丰转债  86.88    10  868.8   160  0.17 -868.97
# 51 2018-04-23  证券买入清算  128012  辉丰转债  90.80    10  908.0   130  0.18 -908.18
# 52 2018-04-23  证券买入清算  128012  辉丰转债  90.60    10  906.0   140  0.18 -906.18
# 53 2018-04-23  证券买入清算  128012  辉丰转债  88.21    10  882.1   150  0.18 -882.28
# 54 2018-04-24  证券买入清算  128012  辉丰转债  83.55    10  835.5   170  0.17 -835.67
#
#          成本    到期本息   到期利率%  到期年化%
# 50   78.814  105.28  21.179  5.302
# 51  103.987  105.28  15.947  3.992
# 52  103.032  105.28  16.203  4.056
# 53  102.045  105.28  19.352  4.845
# 54   94.956  105.28  26.008  6.515

# %%
cbtd.huifeng_CB_TD_cost
# Out:
#           持仓金额   成交数量    持仓成本         起息日    剩余年限    证券代码   成交金额  买卖数量  \
# 辉丰转债  16142.49  170.0  94.956  2016-04-21  3年252天  128012  83.55    10
#
#            交易时间    到期本息   到期利率%  到期年化%  锁仓张数
# 辉丰转债 2018-04-24  105.28  10.873  2.724    20

# %% [markdown]
# ### 洪涛转债128013

# %%
hongtao = ts.bar('128013', conn=cons)
hongtao.head()
# Out:
#               code    open   close    high     low    vol      amount
# datetime
# 2018-08-10  128013  87.221  87.221  87.388  87.008  208.0  3776461.50
# 2018-08-09  128013  87.248  87.397  87.409  87.030  256.0  4098130.00
# 2018-08-08  128013  87.290  87.005  87.290  87.000   26.0  2279483.50
# 2018-08-07  128013  86.599  86.999  86.999  86.599  480.0  5294846.00
# 2018-08-06  128013  86.801  86.600  87.000  86.514  208.0  3805770.25

# %%
hongtao['date'] = hongtao.index
hongtao['volume'] = hongtao['vol']*100
Candle_hongtao = Candle.Candle_plot(hongtao, stadate, enddate)

# %%
cbtd.hongtao_CB_TD.tail()
# Out:
#          发生日期    业务名称    证券代码  证券名称    成交均价  成交数量    成交金额  股份余额    手续费  \
# 47 2018-05-03  证券买入清算  128013  洪涛转债  91.800    10  918.00   410   0.18
# 48 2018-05-28  证券买入清算  128013  洪涛转债  89.991    10  899.91   420   0.18
# 49 2018-05-30  证券买入清算  128013  洪涛转债  88.010    10  880.10   430   0.18
# 50 2018-07-25  证券卖出清算  128013  洪涛转债  89.720   -10  897.20   420   0.18
# 51 2018-07-27    债券兑息  128013  洪涛转债   0.000     0  252.00   420  50.40
#
#       发生金额       成本    到期本息   到期利率%  到期年化%
# 47 -918.18  101.826  110.32  20.174  4.760
# 48 -900.09  101.545  110.32  22.590  5.417
# 49 -880.28  101.230  110.32  25.349  6.087
# 50  897.02  101.505    0.00   0.000  0.000
# 51  201.60  101.025    0.00   0.000  0.000

# %%
cbtd.hongtao_CB_TD_cost
# Out:
#           持仓金额   成交数量     持仓成本         起息日    剩余年限    证券代码  成交金额  买卖数量  \
# 洪涛转债  42430.37  420.0  101.025  2016-07-29  3年352天  128013   0.0     0
#
#            交易时间    到期本息  到期利率%  到期年化%  锁仓张数
# 洪涛转债 2018-07-27  110.32  9.201  2.297    20

# %% [markdown]
# ### 航信转债110031

# %%
hangxin = ts.bar('110031', conn=cons)
hangxin.head()
# Out:
#               code    open   close    high     low    vol      amount
# datetime
# 2018-08-10  110031  105.92  106.31  106.59  105.92  776.0   1238442.0
# 2018-08-09  110031  105.50  106.50  106.61  105.49  196.0  20859012.0
# 2018-08-08  110031  105.17  105.38  105.60  105.17  384.0   5726363.0
# 2018-08-07  110031  105.10  105.49  105.50  105.10  208.0   4543402.0
# 2018-08-06  110031  104.88  105.11  105.77  104.75   79.0   8336665.0

# %%
hangxin['date'] = hangxin.index
hangxin['volume'] = hangxin['vol']*100
Candle_hangxin = Candle.Candle_plot(hangxin, stadate, enddate)

# %%
cbtd.hangxin_CB_TD.tail()
# Out:
#          发生日期    业务名称    证券代码  证券名称    成交均价  成交数量    成交金额  股份余额   手续费    发生金额  \
# 27 2018-04-19  证券卖出清算  110031  航信转债  106.24   -20  2124.8    50   1.0  2123.8
# 28 2018-04-20  证券卖出清算  110031  航信转债  107.51   -10  1075.1    40   1.0  1074.1
# 29 2018-05-18  证券买入清算  110031  航信转债  104.19    10  1041.9    50   1.0 -1042.9
# 30 2018-06-04  证券买入清算  110031  航信转债  101.13    10  1011.3    60   1.0 -1012.3
# 31 2018-06-15    债券兑息  110031  航信转债    0.00     0    60.0    60  12.0    48.0
#
#          成本   到期本息  到期利率%  到期年化%
# 27  100.301    0.0  0.000  0.000
# 28   98.524    0.0  0.000  0.000
# 29   99.677  108.8  4.425  1.443
# 30   99.936  108.8  7.584  2.512
# 31   99.136    0.0  0.000  0.000

# %%
cbtd.hangxin_CB_TD_cost
# Out:
#          持仓金额  成交数量    持仓成本         起息日    剩余年限    证券代码  成交金额  买卖数量  \
# 航信转债  5948.16  60.0  99.136  2015-06-12  2年304天  110031   0.0     0
#
#            交易时间   到期本息  到期利率%  到期年化%  锁仓张数
# 航信转债 2018-06-15  108.0  8.941  2.991   0.0

# %% [markdown]
# ### 海印转债127003

# %%
haiyin = ts.bar('127003', conn=cons)
haiyin.head()
# Out:
#               code    open   close    high     low    vol      amount
# datetime
# 2018-08-10  127003  90.000  89.350  90.300  89.172  558.0  50144520.0
# 2018-08-09  127003  90.680  92.400  92.990  90.600  420.0  38476356.0
# 2018-08-08  127003  90.790  90.590  91.090  90.320  276.0  25074764.0
# 2018-08-07  127003  90.300  90.590  90.789  90.300  207.0  18827636.0
# 2018-08-06  127003  89.814  90.299  90.720  89.814  117.0  10655114.0

# %%
haiyin['date'] = haiyin.index
haiyin['volume'] = haiyin['vol']*100
Candle_haiyin = Candle.Candle_plot(haiyin, stadate, enddate)

# %%
cbtd.haiyin_CB_TD.tail(10)
# Out:
#          发生日期    业务名称    证券代码  证券名称    成交均价  成交数量    成交金额  股份余额    手续费  \
# 22 2017-11-21  证券买入清算  127003  海印转债  96.135    10  961.35   150   0.19
# 23 2017-11-24  证券买入清算  127003  海印转债  95.788    10  957.88   160   0.19
# 24 2017-12-07  证券买入清算  127003  海印转债  93.730    10  937.30   170   0.19
# 25 2018-01-25  证券卖出清算  127003  海印转债  94.265   -10  942.65   160   0.19
# 26 2018-02-09  证券买入清算  127003  海印转债  93.000    10  930.00   170   0.19
# 27 2018-05-14  证券买入清算  127003  海印转债  91.800    10  918.00   180   0.18
# 28 2018-05-28  证券买入清算  127003  海印转债  89.998    10  899.98   190   0.18
# 29 2018-06-07    债券兑息  127003  海印转债   0.000     0  133.00   190  26.60
# 30 2018-07-25  证券卖出清算  127003  海印转债  91.330   -10  913.30   180   0.18
# 31 2018-07-26  证券卖出清算  127003  海印转债  92.362   -10  923.62   170   0.18
#
#       发生金额       成本   到期本息   到期利率%  到期年化%
# 22 -961.54  100.577  112.0  16.503  3.631
# 23 -958.07  100.279  112.0  16.925  3.730
# 24 -937.49   99.895  112.0  19.492  4.330
# 25  942.46  100.248    0.0   0.000  0.000
# 26 -930.19   99.822  112.0  20.430  4.723
# 27 -918.18   99.378  112.0  22.004  5.408
# 28 -900.16   98.885  112.0  24.447  6.066
# 29  106.40   98.325    0.0   0.000  0.000
# 30  913.12   98.715    0.0   0.000  0.000
# 31  923.44   99.089    0.0   0.000  0.000

# %%
cbtd.haiyin_CB_TD_cost
# Out:
#           持仓金额   成交数量    持仓成本         起息日    剩余年限    证券代码    成交金额  买卖数量  \
# 海印转债  16845.18  170.0  99.089  2016-06-08  3年300天  127003  92.362   -10
#
#            交易时间    到期本息   到期利率%  到期年化%  锁仓张数
# 海印转债 2018-07-26  111.44  12.464  3.222    20

# %% [markdown]
# ### 光大转债113011

# %%
guangda = ts.bar('113011', conn=cons)
guangda.head()
# Out:
#               code    open   close    high     low     vol       amount
# datetime
# 2018-08-10  113011  106.49  105.99  106.58  105.80  1994.0  211714464.0
# 2018-08-09  113011  106.10  106.41  107.10  106.09  2149.0  229169840.0
# 2018-08-08  113011  106.40  106.13  107.09  105.71  1456.0  154894944.0
# 2018-08-07  113011  105.40  106.90  107.00  105.38  3229.0  341481216.0
# 2018-08-06  113011  105.67  105.40  106.40  105.21   788.0   83533600.0

# %%
guangda['date'] = guangda.index
guangda['volume'] = guangda['vol']*100
# Candle_guangda = Candle.Candle_plot(guangda, stadate, enddate)

# %%
cbtd.guangda_CB_TD.tail()
# Out:
#         发生日期    业务名称    证券代码  证券名称    成交均价  成交数量    成交金额  股份余额  手续费    发生金额  \
# 2 2017-05-08  证券买入清算  113011  光大转债  100.11    10  1001.1    30  1.0 -1002.1
# 3 2017-05-08  证券买入清算  113011  光大转债   99.90    10   999.0    40  1.0 -1000.0
# 4 2017-06-28  证券卖出清算  113011  光大转债  106.01   -20  2120.2    20  1.0  2119.2
# 5 2017-07-13  证券卖出清算  113011  光大转债  107.22   -10  1072.2    10  1.0  1071.2
# 6 2017-07-17  证券卖出清算  113011  光大转债  110.95   -10  1109.5     0  1.0  1108.5
#
#        成本   到期本息  到期利率%  到期年化%
# 2  100.52  108.0  7.881  1.346
# 3  100.39  108.0  8.108  1.384
# 4   94.82    0.0  0.000  0.000
# 5   82.52    0.0  0.000  0.000
# 6    0.00    0.0  0.000  0.000

# %%
cbtd.guangda_CB_TD_cost
# Out:
#        持仓金额  成交数量  持仓成本         起息日    剩余年限    证券代码    成交金额  买卖数量       交易时间  \
# 光大转债 -283.3   0.0     0  2017-03-17  4年218天  113011  110.95   -10 2017-07-17
#
#        到期本息  到期利率%  到期年化%  锁仓张数
# 光大转债  108.0      0      0   0.0

# %% [markdown]
# ### 模塑转债127004

# %%
mosu = ts.bar('127004', conn=cons)
mosu.head()
# Out:
#               code    open   close   high     low   vol       amount
# datetime
# 2018-08-10  127004  87.301  87.280  87.40  87.271   5.0   482001.125
# 2018-08-09  127004  86.998  87.270  87.28  86.800  30.0  2679547.250
# 2018-08-08  127004  86.990  86.918  87.40  86.871  20.0  1750859.250
# 2018-08-07  127004  86.610  86.871  87.17  86.610  17.0  1539156.625
# 2018-08-06  127004  87.100  86.611  87.30  86.611   8.0   748428.500

# %%
mosu['date'] = mosu.index
mosu['volume'] = mosu['vol']*100
Candle_mosu = Candle.Candle_plot(mosu, stadate, enddate)

# %%
cbtd.mosu_CB_TD.tail()
# Out:
#          发生日期    业务名称    证券代码  证券名称    成交均价  成交数量     成交金额  股份余额    手续费  \
# 8  2017-11-29  证券买入清算  127004  模塑转债  97.050    20  1941.00   110   0.39
# 9  2017-12-07  证券买入清算  127004  模塑转债  93.988    10   939.88   120   0.19
# 10 2018-01-25  证券卖出清算  127004  模塑转债  96.582   -10   965.82   110   0.19
# 11 2018-05-28  证券买入清算  127004  模塑转债  90.900    10   909.00   120   0.18
# 12 2018-06-01    债券兑息  127004  模塑转债   0.000     0    60.00   120  12.00
#
#        发生金额       成本   到期本息   到期利率%  到期年化%
# 8  -1941.39  101.996  112.4  15.817  2.872
# 9   -940.07  101.330  112.4  19.590  3.572
# 10   965.63  101.764    0.0   0.000  0.000
# 11  -909.18  100.860  112.4  23.652  4.718
# 12    48.00  100.460    0.0   0.000  0.000

# %%
cbtd.mosu_CB_TD_cost
# Out:
#           持仓金额   成交数量    持仓成本         起息日    剩余年限    证券代码  成交金额  买卖数量  \
# 模塑转债  12055.18  120.0  100.46  2017-06-02  4年295天  127004   0.0     0
#
#            交易时间   到期本息   到期利率%  到期年化%  锁仓张数
# 模塑转债 2018-06-01  112.4  11.886  2.376   0.0

# %% [markdown]
# ### 江南转债113010

# %%
jiangnan = ts.bar('113010', conn=cons)
jiangnan.head()
# Out:
#               code    open   close    high     low           vol     amount
# datetime
# 2018-08-10  113010  102.31  102.40  102.40  102.31  1.700000e+01  1800904.0
# 2018-08-09  113010  102.31  102.31  102.39  102.29  5.877472e-39    48086.0
# 2018-08-08  113010  102.40  102.35  102.74  102.29  2.000000e+00   209060.0
# 2018-08-07  113010  102.36  102.35  102.36  102.20  1.900000e+01  1952488.0
# 2018-08-06  113010  102.17  102.30  102.30  102.17  1.120000e+02  3856440.0

# %%
jiangnan['date'] = jiangnan.index
jiangnan['volume'] = jiangnan['vol']*100
Candle_jiangnan = Candle.Candle_plot(jiangnan, stadate, enddate)

# %%
cbtd.jiangnan_CB_TD.tail()
# Out:
#         发生日期    业务名称    证券代码  证券名称    成交均价  成交数量    成交金额  股份余额  手续费    发生金额  \
# 2 2018-01-04  证券买入清算  113010  江南转债  103.29    10  1032.9    30  1.0 -1033.9
# 3 2018-03-22    债券兑息  113010  江南转债    0.00     0    15.0    30  3.0    12.0
# 4 2018-05-03  证券买入清算  113010  江南转债  102.00    10  1020.0    40  1.0 -1021.0
# 5 2018-05-22  证券买入清算  113010  江南转债  101.02    10  1010.2    50  1.0 -1011.2
# 6 2018-07-26    转债回售  113010  江南转债  103.00   -30  3090.0    20  1.0  3089.0
#
#         成本    到期本息  到期利率%  到期年化%
# 2  104.600  110.24  6.729  1.602
# 3  104.200    0.00  0.000  0.000
# 4  103.675  109.84  7.686  1.984
# 5  103.164  109.84  8.731  2.284
# 6  103.460    0.00  0.000  0.000

# %%
cbtd.jiangnan_CB_TD_cost
# Out:
#         持仓金额  成交数量    持仓成本         起息日    剩余年限    证券代码   成交金额  买卖数量  \
# 江南转债  2069.2  20.0  103.46  2016-03-18  3年219天  113010  103.0   -30
#
#            交易时间    到期本息  到期利率%  到期年化%  锁仓张数
# 江南转债 2018-07-26  109.84  6.167  1.692   0.0

# %% [markdown]
# ### 电气转债113008

# %%
dianqi = ts.bar('113008', conn=cons)
dianqi['date'] = dianqi.index
dianqi['volume'] = dianqi['vol']*100
Candle_dianqi = Candle.Candle_plot(dianqi, stadate, enddate)

# %%
cbtd.dianqi_CB_TD.tail()
# Out:
#         发生日期    业务名称    证券代码  证券名称    成交均价  成交数量    成交金额  股份余额   手续费    发生金额  \
# 4 2017-11-29  证券买入清算  113008  电气转债  100.02    10  1000.2    60   1.0 -1001.2
# 5 2018-01-25  证券卖出清算  113008  电气转债  102.09   -10  1020.9    50   1.0  1019.9
# 6 2018-02-02  证券买入清算  113008  电气转债  100.01    10  1000.1    60   1.0 -1001.1
# 7 2018-02-07    债券兑息  113008  电气转债    0.00     0    50.0    60  10.0    40.0
# 8 2018-08-07  证券卖出清算  113008  电气转债  101.92   -20  2038.4    40   1.0  2037.4
#
#         成本    到期本息  到期利率%  到期年化%
# 4  102.407  108.48  8.458  2.664
# 5  102.490    0.00  0.000  0.000
# 6  102.093  107.68  7.669  2.559
# 7  101.427    0.00  0.000  0.000
# 8  101.205    0.00  0.000  0.000

# %%
cbtd.dianqi_CB_TD_cost
# Out:
#         持仓金额  成交数量     持仓成本         起息日    剩余年限    证券代码    成交金额  买卖数量  \
# 电气转债  4048.2  40.0  101.205  2015-02-02  2年174天  113008  101.92   -20
#
#            交易时间    到期本息  到期利率%  到期年化%  锁仓张数
# 电气转债 2018-08-07  107.68  6.398  2.572   0.0

# %% [markdown]
# ### 格力转债110030

# %%
geli = ts.bar('110030', conn=cons)
geli['date'] = geli.index
geli['volume'] = geli['vol']*100
Candle_geli = Candle.Candle_plot(geli, stadate, enddate)

# %%
cbtd.geli_CB_TD.tail()
# Out:
#         发生日期    业务名称    证券代码  证券名称    成交均价  成交数量    成交金额  股份余额  手续费    发生金额  \
# 1 2017-11-21  证券买入清算  110030  格力转债  106.61    10  1066.1    20  1.0 -1067.1
# 2 2017-12-27  证券买入清算  110030  格力转债  104.89    10  1048.9    30  1.0 -1049.9
# 3 2017-12-28    债券兑息  110030  格力转债    0.00     0    20.0    30  4.0    16.0
# 4 2018-01-25  证券卖出清算  110030  格力转债  111.03   -10  1110.3    20  1.0  1109.3
# 5 2018-02-07  证券买入清算  110030  格力转债  106.50    10  1065.0    30  1.0 -1066.0
#
#         成本   到期本息  到期利率%  到期年化%
# 1  107.080  106.8  0.178  0.085
# 2  106.383  106.0  1.058  0.531
# 3  105.850    0.0  0.000  0.000
# 4  103.310    0.0  0.000  0.000
# 5  104.407  106.0 -0.469 -0.250

# %%
cbtd.geli_CB_TD_cost
# Out:
#         持仓金额  成交数量     持仓成本         起息日    剩余年限    证券代码   成交金额  买卖数量  \
# 格力转债  3132.2  30.0  104.407  2014-12-25  2年135天  110030  106.5    10
#
#            交易时间   到期本息  到期利率%  到期年化%  锁仓张数
# 格力转债 2018-02-07  106.0  1.526  0.813   0.0

# %% [markdown]
# ### 久其转债128015

# %%
jiuqi = ts.bar('128015', conn=cons)
jiuqi['date'] = jiuqi.index
jiuqi['volume'] = jiuqi['vol']*100
# Candle_jiuqi = Candle.Candle_plot(jiuqi, stadate, enddate)

# %%
cbtd.jiuqi_CB_TD.tail()
# Out:
#         发生日期    业务名称    证券代码  证券名称     成交均价  成交数量     成交金额  股份余额   手续费  \
# 3 2018-01-04  证券卖出清算  128015  久其转债   97.278   -10   972.78    20  0.19
# 4 2018-01-25  证券卖出清算  128015  久其转债  100.849   -10  1008.49    10  0.20
# 5 2018-01-26  证券卖出清算  128015  久其转债  102.450   -10  1024.50     0  0.20
# 6 2018-01-31  证券买入清算  128015  久其转债   98.010    10   980.10    10  0.20
# 7 2018-02-14  证券卖出清算  128015  久其转债  100.097   -10  1000.97     0  0.20
#
#       发生金额      成本    到期本息   到期利率%  到期年化%
# 3   972.59  99.949    0.00   0.000  0.000
# 4  1008.29  99.070    0.00   0.000  0.000
# 5  1024.30   0.000    0.00   0.000  0.000
# 6  -980.30  94.670  110.08  12.315  2.302
# 7  1000.77   0.000    0.00   0.000  0.000

# %%
cbtd.jiuqi_CB_TD_cost
# Out:
#        持仓金额  成交数量  持仓成本         起息日    剩余年限    证券代码     成交金额  买卖数量       交易时间  \
# 久其转债 -54.07   0.0     0  2017-06-08  4年300天  128015  100.097   -10 2018-02-14
#
#         到期本息  到期利率%  到期年化%  锁仓张数
# 久其转债  110.08      0      0   0.0

# %% [markdown]
# ### 嘉澳转债113502

# %%
jiaao = ts.bar('113502', conn=cons)
jiaao.head()
# Out:
#               code   open  close   high    low    vol     amount
# datetime
# 2018-08-10  113502  89.77  89.77  90.87  89.61  520.0   930203.0
# 2018-08-09  113502  88.62  89.72  90.00  88.62   20.0  1867779.0
# 2018-08-08  113502  88.97  88.75  89.04  88.70  264.0   862342.0
# 2018-08-07  113502  88.87  88.97  89.95  88.64   17.0  1591133.0
# 2018-08-06  113502  88.35  88.87  89.39  88.35    7.0   692090.0

# %%
jiaao['date'] = jiaao.index
jiaao['volume'] = jiaao['vol']*100
Candle_jiaao = Candle.Candle_plot(jiaao, stadate, enddate)

# %%
cbtd.jiaao_CB_TD.tail()
# Out:
#         发生日期    业务名称    证券代码  证券名称    成交均价  成交数量    成交金额  股份余额  手续费    发生金额  \
# 0 2017-11-29  证券买入清算  113502  嘉澳转债  101.78    10  1017.8    10  1.0 -1018.8
# 1 2017-12-07  证券买入清算  113502  嘉澳转债   96.12    10   961.2    20  1.0  -962.2
# 2 2018-05-10  证券卖出清算  113502  嘉澳转债  101.09   -10  1010.9    10  1.0  1009.9
# 3 2018-05-30  证券买入清算  113502  嘉澳转债   91.86    10   918.6    20  1.0  -919.6
#
#         成本    到期本息   到期利率%  到期年化%
# 0  101.880  110.64   8.705  1.464
# 1   99.050  110.64  15.106  2.549
# 2   97.110    0.00   0.000  0.000
# 3   94.535  110.64  20.444  3.752

# %%
cbtd.jiaao_CB_TD_cost
# Out:
#         持仓金额  成交数量    持仓成本         起息日   剩余年限    证券代码   成交金额  买卖数量       交易时间  \
# 嘉澳转债  1890.7  20.0  94.535  2017-11-10  5年91天  113502  91.86    10 2018-05-30
#
#         到期本息   到期利率%  到期年化%  锁仓张数
# 嘉澳转债  110.64  17.036  3.126   0.0

# %% [markdown]
# ### 小康转债113016

# %%
xiaokang = ts.bar('113016', conn=cons)
xiaokang['date'] = xiaokang.index
xiaokang['volume'] = xiaokang['vol']*100
# Candle_xiaokang = Candle.Candle_plot(xiaokang, stadate, enddate)

# %%
cbtd.xiaokang_CB_TD.tail()
# Out:
#         发生日期    业务名称    证券代码  证券名称    成交均价  成交数量    成交金额  股份余额  手续费    发生金额  \
# 0 2017-11-29  证券买入清算  113016  小康转债  100.38    10  1003.8    10  1.0 -1004.8
# 1 2017-12-07  证券买入清算  113016  小康转债   96.75    10   967.5    20  1.0  -968.5
# 2 2018-01-04  证券卖出清算  113016  小康转债  100.40   -20  2008.0     0  1.0  2007.0
# 3 2018-02-01  证券买入清算  113016  小康转债   95.70    10   957.0    10  1.0  -958.0
# 4 2018-03-06  证券卖出清算  113016  小康转债   98.52   -10   985.2     0  1.0   984.2
#
#         成本    到期本息   到期利率%  到期年化%
# 0  100.480  108.88   8.468  1.426
# 1   98.665  108.88  12.537  2.120
# 2    0.000    0.00   0.000  0.000
# 3   92.430  108.88  13.772  2.390
# 4    0.000    0.00   0.000  0.000

# %%
cbtd.xiaokang_CB_TD_cost
# Out:
#       持仓金额  成交数量  持仓成本         起息日   剩余年限    证券代码   成交金额  买卖数量       交易时间  \
# 小康转债 -59.9   0.0     0  2017-11-06  5年86天  113016  98.52   -10 2018-03-06
#
#         到期本息  到期利率%  到期年化%  锁仓张数
# 小康转债  108.88      0      0   0.0

# %% [markdown]
# ### 时达转债128018

# %%
shida = ts.bar('128018', conn=cons)
shida.head()
# Out:
#               code    open   close    high     low     vol       amount
# datetime
# 2018-08-10  128018  88.327  88.300  88.400  88.108     7.0   674300.875
# 2018-08-09  128018  88.077  88.370  88.687  88.077  2056.0  1417956.250
# 2018-08-08  128018  89.180  88.330  89.180  88.290  1032.0  1063137.875
# 2018-08-07  128018  87.650  88.286  88.860  87.630  2056.0  1480022.875
# 2018-08-06  128018  88.000  87.990  88.200  87.500  1544.0  1283801.000

# %%
shida['date'] = shida.index
shida['volume'] = shida['vol']*100
Candle_shida = Candle.Candle_plot(shida, stadate, enddate)

# %%
cbtd.shida_CB_TD.tail(10)
# Out:
#          发生日期    业务名称    证券代码  证券名称    成交均价  成交数量    成交金额  股份余额   手续费    发生金额  \
# 1  2018-01-25  证券卖出清算  128018  时达转债  97.717   -10  977.17     0  0.20  976.97
# 2  2018-02-06  证券买入清算  128018  时达转债  94.980    10  949.80    10  0.19 -949.99
# 3  2018-03-13  证券卖出清算  128018  时达转债  96.650   -10  966.50     0  0.19  966.31
# 4  2018-03-23  证券买入清算  128018  时达转债  94.711    10  947.11    10  0.19 -947.30
# 5  2018-03-29  证券卖出清算  128018  时达转债  95.300   -10  953.00     0  0.19  952.81
# 6  2018-04-24  证券买入清算  128018  时达转债  93.628    10  936.28    10  0.19 -936.47
# 7  2018-04-26  证券买入清算  128018  时达转债  92.611    10  926.11    20  0.19 -926.30
# 8  2018-05-28  证券买入清算  128018  时达转债  90.800    10  908.00    30  0.18 -908.18
# 9  2018-06-05  证券买入清算  128018  时达转债  87.603    10  876.03    40  0.18 -876.21
# 10 2018-07-20  证券卖出清算  128018  时达转债  89.515   -10  895.15    30  0.18  894.97
#
#         成本    到期本息   到期利率%  到期年化%
# 1    0.000    0.00   0.000  0.000
# 2   93.323  108.88  14.635  2.546
# 3    0.000    0.00   0.000  0.000
# 4   91.422  108.88  14.960  2.660
# 5    0.000    0.00   0.000  0.000
# 6   89.788  108.88  16.290  2.942
# 7   91.209  108.88  17.567  3.176
# 8   91.079  108.88  19.912  3.658
# 9   90.214  108.88  24.288  4.480
# 10  90.453    0.00   0.000  0.000

# %%
cbtd.shida_CB_TD_cost
# Out:
#         持仓金额  成交数量    持仓成本         起息日   剩余年限    证券代码    成交金额  买卖数量  \
# 时达转债  2713.6  30.0  90.453  2017-11-06  5年86天  128018  89.515   -10
#
#            交易时间    到期本息   到期利率%  到期年化%  锁仓张数
# 时达转债 2018-07-20  108.88  20.371  3.845   0.0

# %% [markdown]
# ### 骆驼转债113012

# %%
luotuo = ts.bar('113012', conn=cons)
luotuo['date'] = luotuo.index
luotuo['volume'] = luotuo['vol']*100
# Candle_luotuo = Candle.Candle_plot(luotuo, stadate, enddate)

# %%
cbtd.luotuo_CB_TD.tail()
# Out:
#         发生日期    业务名称    证券代码  证券名称   成交均价  成交数量   成交金额  股份余额  手续费   发生金额  \
# 0 2017-12-07  证券买入清算  113012  骆驼转债  97.38    10  973.8    10  1.0 -974.8
# 1 2018-01-25  证券卖出清算  113012  骆驼转债  98.94   -10  989.4     0  1.0  988.4
# 2 2018-02-01  证券买入清算  113012  骆驼转债  95.56    10  955.6    10  1.0 -956.6
# 3 2018-03-09  证券卖出清算  113012  骆驼转债  98.68   -10  986.8     0  1.0  985.8
#
#       成本    到期本息   到期利率%  到期年化%
# 0  97.48  107.68  10.577  1.998
# 1   0.00    0.00   0.000  0.000
# 2  94.30  107.68  12.683  2.468
# 3   0.00    0.00   0.000  0.000

# %%
cbtd.luotuo_CB_TD_cost
# Out:
#       持仓金额  成交数量  持仓成本         起息日    剩余年限    证券代码   成交金额  买卖数量       交易时间  \
# 骆驼转债 -42.8   0.0     0  2017-03-24  4年225天  113012  98.68   -10 2018-03-09
#
#         到期本息  到期利率%  到期年化%  锁仓张数
# 骆驼转债  107.68      0      0   0.0

# %% [markdown]
# ### 蒙电转债110041

# %%
mengdian = ts.bar('110041', conn=cons)
mengdian['date'] = mengdian.index
mengdian['volume'] = mengdian['vol']*100
# Candle_mengdian = Candle.Candle_plot(mengdian, stadate, enddate)

# %%
cbtd.mengdian_CB_TD.tail()
# Out:
#         发生日期      业务名称    证券代码  证券名称    成交均价  成交数量    成交金额  股份余额  手续费    发生金额  \
# 0 2017-12-26  市值认购资金扣收  110041  蒙电转债  100.00    10  1000.0    10  0.0 -1000.0
# 1 2018-01-25    证券卖出清算  110041  蒙电转债  104.60   -10  1046.0     0  1.0  1045.0
# 2 2018-02-09    证券买入清算  110041  蒙电转债   98.35    10   983.5    10  1.0  -984.5
# 3 2018-02-13    证券卖出清算  110041  蒙电转债  100.51   -10  1005.1     0  1.0  1004.1
#
#        成本    到期本息   到期利率%  到期年化%
# 0  100.00  109.04   9.040  1.509
# 1    0.00    0.00   0.000  0.000
# 2   93.95  109.04  10.869  1.853
# 3    0.00    0.00   0.000  0.000

# %%
cbtd.mengdian_CB_TD_cost
# Out:
#       持仓金额  成交数量  持仓成本         起息日    剩余年限    证券代码    成交金额  买卖数量       交易时间  \
# 蒙电转债 -64.6   0.0     0  2017-12-22  5年132天  110041  100.51   -10 2018-02-13
#
#         到期本息  到期利率%  到期年化%  锁仓张数
# 蒙电转债  109.04      0      0   0.0

# %% [markdown]
# ### 吉视转债113017

# %%
jishi = ts.bar('113017', conn=cons)
jishi['date'] = jishi.index
jishi['volume'] = jishi['vol']*100
Candle_jishi = Candle.Candle_plot(jishi, stadate, enddate)

# %%
cbtd.jishi_CB_TD.tail()
# Out:
#         发生日期      业务名称    证券代码  证券名称    成交均价  成交数量    成交金额  股份余额  手续费    发生金额  \
# 0 2017-12-29  市值认购资金扣收  113017  吉视转债  100.00    30  3000.0    30  0.0 -3000.0
# 1 2018-01-25    证券卖出清算  113017  吉视转债  106.50   -10  1065.0    20  1.0  1064.0
# 2 2018-02-07    证券买入清算  113017  吉视转债   98.53    10   985.3    30  1.0  -986.3
# 3 2018-02-26    证券卖出清算  113017  吉视转债  100.65   -10  1006.5    20  1.0  1005.5
#
#        成本    到期本息   到期利率%  到期年化%
# 0  100.00  108.48   8.480  1.415
# 1   96.80    0.00   0.000  0.000
# 2   97.41  108.48  10.098  1.716
# 3   95.84    0.00   0.000  0.000

# %%
cbtd.jishi_CB_TD_cost
# Out:
#         持仓金额  成交数量   持仓成本         起息日    剩余年限    证券代码    成交金额  买卖数量  \
# 吉视转债  1916.8  20.0  95.84  2017-12-27  5年137天  113017  100.65   -10
#
#            交易时间    到期本息   到期利率%  到期年化%  锁仓张数
# 吉视转债 2018-02-26  108.48  13.189  2.261   0.0

# %% [markdown]
# ### 迪龙转债128033

# %%
dilong = ts.bar('128033', conn=cons)
dilong.head()
# Out:
#               code    open   close    high     low     vol        amount
# datetime
# 2018-08-10  128033  96.051  96.240  96.499  96.051     2.0  2.189823e+05
# 2018-08-09  128033  95.320  96.621  98.500  95.320     8.0  8.223546e+05
# 2018-08-08  128033  96.010  95.751  96.799  95.702  4098.0  3.710138e+05
# 2018-08-07  128033  95.500  96.001  96.974  95.500     5.0  5.742382e+05
# 2018-08-06  128033  95.800  95.851  96.000  95.024   776.0  1.130585e+06

# %%
dilong['date'] = dilong.index
dilong['volume'] = dilong['vol']*100
# Candle_dilong = Candle.Candle_plot(dilong, stadate, enddate)

# %%
cbtd.dilong_CB_TD.tail()
# Out:
#         发生日期    业务名称    证券代码  证券名称    成交均价  成交数量    成交金额  股份余额   手续费    发生金额  \
# 5 2018-05-02  证券买入清算  128033  迪龙转债  94.380    10  943.80    20  0.19 -943.99
# 6 2018-05-21  证券卖出清算  128033  迪龙转债  97.710   -10  977.10    10  0.20  976.90
# 7 2018-05-30  证券买入清算  128033  迪龙转债  91.902    10  919.02    20  0.18 -919.20
# 8 2018-06-11  证券卖出清算  128033  迪龙转债  96.900   -10  969.00    10  0.19  968.81
# 9 2018-07-26  证券卖出清算  128033  迪龙转债  99.099   -10  990.99     0  0.20  990.79
#
#        成本    到期本息   到期利率%  到期年化%
# 5  91.755  108.48  14.940  2.642
# 6  85.820    0.00   0.000  0.000
# 7  88.870  108.48  18.039  3.234
# 8  80.859    0.00   0.000  0.000
# 9   0.000    0.00   0.000  0.000

# %%
cbtd.dilong_CB_TD_cost
# Out:
#        持仓金额  成交数量  持仓成本         起息日    剩余年限    证券代码    成交金额  买卖数量       交易时间  \
# 迪龙转债 -182.2   0.0     0  2017-12-27  5年137天  128033  99.099   -10 2018-07-26
#
#         到期本息  到期利率%  到期年化%  锁仓张数
# 迪龙转债  108.48      0      0   0.0

# %% [markdown]
# ### 永东转债128014

# %%
yongdong = ts.bar('128014', conn=cons)
yongdong.head()
# Out:
#               code     open    close     high     low    vol      amount
# datetime
# 2018-08-10  128014  101.490  101.480  101.990  101.11   90.0   9163188.0
# 2018-08-09  128014  101.200  101.489  101.983  100.50   89.0   9082377.0
# 2018-08-08  128014  101.880  100.900  101.880  100.70  176.0   4200806.5
# 2018-08-07  128014  100.500  101.870  102.230  100.50  101.0  10308098.0
# 2018-08-06  128014  100.651  100.495  101.154  100.20   30.0   3115374.0

# %%
yongdong['date'] = yongdong.index
yongdong['volume'] = yongdong['vol']*100
Candle_yongdong = Candle.Candle_plot(yongdong, stadate, enddate)

# %%
cbtd.yongdong_CB_TD.tail()
# Out:
#         发生日期    业务名称    证券代码  证券名称     成交均价  成交数量     成交金额  股份余额   手续费  \
# 1 2018-02-02  证券买入清算  128014  永东转债  103.101    10  1031.01    20  0.21
# 2 2018-02-06  证券买入清算  128014  永东转债  102.012    10  1020.12    30  0.20
# 3 2018-04-16    债券兑息  128014  永东转债    0.000     0    15.00    30  3.00
# 4 2018-05-09  证券卖出清算  128014  永东转债  105.700   -10  1057.00    20  0.21
# 5 2018-06-12  证券卖出清算  128014  永东转债  111.000   -10  1110.00    10  0.22
#
#       发生金额       成本   到期本息  到期利率%  到期年化%
# 1 -1031.22  103.775  110.8  7.467  1.435
# 2 -1020.32  103.194  110.8  8.615  1.659
# 3    12.00  102.794    0.0  0.000  0.000
# 4  1056.79  101.352    0.0  0.000  0.000
# 5  1109.78   91.725    0.0  0.000  0.000

# %%
cbtd.yongdong_CB_TD_cost
# Out:
#         持仓金额  成交数量    持仓成本         起息日    剩余年限    证券代码   成交金额  买卖数量  \
# 永东转债  917.25  10.0  91.725  2017-04-17  4年249天  128014  111.0   -10
#
#            交易时间   到期本息  到期利率%  到期年化%  锁仓张数
# 永东转债 2018-06-12  110.4  20.36  4.201   0.0

# %% [markdown]
# ### 众兴转债128026

# %%
zhongxing = ts.bar('128026', conn=cons)
zhongxing.head()
# Out:
#               code    open   close    high     low    vol      amount
# datetime
# 2018-08-10  128026  86.850  86.850  87.261  86.718  224.0  3860297.75
# 2018-08-09  128026  86.697  86.850  86.970  86.594  448.0  5113178.50
# 2018-08-08  128026  87.020  86.593  87.498  86.500  320.0  4357059.50
# 2018-08-07  128026  86.500  86.750  86.785  86.436   98.0  8545693.00
# 2018-08-06  128026  87.001  86.500  87.356  86.499  304.0  4264803.00

# %%
zhongxing['date'] = zhongxing.index
zhongxing['volume'] = zhongxing['vol']*100
Candle_zhongxing = Candle.Candle_plot(zhongxing, stadate, enddate)

# %%
cbtd.zhongxing_CB_TD.tail()
# Out:
#         发生日期    业务名称    证券代码  证券名称   成交均价  成交数量   成交金额  股份余额   手续费    发生金额  \
# 0 2018-02-06  证券买入清算  128026  众兴转债  95.56    10  955.6    10  0.19 -955.79
# 1 2018-03-13  证券卖出清算  128026  众兴转债  97.00   -10  970.0     0  0.19  969.81
# 2 2018-04-20  证券买入清算  128026  众兴转债  95.00    10  950.0    10  0.19 -950.19
#
#        成本    到期本息   到期利率%  到期年化%
# 0  95.579  109.04  14.106  2.412
# 1   0.000    0.00   0.000  0.000
# 2  93.617  109.04  14.779  2.616

# %%
cbtd.zhongxing_CB_TD_cost
# Out:
#         持仓金额  成交数量    持仓成本         起息日    剩余年限    证券代码  成交金额  买卖数量       交易时间  \
# 众兴转债  936.17  10.0  93.617  2017-12-13  5年123天  128026  95.0    10 2018-04-20
#
#         到期本息   到期利率%  到期年化%  锁仓张数
# 众兴转债  109.04  16.475  2.916   0.0

# %% [markdown]
# ### 水晶转债128020

# %%
shuijing = ts.bar('128020', conn=cons)
shuijing['date'] = shuijing.index
shuijing['volume'] = shuijing['vol']*100
# Candle_shuijing = Candle.Candle_plot(shuijing, stadate, enddate)

# %%
cbtd.shuijing_CB_TD.tail()
# Out:
#         发生日期    业务名称    证券代码  证券名称    成交均价  成交数量    成交金额  股份余额   手续费    发生金额  \
# 1 2018-02-08  证券买入清算  128020  水晶转债  95.062    10  950.62    20  0.19 -950.81
# 2 2018-02-22  证券卖出清算  128020  水晶转债  96.526   -10  965.26    10  0.19  965.07
# 3 2018-03-13  证券卖出清算  128020  水晶转债  99.620   -10  996.20     0  0.20  996.00
# 4 2018-04-23  证券买入清算  128020  水晶转债  94.201    10  942.01    10  0.19 -942.20
# 5 2018-05-02  证券卖出清算  128020  水晶转债  96.400   -10  964.00     0  0.19  963.81
#
#        成本    到期本息   到期利率%  到期年化%
# 1  96.050  109.52  15.209  2.635
# 2  95.594    0.00   0.000  0.000
# 3   0.000    0.00   0.000  0.000
# 4  90.214  109.52  16.262  2.920
# 5   0.000    0.00   0.000  0.000

# %%
cbtd.shuijing_CB_TD_cost
# Out:
#        持仓金额  成交数量  持仓成本         起息日   剩余年限    证券代码  成交金额  买卖数量       交易时间  \
# 水晶转债 -61.67   0.0     0  2017-11-17  5年98天  128020  96.4   -10 2018-05-02
#
#         到期本息  到期利率%  到期年化%  锁仓张数
# 水晶转债  109.52      0      0   0.0

# %% [markdown]
# ### 亚太转债128023

# %%
yatai = ts.bar('128023', conn=cons)
yatai.head()
# Out:
#               code    open   close    high     low     vol       amount
# datetime
# 2018-08-10  128023  87.269  87.299  87.300  87.220  2056.0  1447261.375
# 2018-08-09  128023  87.100  87.300  87.471  87.100    28.0  2450470.250
# 2018-08-08  128023  87.350  87.250  87.660  87.250    27.0  2441304.000
# 2018-08-07  128023  87.001  87.250  87.759  87.001   416.0  4889803.000
# 2018-08-06  128023  87.162  87.013  87.598  87.010  1800.0  1374230.500

# %%
yatai['date'] = yatai.index
yatai['volume'] = yatai['vol']*100
Candle_yatai = Candle.Candle_plot(yatai, stadate, enddate)

# %%
cbtd.yatai_CB_TD.tail()
# Out:
#         发生日期    业务名称    证券代码  证券名称    成交均价  成交数量    成交金额  股份余额   手续费    发生金额  \
# 0 2018-02-08  证券买入清算  128023  亚太转债  94.202    10  942.02    10  0.19 -942.21
# 1 2018-02-09  证券买入清算  128023  亚太转债  93.210    10  932.10    20  0.19 -932.29
#
#        成本    到期本息   到期利率%  到期年化%
# 0  94.221  110.48  17.280  2.969
# 1  93.725  110.48  18.528  3.185

# %%
cbtd.yatai_CB_TD_cost
# Out:
#         持仓金额  成交数量    持仓成本         起息日    剩余年限    证券代码   成交金额  买卖数量  \
# 亚太转债  1874.5  20.0  93.725  2017-12-04  5年114天  128023  93.21    10
#
#            交易时间    到期本息   到期利率%  到期年化%  锁仓张数
# 亚太转债 2018-02-09  110.48  17.877  3.073   0.0

# %% [markdown]
# ### 久立转2128019

# %%
jiuli = ts.bar('128019', conn=cons)
jiuli['date'] = jiuli.index
jiuli['volume'] = jiuli['vol']*100
# Candle_jiuli = Candle.Candle_plot(jiuli, stadate, enddate)

# %%
cbtd.jiuli_CB_TD.tail()
# Out:
#         发生日期    业务名称    证券代码  证券名称    成交均价  成交数量    成交金额  股份余额   手续费   发生金额  \
# 0 2018-02-09  证券买入清算  128019  久立转2  94.911    10  949.11    10  0.19 -949.3
# 1 2018-03-13  证券卖出清算  128019  久立转2  99.000   -10  990.00     0  0.20  989.8
#
#       成本    到期本息   到期利率%  到期年化%
# 0  94.93  108.48  14.297  2.488
# 1   0.00    0.00   0.000  0.000

# %%
cbtd.jiuli_CB_TD_cost
# Out:
#       持仓金额  成交数量  持仓成本         起息日   剩余年限    证券代码  成交金额  买卖数量       交易时间  \
# 久立转2 -40.5   0.0     0  2017-11-08  5年89天  128019  99.0   -10 2018-03-13
#
#         到期本息  到期利率%  到期年化%  锁仓张数
# 久立转2  108.48      0      0   0.0

# %% [markdown]
# ### 双环转债128032

# %%
shuanghuan = ts.bar('128032', conn=cons)
shuanghuan['date'] = shuanghuan.index
shuanghuan['volume'] = shuanghuan['vol']*100
# Candle_shuanghuan = Candle.Candle_plot(shuanghuan, stadate, enddate)

# %%
cbtd.shuanghuan_CB_TD.tail()
# Out:
#         发生日期    业务名称    证券代码  证券名称     成交均价  成交数量     成交金额  股份余额   手续费  \
# 0 2018-02-09  证券买入清算  128032  双环转债   97.348    10   973.48    10  0.19
# 1 2018-03-13  证券卖出清算  128032  双环转债  104.610   -10  1046.10     0  0.21
#
#       发生金额      成本    到期本息   到期利率%  到期年化%
# 0  -973.67  97.367  108.88  11.846  2.017
# 1  1045.89   0.000    0.00   0.000  0.000

# %%
cbtd.shuanghuan_CB_TD_cost
# Out:
#        持仓金额  成交数量  持仓成本         起息日    剩余年限    证券代码    成交金额  买卖数量       交易时间  \
# 双环转债 -72.22   0.0     0  2017-12-25  5年136天  128032  104.61   -10 2018-03-13
#
#         到期本息  到期利率%  到期年化%  锁仓张数
# 双环转债  108.88      0      0   0.0

# %% [markdown]
# ### 江银转债128034

# %%
jiangyin = ts.bar('128034', conn=cons)
jiangyin['date'] = jiangyin.index
jiangyin['volume'] = jiangyin['vol']*100
Candle_jiangyin = Candle.Candle_plot(jiangyin, stadate, enddate)

# %%
cbtd.jiangyin_CB_TD.tail()
# Out:
#         发生日期    业务名称    证券代码  证券名称    成交均价  成交数量    成交金额  股份余额   手续费    发生金额  \
# 4 2018-03-26  证券买入清算  128034  江银转债  93.165    10  931.65    50  0.19 -931.84
# 5 2018-04-17  证券卖出清算  128034  江银转债  97.150   -10  971.50    40  0.19  971.31
# 6 2018-04-17  证券卖出清算  128034  江银转债  98.001   -10  980.01    30  0.20  979.81
# 7 2018-04-19  证券卖出清算  128034  江银转债  98.205   -10  982.05    20  0.20  981.85
# 8 2018-05-03  证券卖出清算  128034  江银转债  98.980   -10  989.80    10  0.20  989.60
#
#        成本    到期本息   到期利率%  到期年化%
# 4  95.950  107.92  15.837  2.713
# 5  95.655    0.00   0.000  0.000
# 6  94.879    0.00   0.000  0.000
# 7  93.227    0.00   0.000  0.000
# 8  87.493    0.00   0.000  0.000

# %%
cbtd.jiangyin_CB_TD_cost
# Out:
#         持仓金额  成交数量    持仓成本         起息日    剩余年限    证券代码   成交金额  买卖数量  \
# 江银转债  874.93  10.0  87.493  2018-01-26  5年167天  128034  98.98   -10
#
#            交易时间    到期本息   到期利率%  到期年化%  锁仓张数
# 江银转债 2018-05-03  107.92  23.347  4.072   0.0

# %% [markdown]
# ### 无锡转债110043

# %%
wuxi = ts.bar('110043', conn=cons)
wuxi['date'] = wuxi.index
wuxi['volume'] = wuxi['vol']*100
Candle_wuxi = Candle.Candle_plot(wuxi, stadate, enddate)

# %%
cbtd.wuxi_CB_TD.tail()
# Out:
#         发生日期    业务名称    证券代码  证券名称    成交均价  成交数量    成交金额  股份余额  手续费    发生金额  \
# 1 2018-03-15  证券买入清算  110043  无锡转债   96.97    10   969.7    30  1.0  -970.7
# 2 2018-03-23  证券买入清算  110043  无锡转债   94.74    10   947.4    40  1.0  -948.4
# 3 2018-05-03  证券卖出清算  110043  无锡转债   97.50   -10   975.0    30  1.0   974.0
# 4 2018-05-07  证券卖出清算  110043  无锡转债   98.14   -10   981.4    20  1.0   980.4
# 5 2018-05-21  证券卖出清算  110043  无锡转债  101.50   -10  1015.0    10  1.0  1014.0
#
#        成本    到期本息   到期利率%  到期年化%
# 1  99.023  107.92  11.292  1.921
# 2  97.977  107.92  13.912  2.375
# 3  98.170    0.00   0.000  0.000
# 4  98.235    0.00   0.000  0.000
# 5  95.070    0.00   0.000  0.000

# %%
cbtd.wuxi_CB_TD_cost
# Out:
#        持仓金额  成交数量   持仓成本         起息日    剩余年限    证券代码   成交金额  买卖数量       交易时间  \
# 无锡转债  950.7  10.0  95.07  2018-01-30  5年172天  110043  101.5   -10 2018-05-21
#
#         到期本息   到期利率%  到期年化%  锁仓张数
# 无锡转债  107.92  13.516  2.373   0.0

# %% [markdown]
# ### 金农转债128036

# %%
jinnong = ts.bar('128036', conn=cons)
jinnong['date'] = jinnong.index
jinnong['volume'] = jinnong['vol']*100
# Candle_jinnong = Candle.Candle_plot(jinnong, stadate, enddate)

# %%
cbtd.jinnong_CB_TD.tail()
# Out:
#         发生日期    业务名称    证券代码  证券名称    成交均价  成交数量    成交金额  股份余额   手续费    发生金额  \
# 0 2018-04-20  证券买入清算  128036  金农转债  96.000    10  960.00    10  0.19 -960.19
# 1 2018-05-07  证券卖出清算  128036  金农转债  97.353   -10  973.53     0  0.19  973.34
#
#        成本    到期本息   到期利率%  到期年化%
# 0  96.019  109.04  13.583  2.308
# 1   0.000    0.00   0.000  0.000

# %%
cbtd.jinnong_CB_TD_cost
# Out:
#        持仓金额  成交数量  持仓成本         起息日    剩余年限    证券代码    成交金额  买卖数量       交易时间  \
# 金农转债 -13.15   0.0     0  2018-03-09  5年209天  128036  97.353   -10 2018-05-07
#
#         到期本息  到期利率%  到期年化%  锁仓张数
# 金农转债  109.04      0      0   0.0

# %% [markdown]
# ### 岩土转债128037

# %%
yantu = ts.bar('128037', conn=cons)
yantu.head()
# Out:
#               code    open   close    high     low     vol       amount
# datetime
# 2018-08-10  128037  87.903  87.753  88.101  87.611  1800.0  1362012.750
# 2018-08-09  128037  87.612  87.999  88.113  87.500    22.0  1945492.375
# 2018-08-08  128037  88.100  87.612  88.299  87.551    19.0  1713316.375
# 2018-08-07  128037  87.010  87.846  87.900  87.004   224.0  3941242.500
# 2018-08-06  128037  87.448  87.012  87.448  87.005    31.0  2737392.250

# %%
yantu['date'] = yantu.index
yantu['volume'] = yantu['vol']*100
Candle_yantu = Candle.Candle_plot(yantu, stadate, enddate)

# %%
cbtd.yantu_CB_TD.tail()
# Out:
#         发生日期    业务名称    证券代码  证券名称   成交均价  成交数量   成交金额  股份余额   手续费    发生金额  \
# 0 2018-05-30  证券买入清算  128037  岩土转债  91.92    10  919.2    10  0.18 -919.38
#
#        成本    到期本息   到期利率%  到期年化%
# 0  91.938  110.48  20.191  3.486

# %%
cbtd.yantu_CB_TD_cost
# Out:
#         持仓金额  成交数量    持仓成本         起息日    剩余年限    证券代码   成交金额  买卖数量  \
# 岩土转债  919.38  10.0  91.938  2018-03-15  5年216天  128037  91.92    10
#
#            交易时间    到期本息   到期利率%  到期年化%  锁仓张数
# 岩土转债 2018-05-30  110.48  20.168  3.482   0.0

# %% [raw]
# #关闭连接
# ts.close_apis(cons)
