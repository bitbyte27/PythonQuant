# %% [markdown]
# ## tushare_cb_candle_risk_ratio（2019-2-13）

# %%
import pandas as pd
import tushare as ts
import Candle
import CB_Transaction_Data as cbtd
import time
# 确定tushare的版本
ts.__version__
# Out:
# '1.1.5'

# %%
# 创建api连接
cons = ts.get_apis()

# %%
# 设置显示K线的时间区间
stadate = '2018-12-01'
Now_Date = time.strftime('%Y-%m-%d',time.localtime(time.time()))
enddate = pd.to_datetime(Now_Date)

# %% [markdown]
# [蓝标转债](#蓝标转债123001)、[辉丰转债](#辉丰转债128012)、[洪涛转债](#洪涛转债128013)、[航信转债](#航信转债110031)、[海印转债](#海印转债127003)、[光大转债](#光大转债113011)、[模塑转债](#模塑转债127004)、[江南转债](#江南转债113010)、[电气转债](#电气转债113008)、[格力转债](#格力转债110030)、[久其转债](#久其转债128015)、[嘉澳转债](#嘉澳转债113502)、[小康转债](#小康转债113016)、[时达转债](#时达转债128018)、[骆驼转债](#骆驼转债113012)、[蒙电转债](#蒙电转债110041)、[吉视转债](#吉视转债113017)、[迪龙转债](#迪龙转债128033)、[永东转债](#永东转债128014)、[众兴转债](#众兴转债128026)、[水晶转债](#水晶转债128020)、[亚太转债](#亚太转债128023)、[久立转2](#久立转2128019)、[双环转债](#双环转债128032)、[江银转债](#江银转债128034)、[无锡转债](#无锡转债110043)、[金农转债](#金农转债128036)、[岩土转债](#岩土转债128037)

# %% [markdown]
# ### 蓝标转债123001

# %%
cbtd.lanbiao_CB_TD_cost
# Out:
#         持仓金额  成交数量  持仓成本         起息日    剩余年限    证券代码   成交金额  买卖数量       交易时间  \
# 蓝标转债 -102.87   0.0     0  2015-12-18  2年307天  123001  100.2  -100 2019-01-31
#
#         到期本息  到期利率%  到期年化%  锁仓张数
# 蓝标转债  109.04      0      0    30

# %% [markdown]
# ### 辉丰转债128012

# %%
huifeng = ts.bar('128012', conn=cons)
huifeng.head()
# Out:
#               code   open   close    high     low    vol      amount
# datetime
# 2019-02-13  128012  92.90  92.136  92.900  91.700  120.0  11093619.0
# 2019-02-12  128012  92.88  93.180  93.180  92.000  367.0  34028284.0
# 2019-02-11  128012  90.49  91.490  91.600  90.301  552.0  50284356.0
# 2019-01-31  128012  88.95  88.907  89.377  88.710   83.0   7392894.0
# 2019-01-30  128012  89.00  88.950  89.490  88.701  264.0  23519032.0

# %%
huifeng['date'] = huifeng.index
huifeng['volume'] = huifeng['vol']*100
Candle_huifeng = Candle.Candle_plot(huifeng, stadate, enddate)

# %%
cbtd.huifeng_CB_TD.tail()
# Out:
#          发生日期    业务名称    证券代码  证券名称   成交均价  成交数量    成交金额  股份余额   手续费     发生金额  \
# 52 2018-04-23  证券买入清算  128012  辉丰转债  90.60    10   906.0   140  0.18  -906.18
# 53 2018-04-23  证券买入清算  128012  辉丰转债  88.21    10   882.1   150  0.18  -882.28
# 54 2018-04-24  证券买入清算  128012  辉丰转债  83.55    10   835.5   170  0.17  -835.67
# 55 2019-02-12  证券卖出清算  128012  辉丰转债  92.88   -30  2786.4   140  0.56  2785.84
# 56 2019-02-12  证券卖出清算  128012  辉丰转债  92.88   -20  1857.6   120  0.37  1857.23
#
#          成本    到期本息   到期利率%  到期年化%
# 52  103.032  105.28  16.203  4.056
# 53  102.045  105.28  19.352  4.845
# 54   94.956  105.28  26.008  6.515
# 55   95.405    0.00   0.000  0.000
# 56   95.828    0.00   0.000  0.000

# %%
cbtd.huifeng_CB_TD_cost
# Out:
#           持仓金额   成交数量    持仓成本         起息日   剩余年限    证券代码   成交金额  买卖数量  \
# 辉丰转债  11499.42  120.0  95.828  2016-04-21  3年67天  128012  92.88   -20
#
#            交易时间    到期本息  到期利率%  到期年化%  锁仓张数
# 辉丰转债 2019-02-12  105.28  9.863  3.095    20

# %% [markdown]
# ### 洪涛转债128013

# %%
hongtao = ts.bar('128013', conn=cons)
hongtao.head()
# Out:
#               code    open   close    high     low    vol      amount
# datetime
# 2019-02-13  128013  92.350  92.099  92.500  92.051   26.0  2456172.25
# 2019-02-12  128013  91.690  92.165  92.180  91.690  104.0  9582393.00
# 2019-02-11  128013  91.180  91.628  91.650  91.180  240.0  4147240.50
# 2019-02-01  128013  90.681  91.180  91.190  90.681  496.0  5599882.00
# 2019-01-31  128013  90.699  90.645  90.737  90.604   27.0  2514372.75

# %%
hongtao['date'] = hongtao.index
hongtao['volume'] = hongtao['vol']*100
Candle_hongtao = Candle.Candle_plot(hongtao, stadate, enddate)

# %%
cbtd.hongtao_CB_TD.tail()
# Out:
#          发生日期    业务名称    证券代码  证券名称    成交均价  成交数量    成交金额  股份余额    手续费  \
# 48 2018-05-28  证券买入清算  128013  洪涛转债  89.991    10  899.91   420   0.18
# 49 2018-05-30  证券买入清算  128013  洪涛转债  88.010    10  880.10   430   0.18
# 50 2018-07-25  证券卖出清算  128013  洪涛转债  89.720   -10  897.20   420   0.18
# 51 2018-07-27    债券兑息  128013  洪涛转债   0.000     0  252.00   420  50.40
# 52 2019-02-12  证券卖出清算  128013  洪涛转债  92.158   -10  921.58   410   0.18
#
#       发生金额       成本    到期本息   到期利率%  到期年化%
# 48 -900.09  101.545  110.32  22.590  5.417
# 49 -880.28  101.230  110.32  25.349  6.087
# 50  897.02  101.505    0.00   0.000  0.000
# 51  201.60  101.025    0.00   0.000  0.000
# 52  921.40  101.241    0.00   0.000  0.000

# %%
cbtd.hongtao_CB_TD_cost
# Out:
#           持仓金额   成交数量     持仓成本         起息日    剩余年限    证券代码    成交金额  买卖数量  \
# 洪涛转债  41508.97  410.0  101.241  2016-07-29  3年166天  128013  92.158   -10
#
#            交易时间    到期本息  到期利率%  到期年化%  锁仓张数
# 洪涛转债 2019-02-12  109.84  8.493  2.456    20

# %% [markdown]
# ### 航信转债110031

# %%
cbtd.hangxin_CB_TD_cost
# Out:
#         持仓金额  成交数量  持仓成本         起息日    剩余年限    证券代码    成交金额  买卖数量       交易时间  \
# 航信转债 -540.34   0.0     0  2015-06-12  2年117天  110031  108.56   -30 2019-01-25
#
#        到期本息  到期利率%  到期年化%  锁仓张数
# 航信转债  108.0      0      0   0.0

# %% [markdown]
# ### 海印转债127003

# %%
haiyin = ts.bar('127003', conn=cons)
haiyin.head()
# Out:
#               code    open   close    high     low    vol        amount
# datetime
# 2019-02-13  127003  94.050  94.000  94.075  93.910  776.0  1.118859e+06
# 2019-02-12  127003  93.350  94.050  94.080  93.350  116.0  1.092829e+07
# 2019-02-11  127003  93.259  93.478  93.500  93.106   95.0  8.900569e+06
# 2019-02-01  127003  92.897  93.220  93.300  92.897   99.0  9.296915e+06
# 2019-01-31  127003  92.918  92.897  93.139  92.811   70.0  6.536502e+06

# %%
haiyin['date'] = haiyin.index
haiyin['volume'] = haiyin['vol']*100
Candle_haiyin = Candle.Candle_plot(haiyin, stadate, enddate)

# %%
cbtd.haiyin_CB_TD.tail(10)
# Out:
#          发生日期    业务名称    证券代码  证券名称    成交均价  成交数量    成交金额  股份余额    手续费  \
# 22 2017-11-21  证券买入清算  127003  海印转债  96.135    10  961.35   150   0.19
# 23 2017-11-24  证券买入清算  127003  海印转债  95.788    10  957.88   160   0.19
# 24 2017-12-07  证券买入清算  127003  海印转债  93.730    10  937.30   170   0.19
# 25 2018-01-25  证券卖出清算  127003  海印转债  94.265   -10  942.65   160   0.19
# 26 2018-02-09  证券买入清算  127003  海印转债  93.000    10  930.00   170   0.19
# 27 2018-05-14  证券买入清算  127003  海印转债  91.800    10  918.00   180   0.18
# 28 2018-05-28  证券买入清算  127003  海印转债  89.998    10  899.98   190   0.18
# 29 2018-06-07    债券兑息  127003  海印转债   0.000     0  133.00   190  26.60
# 30 2018-07-25  证券卖出清算  127003  海印转债  91.330   -10  913.30   180   0.18
# 31 2018-07-26  证券卖出清算  127003  海印转债  92.362   -10  923.62   170   0.18
#
#       发生金额       成本   到期本息   到期利率%  到期年化%
# 22 -961.54  100.577  112.0  16.503  3.631
# 23 -958.07  100.279  112.0  16.925  3.730
# 24 -937.49   99.895  112.0  19.492  4.330
# 25  942.46  100.248    0.0   0.000  0.000
# 26 -930.19   99.822  112.0  20.430  4.723
# 27 -918.18   99.378  112.0  22.004  5.408
# 28 -900.16   98.885  112.0  24.447  6.066
# 29  106.40   98.325    0.0   0.000  0.000
# 30  913.12   98.715    0.0   0.000  0.000
# 31  923.44   99.089    0.0   0.000  0.000

# %%
cbtd.haiyin_CB_TD_cost
# Out:
#           持仓金额   成交数量    持仓成本         起息日    剩余年限    证券代码    成交金额  买卖数量  \
# 海印转债  16845.18  170.0  99.089  2016-06-08  3年114天  127003  92.362   -10
#
#            交易时间    到期本息   到期利率%  到期年化%  锁仓张数
# 海印转债 2018-07-26  111.44  12.464  3.222    20

# %% [markdown]
# ### 光大转债113011

# %%
cbtd.guangda_CB_TD_cost
# Out:
#        持仓金额  成交数量  持仓成本         起息日   剩余年限    证券代码    成交金额  买卖数量       交易时间  \
# 光大转债 -283.3   0.0     0  2017-03-17  4年31天  113011  110.95   -10 2017-07-17
#
#        到期本息  到期利率%  到期年化%  锁仓张数
# 光大转债  108.0      0      0   0.0

# %% [markdown]
# ### 模塑转债127004

# %%
mosu = ts.bar('127004', conn=cons)
mosu.head()
# Out:
#               code    open   close    high     low    vol      amount
# datetime
# 2019-02-13  127004  90.180  89.897  90.180  89.600  320.0   4516611.5
# 2019-02-12  127004  89.310  90.180  90.380  89.310  454.0  40932296.0
# 2019-02-11  127004  88.431  89.155  89.220  88.350   72.0   6420718.5
# 2019-02-01  127004  87.900  88.360  88.481  87.900  123.0  10863388.0
# 2019-01-31  127004  88.300  87.997  88.300  87.818   75.0   6614613.0

# %%
mosu['date'] = mosu.index
mosu['volume'] = mosu['vol']*100
Candle_mosu = Candle.Candle_plot(mosu, stadate, enddate)

# %%
cbtd.mosu_CB_TD.tail()
# Out:
#          发生日期    业务名称    证券代码  证券名称    成交均价  成交数量     成交金额  股份余额    手续费  \
# 8  2017-11-29  证券买入清算  127004  模塑转债  97.050    20  1941.00   110   0.39
# 9  2017-12-07  证券买入清算  127004  模塑转债  93.988    10   939.88   120   0.19
# 10 2018-01-25  证券卖出清算  127004  模塑转债  96.582   -10   965.82   110   0.19
# 11 2018-05-28  证券买入清算  127004  模塑转债  90.900    10   909.00   120   0.18
# 12 2018-06-01    债券兑息  127004  模塑转债   0.000     0    60.00   120  12.00
#
#        发生金额       成本   到期本息   到期利率%  到期年化%
# 8  -1941.39  101.996  112.4  15.817  2.872
# 9   -940.07  101.330  112.4  19.590  3.572
# 10   965.63  101.764    0.0   0.000  0.000
# 11  -909.18  100.860  112.4  23.652  4.718
# 12    48.00  100.460    0.0   0.000  0.000

# %%
cbtd.mosu_CB_TD_cost
# Out:
#           持仓金额   成交数量    持仓成本         起息日    剩余年限    证券代码  成交金额  买卖数量  \
# 模塑转债  12055.18  120.0  100.46  2017-06-02  4年109天  127004   0.0     0
#
#            交易时间   到期本息   到期利率%  到期年化%  锁仓张数
# 模塑转债 2018-06-01  112.4  11.886  2.376   0.0

# %% [markdown]
# ### 江南转债113010

# %%
cbtd.jiangnan_CB_TD_cost
# Out:
#       持仓金额  成交数量  持仓成本         起息日   剩余年限    证券代码    成交金额  买卖数量       交易时间  \
# 江南转债 -40.6   0.0     0  2016-03-18  3年33天  113010  105.54   -20 2018-11-05
#
#         到期本息  到期利率%  到期年化%  锁仓张数
# 江南转债  109.84      0      0   0.0

# %% [markdown]
# ### 电气转债113008

# %%
cbtd.dianqi_CB_TD_cost
# Out:
#        持仓金额  成交数量  持仓成本         起息日    剩余年限    证券代码   成交金额  买卖数量       交易时间  \
# 电气转债 -170.8   0.0     0  2015-02-02  1年352天  113008  105.5   -40 2018-11-19
#
#         到期本息  到期利率%  到期年化%  锁仓张数
# 电气转债  107.68      0      0   0.0

# %% [markdown]
# ### 格力转债110030

# %%
geli = ts.bar('110030', conn=cons)
geli['date'] = geli.index
geli['volume'] = geli['vol']*100
Candle_geli = Candle.Candle_plot(geli, stadate, enddate)

# %%
cbtd.geli_CB_TD.tail()
# Out:
#         发生日期    业务名称    证券代码  证券名称    成交均价  成交数量    成交金额  股份余额  手续费    发生金额  \
# 2 2017-12-27  证券买入清算  110030  格力转债  104.89    10  1048.9    30  1.0 -1049.9
# 3 2017-12-28    债券兑息  110030  格力转债    0.00     0    20.0    30  4.0    16.0
# 4 2018-01-25  证券卖出清算  110030  格力转债  111.03   -10  1110.3    20  1.0  1109.3
# 5 2018-02-07  证券买入清算  110030  格力转债  106.50    10  1065.0    30  1.0 -1066.0
# 6 2018-12-28    债券兑息  110030  格力转债    0.00     0    45.0    30  9.0    36.0
#
#         成本   到期本息  到期利率%  到期年化%
# 2  106.383  106.0  1.058  0.531
# 3  105.850    0.0  0.000  0.000
# 4  103.310    0.0  0.000  0.000
# 5  104.407  106.0 -0.469 -0.250
# 6  103.207    0.0  0.000  0.000

# %%
cbtd.geli_CB_TD_cost
# Out:
#         持仓金额  成交数量     持仓成本         起息日    剩余年限    证券代码  成交金额  买卖数量  \
# 格力转债  3096.2  30.0  103.207  2014-12-25  1年314天  110030   0.0     0
#
#            交易时间   到期本息  到期利率%  到期年化%  锁仓张数
# 格力转债 2018-12-28  104.8  1.544  1.561   0.0

# %% [markdown]
# ### 久其转债128015

# %%
cbtd.jiuqi_CB_TD_cost
# Out:
#        持仓金额  成交数量  持仓成本         起息日    剩余年限    证券代码     成交金额  买卖数量       交易时间  \
# 久其转债 -54.07   0.0     0  2017-06-08  4年114天  128015  100.097   -10 2018-02-14
#
#         到期本息  到期利率%  到期年化%  锁仓张数
# 久其转债  110.08      0      0   0.0

# %% [markdown]
# ### 嘉澳转债113502

# %%
cbtd.jiaao_CB_TD_cost
# Out:
#       持仓金额  成交数量  持仓成本         起息日    剩余年限    证券代码  成交金额  买卖数量       交易时间  \
# 嘉澳转债 -38.7   0.0     0  2017-11-10  4年270天  113502  96.2   -20 2019-02-12
#
#         到期本息  到期利率%  到期年化%  锁仓张数
# 嘉澳转债  110.32      0      0   0.0

# %% [markdown]
# ### 小康转债113016

# %%
cbtd.xiaokang_CB_TD_cost
# Out:
#       持仓金额  成交数量  持仓成本         起息日    剩余年限    证券代码   成交金额  买卖数量       交易时间  \
# 小康转债 -59.9   0.0     0  2017-11-06  4年265天  113016  98.52   -10 2018-03-06
#
#         到期本息  到期利率%  到期年化%  锁仓张数
# 小康转债  108.88      0      0   0.0

# %% [markdown]
# ### 时达转债128018

# %%
shida = ts.bar('128018', conn=cons)
shida.head()
# Out:
#               code    open  close    high    low     vol     amount
# datetime
# 2019-02-13  128018  90.000  90.15  90.299  89.81  1288.0  1213320.0
# 2019-02-12  128018  89.500  90.00  90.249  89.50    90.0  8110098.0
# 2019-02-11  128018  89.023  89.50  89.510  88.93    81.0  7289261.0
# 2019-02-01  128018  88.140  88.93  89.034  88.14    31.0  2805657.5
# 2019-01-31  128018  87.820  88.14  88.259  87.80    74.0  6551916.5

# %%
shida['date'] = shida.index
shida['volume'] = shida['vol']*100
Candle_shida = Candle.Candle_plot(shida, stadate, enddate)

# %%
cbtd.shida_CB_TD.tail(10)
# Out:
#          发生日期    业务名称    证券代码  证券名称    成交均价  成交数量    成交金额  股份余额   手续费    发生金额  \
# 2  2018-02-06  证券买入清算  128018  时达转债  94.980    10  949.80    10  0.19 -949.99
# 3  2018-03-13  证券卖出清算  128018  时达转债  96.650   -10  966.50     0  0.19  966.31
# 4  2018-03-23  证券买入清算  128018  时达转债  94.711    10  947.11    10  0.19 -947.30
# 5  2018-03-29  证券卖出清算  128018  时达转债  95.300   -10  953.00     0  0.19  952.81
# 6  2018-04-24  证券买入清算  128018  时达转债  93.628    10  936.28    10  0.19 -936.47
# 7  2018-04-26  证券买入清算  128018  时达转债  92.611    10  926.11    20  0.19 -926.30
# 8  2018-05-28  证券买入清算  128018  时达转债  90.800    10  908.00    30  0.18 -908.18
# 9  2018-06-05  证券买入清算  128018  时达转债  87.603    10  876.03    40  0.18 -876.21
# 10 2018-07-20  证券卖出清算  128018  时达转债  89.515   -10  895.15    30  0.18  894.97
# 11 2018-11-05    债券兑息  128018  时达转债   0.000     0    9.00    30  1.80    7.20
#
#         成本    到期本息   到期利率%  到期年化%
# 2   93.323  108.88  14.635  2.546
# 3    0.000    0.00   0.000  0.000
# 4   91.422  108.88  14.960  2.660
# 5    0.000    0.00   0.000  0.000
# 6   89.788  108.88  16.290  2.942
# 7   91.209  108.88  17.567  3.176
# 8   91.079  108.88  19.912  3.658
# 9   90.214  108.88  24.288  4.480
# 10  90.453    0.00   0.000  0.000
# 11  90.213    0.00   0.000  0.000

# %%
cbtd.shida_CB_TD_cost
# Out:
#         持仓金额  成交数量    持仓成本         起息日    剩余年限    证券代码  成交金额  买卖数量       交易时间  \
# 时达转债  2706.4  30.0  90.213  2017-11-06  4年265天  128018   0.0     0 2018-11-05
#
#         到期本息   到期利率%  到期年化%  锁仓张数
# 时达转债  108.88  20.692  4.136   0.0

# %% [markdown]
# ### 骆驼转债113012

# %%
cbtd.luotuo_CB_TD_cost
# Out:
#       持仓金额  成交数量  持仓成本         起息日   剩余年限    证券代码   成交金额  买卖数量       交易时间  \
# 骆驼转债 -42.8   0.0     0  2017-03-24  4年38天  113012  98.68   -10 2018-03-09
#
#         到期本息  到期利率%  到期年化%  锁仓张数
# 骆驼转债  107.68      0      0   0.0

# %% [markdown]
# ### 蒙电转债110041

# %%
cbtd.mengdian_CB_TD_cost
# Out:
#       持仓金额  成交数量  持仓成本         起息日    剩余年限    证券代码    成交金额  买卖数量       交易时间  \
# 蒙电转债 -64.6   0.0     0  2017-12-22  4年312天  110041  100.51   -10 2018-02-13
#
#         到期本息  到期利率%  到期年化%  锁仓张数
# 蒙电转债  109.04      0      0   0.0

# %% [markdown]
# ### 吉视转债113017

# %%
cbtd.jishi_CB_TD_cost
# Out:
#       持仓金额  成交数量  持仓成本         起息日    剩余年限    证券代码   成交金额  买卖数量       交易时间  \
# 吉视转债 -24.2   0.0     0  2017-12-27  4年317天  113017  96.86   -20 2019-02-12
#
#         到期本息  到期利率%  到期年化%  锁仓张数
# 吉视转债  108.24      0      0   0.0

# %% [markdown]
# ### 迪龙转债128033

# %%
cbtd.dilong_CB_TD_cost
# Out:
#        持仓金额  成交数量  持仓成本         起息日    剩余年限    证券代码    成交金额  买卖数量       交易时间  \
# 迪龙转债 -182.2   0.0     0  2017-12-27  4年317天  128033  99.099   -10 2018-07-26
#
#         到期本息  到期利率%  到期年化%  锁仓张数
# 迪龙转债  108.48      0      0   0.0

# %% [markdown]
# ### 永东转债128014

# %%
cbtd.yongdong_CB_TD_cost
# Out:
#        持仓金额  成交数量  持仓成本         起息日   剩余年限    证券代码    成交金额  买卖数量       交易时间  \
# 永东转债 -50.05   0.0     0  2017-04-17  4年63天  128014  96.749   -10 2019-02-12
#
#        到期本息  到期利率%  到期年化%  锁仓张数
# 永东转债  110.4      0      0   0.0

# %% [markdown]
# ### 众兴转债128026

# %%
zhongxing = ts.bar('128026', conn=cons)
zhongxing.head()
# Out:
#               code    open   close    high     low    vol       amount
# datetime
# 2019-02-13  128026  90.771  90.769  90.772  90.350   24.0  2218885.750
# 2019-02-12  128026  89.985  90.770  90.770  89.985  544.0  5835460.000
# 2019-02-11  128026  89.255  89.990  90.100  89.255   80.0  3182810.500
# 2019-02-01  128026  88.303  89.255  89.485  88.303   23.0  2083286.875
# 2019-01-31  128026  88.665  88.303  88.700  88.200   64.0  3037013.250

# %%
zhongxing['date'] = zhongxing.index
zhongxing['volume'] = zhongxing['vol']*100
Candle_zhongxing = Candle.Candle_plot(zhongxing, stadate, enddate)

# %%
cbtd.zhongxing_CB_TD.tail()
# Out:
#         发生日期    业务名称    证券代码  证券名称   成交均价  成交数量   成交金额  股份余额   手续费    发生金额  \
# 0 2018-02-06  证券买入清算  128026  众兴转债  95.56    10  955.6    10  0.19 -955.79
# 1 2018-03-13  证券卖出清算  128026  众兴转债  97.00   -10  970.0     0  0.19  969.81
# 2 2018-04-20  证券买入清算  128026  众兴转债  95.00    10  950.0    10  0.19 -950.19
# 3 2018-12-12    债券兑息  128026  众兴转债   0.00     0    4.0    10  0.00    4.00
#
#        成本    到期本息   到期利率%  到期年化%
# 0  95.579  109.04  14.106  2.412
# 1   0.000    0.00   0.000  0.000
# 2  93.617  109.04  14.779  2.616
# 3  93.217    0.00   0.000  0.000

# %%
cbtd.zhongxing_CB_TD_cost
# Out:
#         持仓金额  成交数量    持仓成本         起息日    剩余年限    证券代码  成交金额  买卖数量       交易时间  \
# 众兴转债  932.17  10.0  93.217  2017-12-13  4年303天  128026   0.0     0 2018-12-12
#
#         到期本息   到期利率%  到期年化%  锁仓张数
# 众兴转债  109.04  16.974  3.393   0.0

# %% [markdown]
# ### 水晶转债128020

# %%
cbtd.shuijing_CB_TD_cost
# Out:
#        持仓金额  成交数量  持仓成本         起息日    剩余年限    证券代码  成交金额  买卖数量       交易时间  \
# 水晶转债 -61.67   0.0     0  2017-11-17  4年277天  128020  96.4   -10 2018-05-02
#
#         到期本息  到期利率%  到期年化%  锁仓张数
# 水晶转债  109.52      0      0   0.0

# %% [markdown]
# ### 亚太转债128023

# %%
yatai = ts.bar('128023', conn=cons)
yatai.head()
# Out:
#               code    open   close    high     low     vol        amount
# datetime
# 2019-02-13  128023  90.962  91.000  91.140  90.951  8194.0  4.208008e+05
# 2019-02-12  128023  90.421  90.962  91.000  90.421   416.0  5.106146e+06
# 2019-02-11  128023  90.399  90.667  90.700  90.300    24.0  2.260600e+06
# 2019-02-01  128023  89.780  90.400  90.550  89.780    20.0  1.838893e+06
# 2019-01-31  128023  90.000  90.000  90.002  89.668  2056.0  1.505755e+06

# %%
yatai['date'] = yatai.index
yatai['volume'] = yatai['vol']*100
Candle_yatai = Candle.Candle_plot(yatai, stadate, enddate)

# %%
cbtd.yatai_CB_TD.tail()
# Out:
#         发生日期    业务名称    证券代码  证券名称    成交均价  成交数量    成交金额  股份余额   手续费    发生金额  \
# 0 2018-02-08  证券买入清算  128023  亚太转债  94.202    10  942.02    10  0.19 -942.21
# 1 2018-02-09  证券买入清算  128023  亚太转债  93.210    10  932.10    20  0.19 -932.29
# 2 2018-12-03    债券兑息  128023  亚太转债   0.000     0    6.00    20  1.20    4.80
#
#        成本    到期本息   到期利率%  到期年化%
# 0  94.221  110.48  17.280  2.969
# 1  93.725  110.48  18.528  3.185
# 2  93.485    0.00   0.000  0.000

# %%
cbtd.yatai_CB_TD_cost
# Out:
#         持仓金额  成交数量    持仓成本         起息日    剩余年限    证券代码  成交金额  买卖数量       交易时间  \
# 亚太转债  1869.7  20.0  93.485  2017-12-04  4年294天  128023   0.0     0 2018-12-03
#
#         到期本息   到期利率%  到期年化%  锁仓张数
# 亚太转债  110.48  18.179  3.634   0.0

# %% [markdown]
# ### 久立转2128019

# %%
cbtd.jiuli_CB_TD_cost
# Out:
#       持仓金额  成交数量  持仓成本         起息日    剩余年限    证券代码  成交金额  买卖数量       交易时间  \
# 久立转2 -40.5   0.0     0  2017-11-08  4年268天  128019  99.0   -10 2018-03-13
#
#         到期本息  到期利率%  到期年化%  锁仓张数
# 久立转2  108.48      0      0   0.0

# %% [markdown]
# ### 双环转债128032

# %%
cbtd.shuanghuan_CB_TD_cost
# Out:
#        持仓金额  成交数量  持仓成本         起息日    剩余年限    证券代码    成交金额  买卖数量       交易时间  \
# 双环转债 -72.22   0.0     0  2017-12-25  4年315天  128032  104.61   -10 2018-03-13
#
#         到期本息  到期利率%  到期年化%  锁仓张数
# 双环转债  108.88      0      0   0.0

# %% [markdown]
# ### 江银转债128034

# %%
cbtd.jiangyin_CB_TD_cost
# Out:
#        持仓金额  成交数量  持仓成本         起息日    剩余年限    证券代码     成交金额  买卖数量       交易时间  \
# 江银转债 -134.5   0.0     0  2018-01-26  4年347天  128034  100.963   -10 2018-08-30
#
#         到期本息  到期利率%  到期年化%  锁仓张数
# 江银转债  107.92      0      0   0.0

# %% [markdown]
# ### 无锡转债110043

# %%
cbtd.wuxi_CB_TD_cost
# Out:
#       持仓金额  成交数量  持仓成本         起息日    剩余年限    证券代码    成交金额  买卖数量       交易时间  \
# 无锡转债 -52.5   0.0     0  2018-01-30  4年351天  110043  100.42   -10 2018-11-19
#
#         到期本息  到期利率%  到期年化%  锁仓张数
# 无锡转债  107.92      0      0   0.0

# %% [markdown]
# ### 金农转债128036

# %%
cbtd.jinnong_CB_TD_cost
# Out:
#        持仓金额  成交数量  持仓成本         起息日   剩余年限    证券代码    成交金额  买卖数量       交易时间  \
# 金农转债 -13.15   0.0     0  2018-03-09  5年23天  128036  97.353   -10 2018-05-07
#
#         到期本息  到期利率%  到期年化%  锁仓张数
# 金农转债  109.04      0      0   0.0

# %% [markdown]
# ### 岩土转债128037

# %%
yantu = ts.bar('128037', conn=cons)
yantu.head()
# Out:
#               code    open   close    high     low    vol       amount
# datetime
# 2019-02-13  128037  91.018  91.072  91.080  90.952    7.0   641007.625
# 2019-02-12  128037  90.803  91.010  91.180  90.753  528.0  5764959.000
# 2019-02-11  128037  90.300  90.803  90.927  90.300   64.0  3172326.000
# 2019-02-01  128037  89.900  90.420  90.420  89.900   18.0  1664114.875
# 2019-01-31  128037  89.812  89.910  90.150  89.812   18.0  1623130.625

# %%
yantu['date'] = yantu.index
yantu['volume'] = yantu['vol']*100
Candle_yantu = Candle.Candle_plot(yantu, stadate, enddate)

# %%
cbtd.yantu_CB_TD.tail()
# Out:
#         发生日期    业务名称    证券代码  证券名称   成交均价  成交数量   成交金额  股份余额   手续费    发生金额  \
# 0 2018-05-30  证券买入清算  128037  岩土转债  91.92    10  919.2    10  0.18 -919.38
#
#        成本    到期本息   到期利率%  到期年化%
# 0  91.938  110.48  20.191  3.486

# %%
cbtd.yantu_CB_TD_cost
# Out:
#         持仓金额  成交数量    持仓成本         起息日   剩余年限    证券代码   成交金额  买卖数量       交易时间  \
# 岩土转债  919.38  10.0  91.938  2018-03-15  5年30天  128037  91.92    10 2018-05-30
#
#         到期本息   到期利率%  到期年化%  锁仓张数
# 岩土转债  110.48  20.168  3.482   0.0

# %%
#关闭连接
ts.close_apis(cons)
