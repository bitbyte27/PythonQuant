# %% [markdown]
# ## CB_Transaction_Data_PLOT_F（2019-2-13）

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# [持仓明细表](#持仓明细表)

# %%
import CB_Transaction_Functions

# %% [markdown]
# [蓝标转债](#蓝标转债123001)、[辉丰转债](#辉丰转债128012)、[洪涛转债](#洪涛转债128013)、[航信转债](#航信转债110031)、[海印转债](#海印转债127003)、[光大转债](#光大转债113011)、[模塑转债](#模塑转债127004)、[江南转债](#江南转债113010)、[电气转债](#电气转债113008)、[格力转债](#格力转债110030)、[久其转债](#久其转债128015)、[嘉澳转债](#嘉澳转债113502)、[小康转债](#小康转债113016)、[时达转债](#时达转债128018)、[骆驼转债](#骆驼转债113012)、[蒙电转债](#蒙电转债110041)、[吉视转债](#吉视转债113017)、[迪龙转债](#迪龙转债128033)、[永东转债](#永东转债128014)、[众兴转债](#众兴转债128026)、[水晶转债](#水晶转债128020)、[亚太转债](#亚太转债128023)、[久立转2](#久立转2128019)、[双环转债](#双环转债128032)、[江银转债](#江银转债128034)、[无锡转债](#无锡转债110043)、[金农转债](#金农转债128036)、[岩土转债](#岩土转债128037)

# %% [markdown]
# ### 蓝标转债123001
# * [蓝色光标可转债综合信息库](https://github.com/bitbyte27/PythonQuant/blob/master/ConvertibleBond/CB_specification/01.%E8%93%9D%E8%89%B2%E5%85%89%E6%A0%87%E5%8F%AF%E8%BD%AC%E5%80%BA123001.md)

# %%
lanbiao = u'蓝标转债'
lanbiao_date = '2015-12-18'
lanbiao_rate = [8.0, 1.8, 1.5, 1.0, 0.7, 0.5]

# %%
lanbiao_CB_TD = CB_Transaction_Functions.CB_Transaction_Data(lanbiao,lanbiao_date,lanbiao_rate)
lanbiao_CB_TD_sort = lanbiao_CB_TD.loc[lanbiao_CB_TD[u'成交数量']>0,:]
lanbiao_CB_TD_sort.sort_values(by=u'成交均价').head()
lanbiao_CB_TD.tail(1)
# 蓝标回售，斩仓结束！！！
# Out:
#          发生日期    业务名称    证券代码  证券名称   成交均价  成交数量     成交金额  股份余额  手续费     发生金额  \
# 54 2019-01-31  证券卖出清算  123001  蓝标转债  100.2  -100  10020.0     0  2.0  10018.0
#
#      成本  到期本息  到期利率%  到期年化%
# 54  0.0   0.0    0.0    0.0

# %%
lanbiao_CB_TD_cost = CB_Transaction_Functions.CB_TD_cost(lanbiao,lanbiao_CB_TD,lanbiao_date,lanbiao_rate)
lanbiao_CB_TD_cost
# Out:
#         持仓金额  成交数量  持仓成本         起息日    剩余年限    证券代码   成交金额  买卖数量       交易时间  \
# 蓝标转债 -102.87   0.0     0  2015-12-18  2年287天  123001  100.2  -100 2019-01-31
#
#         到期本息  到期利率%  到期年化%  锁仓张数
# 蓝标转债  109.04      0      0    30

# %% [markdown]
# ### 辉丰转债128012
# * [辉丰股份可转债综合信息库](https://github.com/bitbyte27/PythonQuant/blob/master/ConvertibleBond/CB_specification/02.%E8%BE%89%E4%B8%B0%E8%82%A1%E4%BB%BD%E5%8F%AF%E8%BD%AC%E5%80%BA128012.md)

# %%
huifeng = u'辉丰转债'
huifeng_date = '2016-04-21'
huifeng_rate = [3.0, 1.3, 1.3, 1.0, 0.7, 0.5]

# %%
huifeng_CB_TD = CB_Transaction_Functions.CB_Transaction_Data(huifeng,huifeng_date,huifeng_rate)
huifeng_CB_TD_sort = huifeng_CB_TD.loc[huifeng_CB_TD[u'成交数量']>0,:]
huifeng_CB_TD_sort.sort_values(by=u'成交均价').head()
# Out:
#          发生日期    业务名称    证券代码  证券名称   成交均价  成交数量   成交金额  股份余额   手续费    发生金额  \
# 54 2018-04-24  证券买入清算  128012  辉丰转债  83.55    10  835.5   170  0.17 -835.67
# 50 2018-04-23  证券买入清算  128012  辉丰转债  86.88    10  868.8   160  0.17 -868.97
# 53 2018-04-23  证券买入清算  128012  辉丰转债  88.21    10  882.1   150  0.18 -882.28
# 52 2018-04-23  证券买入清算  128012  辉丰转债  90.60    10  906.0   140  0.18 -906.18
# 51 2018-04-23  证券买入清算  128012  辉丰转债  90.80    10  908.0   130  0.18 -908.18
#
#          成本    到期本息   到期利率%  到期年化%
# 54   94.956  105.28  26.008  6.515
# 50   78.814  105.28  21.179  5.302
# 53  102.045  105.28  19.352  4.845
# 52  103.032  105.28  16.203  4.056
# 51  103.987  105.28  15.947  3.992

# %%
huifeng_CB_TD[40:49]
# 99元以上30张。
# Out:
#          发生日期    业务名称    证券代码  证券名称     成交均价  成交数量     成交金额  股份余额   手续费  \
# 40 2017-09-27  证券买入清算  128012  辉丰转债  102.020    10  1020.20    90  0.20
# 41 2017-11-24  证券买入清算  128012  辉丰转债   99.492    10   994.92   100  0.20
# 42 2017-11-29  证券买入清算  128012  辉丰转债   98.118    10   981.18   110  0.20
# 43 2017-12-07  证券买入清算  128012  辉丰转债   94.900    20  1898.00   130  0.38
# 44 2018-01-04  证券卖出清算  128012  辉丰转债   97.060   -20  1941.20   110  0.39
# 45 2018-01-25  证券卖出清算  128012  辉丰转债  102.448   -20  2048.96    90  0.41
# 46 2018-02-08  证券买入清算  128012  辉丰转债   97.332    10   973.32   100  0.19
# 47 2018-02-09  证券买入清算  128012  辉丰转债   96.086    10   960.86   110  0.19
# 48 2018-03-29  证券买入清算  128012  辉丰转债   94.570    10   945.70   120  0.19
#
#        发生金额       成本    到期本息   到期利率%  到期年化%
# 40 -1020.40  100.472  105.84   3.744  0.820
# 41  -995.12  100.376  105.84   6.380  1.448
# 42  -981.38  100.172  105.84   7.870  1.792
# 43 -1898.38   99.364  105.84  11.528  2.638
# ...

# %%
huifeng_CB_TD.tail(8)
# 91元以上卖出50张（2019年2月12日）。
# Out:
#          发生日期    业务名称    证券代码  证券名称   成交均价  成交数量    成交金额  股份余额    手续费  \
# 49 2018-04-20    债券兑息  128012  辉丰转债   0.00     0    84.0   120  16.80
# 50 2018-04-23  证券买入清算  128012  辉丰转债  86.88    10   868.8   160   0.17
# 51 2018-04-23  证券买入清算  128012  辉丰转债  90.80    10   908.0   130   0.18
# 52 2018-04-23  证券买入清算  128012  辉丰转债  90.60    10   906.0   140   0.18
# 53 2018-04-23  证券买入清算  128012  辉丰转债  88.21    10   882.1   150   0.18
# 54 2018-04-24  证券买入清算  128012  辉丰转债  83.55    10   835.5   170   0.17
# 55 2019-02-12  证券卖出清算  128012  辉丰转债  92.88   -30  2786.4   140   0.56
# 56 2019-02-12  证券卖出清算  128012  辉丰转债  92.88   -20  1857.6   120   0.37
#
#        发生金额       成本    到期本息   到期利率%  到期年化%
# 49    67.20   97.843    0.00   0.000  0.000
# 50  -868.97   78.814  105.28  21.179  5.302
# 51  -908.18  103.987  105.28  15.947  3.992
# 52  -906.18  103.032  105.28  16.203  4.056
# 53  -882.28  102.045  105.28  19.352  4.845
# 54  -835.67   94.956  105.28  26.008  6.515
# ...

# %%
huifeng_CB_TD_cost = CB_Transaction_Functions.CB_TD_cost(huifeng,huifeng_CB_TD,huifeng_date,huifeng_rate)
huifeng_CB_TD_cost
# Out:
#           持仓金额   成交数量    持仓成本         起息日   剩余年限    证券代码   成交金额  买卖数量  \
# 辉丰转债  11499.42  120.0  95.828  2016-04-21  3年47天  128012  92.88   -20
#
#            交易时间    到期本息  到期利率%  到期年化%  锁仓张数
# 辉丰转债 2019-02-12  105.28  9.863  3.095    20

# %% [markdown]
# ### 洪涛转债128013
# * [洪涛股份可转债综合信息库](https://github.com/bitbyte27/PythonQuant/blob/master/ConvertibleBond/CB_specification/03.%E6%B4%AA%E6%B6%9B%E8%82%A1%E4%BB%BD%E5%8F%AF%E8%BD%AC%E5%80%BA128013.md)

# %%
hongtao = u'洪涛转债'
hongtao_date = '2016-07-29'
hongtao_rate = [8.0, 1.8, 1.5, 1.0, 0.6, 0.4]

# %%
hongtao_CB_TD = CB_Transaction_Functions.CB_Transaction_Data(hongtao,hongtao_date,hongtao_rate)
hongtao_CB_TD_sort = hongtao_CB_TD.loc[hongtao_CB_TD[u'成交数量']>0,:]
hongtao_CB_TD_sort.sort_values(by=u'成交均价').head()
# Out:
#          发生日期    业务名称    证券代码  证券名称    成交均价  成交数量    成交金额  股份余额   手续费    发生金额  \
# 49 2018-05-30  证券买入清算  128013  洪涛转债  88.010    10  880.10   430  0.18 -880.28
# 48 2018-05-28  证券买入清算  128013  洪涛转债  89.991    10  899.91   420  0.18 -900.09
# 47 2018-05-03  证券买入清算  128013  洪涛转债  91.800    10  918.00   410  0.18 -918.18
# 46 2017-12-07  证券买入清算  128013  洪涛转债  93.279    10  932.79   400  0.19 -932.98
# 45 2017-11-29  证券买入清算  128013  洪涛转债  95.954    10  959.54   390  0.19 -959.73
#
#          成本    到期本息   到期利率%  到期年化%
# 49  101.230  110.32  25.349  6.087
# 48  101.545  110.32  22.590  5.417
# 47  101.826  110.32  20.174  4.760
# 46  102.076  110.32  18.269  3.936
# 45  102.301  110.32  14.972  3.211

# %%
hongtao_CB_TD[40:48]
# 94元以上20张，97.5元以上30张。
# Out:
#          发生日期    业务名称    证券代码  证券名称    成交均价  成交数量     成交金额  股份余额   手续费  \
# 40 2017-11-03  证券买入清算  128013  洪涛转债  99.901    20  1998.02   320  0.40
# 41 2017-11-15  证券买入清算  128013  洪涛转债  98.983    10   989.83   330  0.20
# 42 2017-11-16  证券买入清算  128013  洪涛转债  98.523    10   985.23   340  0.20
# 43 2017-11-21  证券买入清算  128013  洪涛转债  96.070    20  1921.40   380  0.38
# 44 2017-11-21  证券买入清算  128013  洪涛转债  97.010    20  1940.20   360  0.39
# 45 2017-11-29  证券买入清算  128013  洪涛转债  95.954    10   959.54   390  0.19
# 46 2017-12-07  证券买入清算  128013  洪涛转债  93.279    10   932.79   400  0.19
# 47 2018-05-03  证券买入清算  128013  洪涛转债  91.800    10   918.00   410  0.18
#
#        发生金额       成本    到期本息   到期利率%  到期年化%
# 40 -1998.42  103.437  110.32  10.429  2.203
# 41  -990.03  103.303  110.32  11.453  2.436
# 42  -985.43  103.163  110.32  11.974  2.548
# 43 -1921.78   97.361  110.32  14.833  3.166
# 44 -1940.59  108.160  110.32  13.720  2.929
# 45  -959.73  102.301  110.32  14.972  3.211
# ...

# %%
hongtao_CB_TD.tail(5)
# Out:
#          发生日期    业务名称    证券代码  证券名称    成交均价  成交数量    成交金额  股份余额    手续费  \
# 48 2018-05-28  证券买入清算  128013  洪涛转债  89.991    10  899.91   420   0.18
# 49 2018-05-30  证券买入清算  128013  洪涛转债  88.010    10  880.10   430   0.18
# 50 2018-07-25  证券卖出清算  128013  洪涛转债  89.720   -10  897.20   420   0.18
# 51 2018-07-27    债券兑息  128013  洪涛转债   0.000     0  252.00   420  50.40
# 52 2019-02-12  证券卖出清算  128013  洪涛转债  92.158   -10  921.58   410   0.18
#
#       发生金额       成本    到期本息   到期利率%  到期年化%
# 48 -900.09  101.545  110.32  22.590  5.417
# 49 -880.28  101.230  110.32  25.349  6.087
# 50  897.02  101.505    0.00   0.000  0.000
# 51  201.60  101.025    0.00   0.000  0.000
# 52  921.40  101.241    0.00   0.000  0.000

# %%
hongtao_CB_TD_cost = CB_Transaction_Functions.CB_TD_cost(hongtao,hongtao_CB_TD,hongtao_date,hongtao_rate)
hongtao_CB_TD_cost
# Out:
#           持仓金额   成交数量     持仓成本         起息日    剩余年限    证券代码    成交金额  买卖数量  \
# 洪涛转债  41508.97  410.0  101.241  2016-07-29  3年147天  128013  92.158   -10
#
#            交易时间    到期本息  到期利率%  到期年化%  锁仓张数
# 洪涛转债 2019-02-12  109.84  8.493  2.456    20

# %% [markdown]
# ### 航信转债110031

# %%
hangxin = u'航信转债'
hangxin_date = '2015-06-12'
hangxin_rate = [7, 1.5, 1.5, 1.0, 0.5, 0.2]

# %%
hangxin_CB_TD = CB_Transaction_Functions.CB_Transaction_Data(hangxin,hangxin_date,hangxin_rate)
hangxin_CB_TD_sort = hangxin_CB_TD.loc[hangxin_CB_TD[u'成交数量']<>0,:]
hangxin_CB_TD_sort.sort_values(by=u'成交均价').head()
hangxin_CB_TD.tail(2)
# Out:
#          发生日期    业务名称    证券代码  证券名称    成交均价  成交数量    成交金额  股份余额  手续费    发生金额  \
# 32 2018-12-13  证券卖出清算  110031  航信转债  107.79   -30  3233.7    30  1.0  3232.7
# 33 2019-01-25  证券卖出清算  110031  航信转债  108.56   -30  3256.8     0  1.0  3255.8
#
#         成本  到期本息  到期利率%  到期年化%
# 32  90.515   0.0    0.0    0.0
# 33   0.000   0.0    0.0    0.0

# %%
hangxin_CB_TD_cost = CB_Transaction_Functions.CB_TD_cost(hangxin,hangxin_CB_TD,hangxin_date,hangxin_rate)
hangxin_CB_TD_cost
# Out:
#         持仓金额  成交数量  持仓成本         起息日   剩余年限    证券代码    成交金额  买卖数量       交易时间  \
# 航信转债 -540.34   0.0     0  2015-06-12  2年99天  110031  108.56   -30 2019-01-25
#
#        到期本息  到期利率%  到期年化%  锁仓张数
# 航信转债  108.0      0      0   0.0

# %% [markdown]
# ### 海印转债127003

# %%
haiyin = u'海印转债'
haiyin_date = '2016-06-08'
haiyin_rate = [10.0, 1.8, 1.5, 1.0, 0.7, 0.5]

# %%
haiyin_CB_TD = CB_Transaction_Functions.CB_Transaction_Data(haiyin,haiyin_date,haiyin_rate)
haiyin_CB_TD_sort = haiyin_CB_TD.loc[haiyin_CB_TD[u'成交数量']>0,:]
haiyin_CB_TD_sort.sort_values(by=u'成交均价').head()
# Out:
#          发生日期    业务名称    证券代码  证券名称    成交均价  成交数量    成交金额  股份余额   手续费    发生金额  \
# 28 2018-05-28  证券买入清算  127003  海印转债  89.998    10  899.98   190  0.18 -900.16
# 27 2018-05-14  证券买入清算  127003  海印转债  91.800    10  918.00   180  0.18 -918.18
# 26 2018-02-09  证券买入清算  127003  海印转债  93.000    10  930.00   170  0.19 -930.19
# 24 2017-12-07  证券买入清算  127003  海印转债  93.730    10  937.30   170  0.19 -937.49
# 23 2017-11-24  证券买入清算  127003  海印转债  95.788    10  957.88   160  0.19 -958.07
#
#          成本   到期本息   到期利率%  到期年化%
# 28   98.885  112.0  24.447  6.066
# 27   99.378  112.0  22.004  5.408
# 26   99.822  112.0  20.430  4.723
# 24   99.895  112.0  19.492  4.330
# 23  100.279  112.0  16.925  3.730

# %%
haiyin_CB_TD[10:22]
# 100元卖30张，102元卖40张，104元买30张，105元卖10张，108元清仓。
# Out:
#          发生日期    业务名称    证券代码  证券名称     成交均价  成交数量     成交金额  股份余额   手续费  \
# 10 2017-08-11  证券买入清算  127003  海印转债  103.450    10  1034.50    30  0.21
# 11 2017-09-25  证券买入清算  127003  海印转债  102.400    10  1024.00    40  0.20
# 12 2017-09-25  证券买入清算  127003  海印转债  101.980    10  1019.80    50  0.20
# 13 2017-09-26  证券买入清算  127003  海印转债  101.431    10  1014.31    60  0.20
# 14 2017-10-26  证券买入清算  127003  海印转债  100.940    10  1009.40    70  0.20
# 15 2017-10-27  证券买入清算  127003  海印转债  100.780    10  1007.80    80  0.20
# 16 2017-10-30  证券买入清算  127003  海印转债  100.422    10  1004.22    90  0.20
# 17 2017-10-31  证券买入清算  127003  海印转债  100.020    10  1000.20   100  0.20
# 18 2017-11-02  证券买入清算  127003  海印转债   99.983    10   999.83   110  0.20
# 19 2017-11-15  证券买入清算  127003  海印转债   98.949    10   989.49   120  0.20
# 20 2017-11-17  证券买入清算  127003  海印转债   98.400    10   984.00   130  0.20
# 21 2017-11-21  证券买入清算  127003  海印转债   97.010    10   970.10   140  0.19
#
# ...

# %%
haiyin_CB_TD.tail(12)
# 94元以上可卖出1张，97元以上卖出2张。(2019-2-19，2019-3-1)
# Out:
#          发生日期    业务名称    证券代码  证券名称    成交均价  成交数量     成交金额  股份余额    手续费  \
# 22 2017-11-21  证券买入清算  127003  海印转债  96.135    10   961.35   150   0.19
# 23 2017-11-24  证券买入清算  127003  海印转债  95.788    10   957.88   160   0.19
# 24 2017-12-07  证券买入清算  127003  海印转债  93.730    10   937.30   170   0.19
# 25 2018-01-25  证券卖出清算  127003  海印转债  94.265   -10   942.65   160   0.19
# 26 2018-02-09  证券买入清算  127003  海印转债  93.000    10   930.00   170   0.19
# 27 2018-05-14  证券买入清算  127003  海印转债  91.800    10   918.00   180   0.18
# 28 2018-05-28  证券买入清算  127003  海印转债  89.998    10   899.98   190   0.18
# 29 2018-06-07    债券兑息  127003  海印转债   0.000     0   133.00   190  26.60
# 30 2018-07-25  证券卖出清算  127003  海印转债  91.330   -10   913.30   180   0.18
# 31 2018-07-26  证券卖出清算  127003  海印转债  92.362   -10   923.62   170   0.18
# 32 2019-02-19  证券卖出清算  127003  海印转债  95.382   -10   953.82   160   0.19
# 33 2019-03-01  证券卖出清算  127003  海印转债  97.980   -20  1959.60   140   0.39
#
# ...

# %%
haiyin_CB_TD_cost = CB_Transaction_Functions.CB_TD_cost(haiyin,haiyin_CB_TD,haiyin_date,haiyin_rate)
haiyin_CB_TD_cost
# Out:
#           持仓金额   成交数量    持仓成本         起息日   剩余年限    证券代码   成交金额  买卖数量  \
# 海印转债  13932.34  140.0  99.517  2016-06-08  3年95天  127003  97.98   -20
#
#            交易时间    到期本息   到期利率%  到期年化%  锁仓张数
# 海印转债 2019-03-01  111.44  11.981  3.663    20

# %% [markdown]
# ### 光大转债113011

# %%
guangda = u'光大转债'
guangda_date = '2017-03-17'
guangda_rate = [5.0, 1.8, 1.5, 1.0, 0.5, 0.2]

# %%
guangda_CB_TD = CB_Transaction_Functions.CB_Transaction_Data(guangda,guangda_date,guangda_rate)
guangda_CB_TD.tail(1)
# Out:
#         发生日期    业务名称    证券代码  证券名称    成交均价  成交数量    成交金额  股份余额  手续费    发生金额  \
# 6 2017-07-17  证券卖出清算  113011  光大转债  110.95   -10  1109.5     0  1.0  1108.5
#
#     成本  到期本息  到期利率%  到期年化%
# 6  0.0   0.0    0.0    0.0

# %%
guangda_CB_TD_cost = CB_Transaction_Functions.CB_TD_cost(guangda,guangda_CB_TD,guangda_date,guangda_rate)
guangda_CB_TD_cost
# Out:
#        持仓金额  成交数量  持仓成本         起息日   剩余年限    证券代码    成交金额  买卖数量       交易时间  \
# 光大转债 -283.3   0.0     0  2017-03-17  4年13天  113011  110.95   -10 2017-07-17
#
#        到期本息  到期利率%  到期年化%  锁仓张数
# 光大转债  108.0      0      0   0.0

# %% [markdown]
# ### 模塑转债127004

# %%
mosu = u'模塑转债'
mosu_date = '2017-06-02'
mosu_rate = [10.0, 1.8, 1.5, 1.0, 0.7, 0.5]

# %%
mosu_CB_TD = CB_Transaction_Functions.CB_Transaction_Data(mosu,mosu_date,mosu_rate)
mosu_CB_TD
# Out:
#          发生日期    业务名称    证券代码  证券名称     成交均价  成交数量     成交金额  股份余额    手续费  \
# 0  2017-10-30  证券买入清算  127004  模塑转债  106.201    10  1062.01    10   0.21
# 1  2017-10-31  证券买入清算  127004  模塑转债  105.861    10  1058.61    20   0.21
# 2  2017-11-02  证券买入清算  127004  模塑转债  105.015    10  1050.15    30   0.21
# 3  2017-11-03  证券买入清算  127004  模塑转债  104.301    10  1043.01    40   0.21
# 4  2017-11-06  证券买入清算  127004  模塑转债  103.467    10  1034.67    50   0.21
# 5  2017-11-07  证券买入清算  127004  模塑转债  101.920    20  2038.40    70   0.41
# 6  2017-11-24  证券买入清算  127004  模塑转债   99.974    10   999.74    80   0.20
# 7  2017-11-27  证券买入清算  127004  模塑转债   98.972    10   989.72    90   0.20
# 8  2017-11-29  证券买入清算  127004  模塑转债   97.050    20  1941.00   110   0.39
# 9  2017-12-07  证券买入清算  127004  模塑转债   93.988    10   939.88   120   0.19
# 10 2018-01-25  证券卖出清算  127004  模塑转债   96.582   -10   965.82   110   0.19
# 11 2018-05-28  证券买入清算  127004  模塑转债   90.900    10   909.00   120   0.18
# ...

# %%
mosu_CB_TD_cost = CB_Transaction_Functions.CB_TD_cost(mosu,mosu_CB_TD,mosu_date,mosu_rate)
mosu_CB_TD_cost
# Out:
#           持仓金额   成交数量    持仓成本         起息日   剩余年限    证券代码  成交金额  买卖数量  \
# 模塑转债  12055.18  120.0  100.46  2017-06-02  4年90天  127004   0.0     0
#
#            交易时间   到期本息   到期利率%  到期年化%  锁仓张数
# 模塑转债 2018-06-01  112.4  11.886  2.376   0.0

# %% [markdown]
# ### 江南转债113010

# %%
jiangnan = u'江南转债'
jiangnan_date = '2016-03-18'
jiangnan_rate = [8.0, 1.8, 1.5, 1.0, 0.5, 0.3]

# %%
jiangnan_CB_TD = CB_Transaction_Functions.CB_Transaction_Data(jiangnan,jiangnan_date,jiangnan_rate)
jiangnan_CB_TD.tail(2)
# Out:
#         发生日期    业务名称    证券代码  证券名称    成交均价  成交数量    成交金额  股份余额  手续费    发生金额  \
# 6 2018-07-26    转债回售  113010  江南转债  103.00   -30  3090.0    20  1.0  3089.0
# 7 2018-11-05  证券卖出清算  113010  江南转债  105.54   -20  2110.8     0  1.0  2109.8
#
#        成本  到期本息  到期利率%  到期年化%
# 6  103.46   0.0    0.0    0.0
# 7    0.00   0.0    0.0    0.0

# %%
jiangnan_CB_TD_cost = CB_Transaction_Functions.CB_TD_cost(jiangnan,jiangnan_CB_TD,jiangnan_date,jiangnan_rate)
jiangnan_CB_TD_cost
# Out:
#       持仓金额  成交数量  持仓成本         起息日   剩余年限    证券代码    成交金额  买卖数量       交易时间  \
# 江南转债 -40.6   0.0     0  2016-03-18  3年14天  113010  105.54   -20 2018-11-05
#
#         到期本息  到期利率%  到期年化%  锁仓张数
# 江南转债  109.84      0      0   0.0

# %% [markdown]
# ### 电气转债113008

# %%
dianqi = u'电气转债'
dianqi_date = '2015-02-02'
dianqi_rate = [6.6, 1.5, 1.5, 1.0, 0.5, 0.2]

# %%
dianqi_CB_TD = CB_Transaction_Functions.CB_Transaction_Data(dianqi,dianqi_date,dianqi_rate)
dianqi_CB_TD.tail(2)
# Out:
#         发生日期    业务名称    证券代码  证券名称    成交均价  成交数量    成交金额  股份余额  手续费    发生金额  \
# 8 2018-08-07  证券卖出清算  113008  电气转债  101.92   -20  2038.4    40  1.0  2037.4
# 9 2018-11-19  证券卖出清算  113008  电气转债  105.50   -40  4220.0     0  1.0  4219.0
#
#         成本  到期本息  到期利率%  到期年化%
# 8  101.205   0.0    0.0    0.0
# 9    0.000   0.0    0.0    0.0

# %%
dianqi_CB_TD_cost = CB_Transaction_Functions.CB_TD_cost(dianqi,dianqi_CB_TD,dianqi_date,dianqi_rate)
dianqi_CB_TD_cost
# Out:
#        持仓金额  成交数量  持仓成本         起息日    剩余年限    证券代码   成交金额  买卖数量       交易时间  \
# 电气转债 -170.8   0.0     0  2015-02-02  1年333天  113008  105.5   -40 2018-11-19
#
#         到期本息  到期利率%  到期年化%  锁仓张数
# 电气转债  107.68      0      0   0.0

# %% [markdown]
# ### 格力转债110030

# %%
geli = u'格力转债'
geli_date = '2014-12-25'
geli_rate = [6.0, 1.5, 1.0, 0.8, 0.6]

# %%
geli_CB_TD = CB_Transaction_Functions.CB_Transaction_Data(geli,geli_date,geli_rate)
geli_CB_TD
# 107以上
# Out:
#         发生日期    业务名称    证券代码  证券名称    成交均价  成交数量    成交金额  股份余额  手续费    发生金额  \
# 0 2017-11-21  证券买入清算  110030  格力转债  107.35    10  1073.5    10  1.0 -1074.5
# 1 2017-11-21  证券买入清算  110030  格力转债  106.61    10  1066.1    20  1.0 -1067.1
# 2 2017-12-27  证券买入清算  110030  格力转债  104.89    10  1048.9    30  1.0 -1049.9
# 3 2017-12-28    债券兑息  110030  格力转债    0.00     0    20.0    30  4.0    16.0
# 4 2018-01-25  证券卖出清算  110030  格力转债  111.03   -10  1110.3    20  1.0  1109.3
# 5 2018-02-07  证券买入清算  110030  格力转债  106.50    10  1065.0    30  1.0 -1066.0
# 6 2018-12-28    债券兑息  110030  格力转债    0.00     0    45.0    30  9.0    36.0
#
#         成本   到期本息  到期利率%  到期年化%
# 0  107.450  106.8 -0.512 -0.245
# 1  107.080  106.8  0.178  0.085
# 2  106.383  106.0  1.058  0.531
# 3  105.850    0.0  0.000  0.000
# 4  103.310    0.0  0.000  0.000
# 5  104.407  106.0 -0.469 -0.250
# 6  103.207    0.0  0.000  0.000

# %%
geli_CB_TD_cost = CB_Transaction_Functions.CB_TD_cost(geli,geli_CB_TD,geli_date,geli_rate)
geli_CB_TD_cost
# Out:
#         持仓金额  成交数量     持仓成本         起息日    剩余年限    证券代码  成交金额  买卖数量  \
# 格力转债  3096.2  30.0  103.207  2014-12-25  1年295天  110030   0.0     0
#
#            交易时间   到期本息  到期利率%  到期年化%  锁仓张数
# 格力转债 2018-12-28  104.8  1.544  1.561   0.0

# %% [markdown]
# ### 久其转债128015

# %%
jiuqi = u'久其转债'
jiuqi_date = '2017-06-08'
jiuqi_rate = [8.0, 1.5, 1.3, 1.0, 0.5, 0.3]

# %%
jiuqi_CB_TD = CB_Transaction_Functions.CB_Transaction_Data(jiuqi,jiuqi_date,jiuqi_rate)
jiuqi_CB_TD.tail(1)
# Out:
#         发生日期    业务名称    证券代码  证券名称     成交均价  成交数量     成交金额  股份余额  手续费  \
# 7 2018-02-14  证券卖出清算  128015  久其转债  100.097   -10  1000.97     0  0.2
#
#       发生金额   成本  到期本息  到期利率%  到期年化%
# 7  1000.77  0.0   0.0    0.0    0.0

# %%
jiuqi_CB_TD_cost = CB_Transaction_Functions.CB_TD_cost(jiuqi,jiuqi_CB_TD,jiuqi_date,jiuqi_rate)
jiuqi_CB_TD_cost
# Out:
#        持仓金额  成交数量  持仓成本         起息日   剩余年限    证券代码     成交金额  买卖数量       交易时间  \
# 久其转债 -54.07   0.0     0  2017-06-08  4年95天  128015  100.097   -10 2018-02-14
#
#         到期本息  到期利率%  到期年化%  锁仓张数
# 久其转债  110.08      0      0   0.0

# %% [markdown]
# ### 嘉澳转债113502

# %%
jiaao = u'嘉澳转债'
jiaao_date = '2017-11-10'
jiaao_rate = [8.0, 1.8, 1.5, 1.0, 0.6, 0.4]

# %%
jiaao_CB_TD = CB_Transaction_Functions.CB_Transaction_Data(jiaao,jiaao_date,jiaao_rate)
jiaao_CB_TD.tail(1)
# Out:
#         发生日期    业务名称    证券代码  证券名称  成交均价  成交数量    成交金额  股份余额  手续费    发生金额  \
# 5 2019-02-12  证券卖出清算  113502  嘉澳转债  96.2   -20  1924.0     0  1.0  1923.0
#
#     成本  到期本息  到期利率%  到期年化%
# 5  0.0   0.0    0.0    0.0

# %%
jiaao_CB_TD_cost = CB_Transaction_Functions.CB_TD_cost(jiaao,jiaao_CB_TD,jiaao_date,jiaao_rate)
jiaao_CB_TD_cost
# Out:
#       持仓金额  成交数量  持仓成本         起息日    剩余年限    证券代码  成交金额  买卖数量       交易时间  \
# 嘉澳转债 -38.7   0.0     0  2017-11-10  4年251天  113502  96.2   -20 2019-02-12
#
#         到期本息  到期利率%  到期年化%  锁仓张数
# 嘉澳转债  110.32      0      0   0.0

# %% [markdown]
# ### 小康转债113016

# %%
xiaokang = u'小康转债'
xiaokang_date = '2017-11-06'
xiaokang_rate = [6.0, 1.8, 1.5, 1.0, 0.5, 0.3]

# %%
xiaokang_CB_TD = CB_Transaction_Functions.CB_Transaction_Data(xiaokang,xiaokang_date,xiaokang_rate)
xiaokang_CB_TD.tail(1)
# Out:
#         发生日期    业务名称    证券代码  证券名称   成交均价  成交数量   成交金额  股份余额  手续费   发生金额   成本  \
# 4 2018-03-06  证券卖出清算  113016  小康转债  98.52   -10  985.2     0  1.0  984.2  0.0
#
#    到期本息  到期利率%  到期年化%
# 4   0.0    0.0    0.0

# %%
xiaokang_CB_TD_cost = CB_Transaction_Functions.CB_TD_cost(xiaokang,xiaokang_CB_TD,xiaokang_date,xiaokang_rate)
xiaokang_CB_TD_cost
# Out:
#       持仓金额  成交数量  持仓成本         起息日    剩余年限    证券代码   成交金额  买卖数量       交易时间  \
# 小康转债 -59.9   0.0     0  2017-11-06  4年246天  113016  98.52   -10 2018-03-06
#
#         到期本息  到期利率%  到期年化%  锁仓张数
# 小康转债  108.88      0      0   0.0

# %% [markdown]
# ### 时达转债128018

# %%
shida = u'时达转债'
shida_date = '2017-11-06'
shida_rate = [6.0, 1.8, 1.5, 1.0, 0.5, 0.3]

# %%
shida_CB_TD = CB_Transaction_Functions.CB_Transaction_Data(shida,shida_date,shida_rate)
shida_CB_TD.tail(6)
# 94元以上卖出30张。
# Out:
#          发生日期    业务名称    证券代码  证券名称    成交均价  成交数量    成交金额  股份余额   手续费    发生金额  \
# 6  2018-04-24  证券买入清算  128018  时达转债  93.628    10  936.28    10  0.19 -936.47
# 7  2018-04-26  证券买入清算  128018  时达转债  92.611    10  926.11    20  0.19 -926.30
# 8  2018-05-28  证券买入清算  128018  时达转债  90.800    10  908.00    30  0.18 -908.18
# 9  2018-06-05  证券买入清算  128018  时达转债  87.603    10  876.03    40  0.18 -876.21
# 10 2018-07-20  证券卖出清算  128018  时达转债  89.515   -10  895.15    30  0.18  894.97
# 11 2018-11-05    债券兑息  128018  时达转债   0.000     0    9.00    30  1.80    7.20
#
#         成本    到期本息   到期利率%  到期年化%
# 6   89.788  108.88  16.290  2.942
# 7   91.209  108.88  17.567  3.176
# 8   91.079  108.88  19.912  3.658
# 9   90.214  108.88  24.288  4.480
# 10  90.453    0.00   0.000  0.000
# 11  90.213    0.00   0.000  0.000

# %%
shida_CB_TD_cost = CB_Transaction_Functions.CB_TD_cost(shida,shida_CB_TD,shida_date,shida_rate)
shida_CB_TD_cost
# Out:
#         持仓金额  成交数量    持仓成本         起息日    剩余年限    证券代码  成交金额  买卖数量       交易时间  \
# 时达转债  2706.4  30.0  90.213  2017-11-06  4年246天  128018   0.0     0 2018-11-05
#
#         到期本息   到期利率%  到期年化%  锁仓张数
# 时达转债  108.88  20.692  4.136   0.0

# %% [markdown]
# ### 骆驼转债113012

# %%
luotuo = u'骆驼转债'
luotuo_date = '2017-03-24'
luotuo_rate = [5.0, 1.5, 1.3, 1.0, 0.5, 0.3]

# %%
luotuo_CB_TD = CB_Transaction_Functions.CB_Transaction_Data(luotuo,luotuo_date,luotuo_rate)
luotuo_CB_TD
# Out:
#         发生日期    业务名称    证券代码  证券名称   成交均价  成交数量   成交金额  股份余额  手续费   发生金额  \
# 0 2017-12-07  证券买入清算  113012  骆驼转债  97.38    10  973.8    10  1.0 -974.8
# 1 2018-01-25  证券卖出清算  113012  骆驼转债  98.94   -10  989.4     0  1.0  988.4
# 2 2018-02-01  证券买入清算  113012  骆驼转债  95.56    10  955.6    10  1.0 -956.6
# 3 2018-03-09  证券卖出清算  113012  骆驼转债  98.68   -10  986.8     0  1.0  985.8
#
#       成本    到期本息   到期利率%  到期年化%
# 0  97.48  107.68  10.577  1.998
# 1   0.00    0.00   0.000  0.000
# 2  94.30  107.68  12.683  2.468
# 3   0.00    0.00   0.000  0.000

# %%
luotuo_CB_TD_cost = CB_Transaction_Functions.CB_TD_cost(luotuo,luotuo_CB_TD,luotuo_date,luotuo_rate)
luotuo_CB_TD_cost
# Out:
#       持仓金额  成交数量  持仓成本         起息日   剩余年限    证券代码   成交金额  买卖数量       交易时间  \
# 骆驼转债 -42.8   0.0     0  2017-03-24  4年20天  113012  98.68   -10 2018-03-09
#
#         到期本息  到期利率%  到期年化%  锁仓张数
# 骆驼转债  107.68      0      0   0.0

# %% [markdown]
# ### 蒙电转债110041

# %%
mengdian = u'蒙电转债'
mengdian_date = '2017-12-22'
mengdian_rate = [6.0, 1.8, 1.5, 1.0, 0.6, 0.4]

# %%
mengdian_CB_TD = CB_Transaction_Functions.CB_Transaction_Data(mengdian,mengdian_date,mengdian_rate)
mengdian_CB_TD
# Out:
#         发生日期      业务名称    证券代码  证券名称    成交均价  成交数量    成交金额  股份余额  手续费    发生金额  \
# 0 2017-12-26  市值认购资金扣收  110041  蒙电转债  100.00    10  1000.0    10  0.0 -1000.0
# 1 2018-01-25    证券卖出清算  110041  蒙电转债  104.60   -10  1046.0     0  1.0  1045.0
# 2 2018-02-09    证券买入清算  110041  蒙电转债   98.35    10   983.5    10  1.0  -984.5
# 3 2018-02-13    证券卖出清算  110041  蒙电转债  100.51   -10  1005.1     0  1.0  1004.1
#
#        成本    到期本息   到期利率%  到期年化%
# 0  100.00  109.04   9.040  1.509
# 1    0.00    0.00   0.000  0.000
# 2   93.95  109.04  10.869  1.853
# 3    0.00    0.00   0.000  0.000

# %%
mengdian_CB_TD_cost = CB_Transaction_Functions.CB_TD_cost(mengdian,mengdian_CB_TD,mengdian_date,mengdian_rate)
mengdian_CB_TD_cost
# Out:
#       持仓金额  成交数量  持仓成本         起息日    剩余年限    证券代码    成交金额  买卖数量       交易时间  \
# 蒙电转债 -64.6   0.0     0  2017-12-22  4年293天  110041  100.51   -10 2018-02-13
#
#         到期本息  到期利率%  到期年化%  锁仓张数
# 蒙电转债  109.04      0      0   0.0

# %% [markdown]
# ### 吉视转债113017

# %%
jishi = u'吉视转债'
jishi_date = '2017-12-27'
jishi_rate = [6.0, 1.5, 1.3, 1.0, 0.5, 0.3]

# %%
jishi_CB_TD = CB_Transaction_Functions.CB_Transaction_Data(jishi,jishi_date,jishi_rate)
jishi_CB_TD
# Out:
#         发生日期      业务名称    证券代码  证券名称    成交均价  成交数量    成交金额  股份余额  手续费    发生金额  \
# 0 2017-12-29  市值认购资金扣收  113017  吉视转债  100.00    30  3000.0    30  0.0 -3000.0
# 1 2018-01-25    证券卖出清算  113017  吉视转债  106.50   -10  1065.0    20  1.0  1064.0
# 2 2018-02-07    证券买入清算  113017  吉视转债   98.53    10   985.3    30  1.0  -986.3
# 3 2018-02-26    证券卖出清算  113017  吉视转债  100.65   -10  1006.5    20  1.0  1005.5
# 4 2019-01-02      债券兑息  113017  吉视转债    0.00     0     6.0    20  1.2     4.8
# 5 2019-02-12    证券卖出清算  113017  吉视转债   96.86   -20  1937.2     0  1.0  1936.2
#
#        成本    到期本息   到期利率%  到期年化%
# 0  100.00  108.48   8.480  1.415
# 1   96.80    0.00   0.000  0.000
# 2   97.41  108.48  10.098  1.716
# 3   95.84    0.00   0.000  0.000
# 4   95.60    0.00   0.000  0.000
# 5    0.00    0.00   0.000  0.000

# %%
jishi_CB_TD_cost = CB_Transaction_Functions.CB_TD_cost(jishi,jishi_CB_TD,jishi_date,jishi_rate)
jishi_CB_TD_cost
# Out:
#       持仓金额  成交数量  持仓成本         起息日    剩余年限    证券代码   成交金额  买卖数量       交易时间  \
# 吉视转债 -24.2   0.0     0  2017-12-27  4年297天  113017  96.86   -20 2019-02-12
#
#         到期本息  到期利率%  到期年化%  锁仓张数
# 吉视转债  108.24      0      0   0.0

# %% [markdown]
# ### 迪龙转债128033

# %%
dilong = u'迪龙转债'
dilong_date = '2017-12-27'
dilong_rate = [6.0, 1.5, 1.3, 1.0, 0.5, 0.3]

# %%
dilong_CB_TD = CB_Transaction_Functions.CB_Transaction_Data(dilong,dilong_date,dilong_rate)
dilong_CB_TD
# Out:
#         发生日期      业务名称    证券代码  证券名称     成交均价  成交数量     成交金额  股份余额   手续费  \
# 0 2017-12-29  市值认购资金扣收   72658  迪龙转债  100.000    10  1000.00    10  0.00
# 1 2018-01-29    证券卖出清算  128033  迪龙转债  103.808   -10  1038.08     0  0.21
# 2 2018-02-09    证券买入清算  128033  迪龙转债   97.318    10   973.18    10  0.19
# 3 2018-03-14    证券卖出清算  128033  迪龙转债  102.000   -10  1020.00     0  0.20
# 4 2018-04-23    证券买入清算  128033  迪龙转债   97.521    10   975.21    10  0.20
# 5 2018-05-02    证券买入清算  128033  迪龙转债   94.380    10   943.80    20  0.19
# 6 2018-05-21    证券卖出清算  128033  迪龙转债   97.710   -10   977.10    10  0.20
# 7 2018-05-30    证券买入清算  128033  迪龙转债   91.902    10   919.02    20  0.18
# 8 2018-06-11    证券卖出清算  128033  迪龙转债   96.900   -10   969.00    10  0.19
# 9 2018-07-26    证券卖出清算  128033  迪龙转债   99.099   -10   990.99     0  0.20
#
#       发生金额       成本    到期本息   到期利率%  到期年化%
# 0 -1000.00  100.000  108.48   8.480  1.415
# 1  1037.87    0.000    0.00   0.000  0.000
# ...

# %%
dilong_CB_TD_cost = CB_Transaction_Functions.CB_TD_cost(dilong,dilong_CB_TD,dilong_date,dilong_rate)
dilong_CB_TD_cost
# Out:
#        持仓金额  成交数量  持仓成本         起息日    剩余年限    证券代码    成交金额  买卖数量       交易时间  \
# 迪龙转债 -182.2   0.0     0  2017-12-27  4年297天  128033  99.099   -10 2018-07-26
#
#         到期本息  到期利率%  到期年化%  锁仓张数
# 迪龙转债  108.48      0      0   0.0

# %% [markdown]
# ### 永东转债128014

# %%
yongdong = u'永东转债'
yongdong_date = '2017-04-17'
yongdong_rate = [8.0, 1.8, 1.5, 1.0, 0.7, 0.5]

# %%
yongdong_CB_TD = CB_Transaction_Functions.CB_Transaction_Data(yongdong,yongdong_date,yongdong_rate)
yongdong_CB_TD
# Out:
#         发生日期    业务名称    证券代码  证券名称     成交均价  成交数量     成交金额  股份余额   手续费  \
# 0 2018-02-02  证券买入清算  128014  永东转债  104.407    10  1044.07    10  0.21
# 1 2018-02-02  证券买入清算  128014  永东转债  103.101    10  1031.01    20  0.21
# 2 2018-02-06  证券买入清算  128014  永东转债  102.012    10  1020.12    30  0.20
# 3 2018-04-16    债券兑息  128014  永东转债    0.000     0    15.00    30  3.00
# 4 2018-05-09  证券卖出清算  128014  永东转债  105.700   -10  1057.00    20  0.21
# 5 2018-06-12  证券卖出清算  128014  永东转债  111.000   -10  1110.00    10  0.22
# 6 2019-02-12  证券卖出清算  128014  永东转债   96.749   -10   967.49     0  0.19
#
#       发生金额       成本   到期本息  到期利率%  到期年化%
# 0 -1044.28  104.428  110.8  6.123  1.177
# 1 -1031.22  103.775  110.8  7.467  1.435
# 2 -1020.32  103.194  110.8  8.615  1.659
# 3    12.00  102.794    0.0  0.000  0.000
# 4  1056.79  101.352    0.0  0.000  0.000
# 5  1109.78   91.725    0.0  0.000  0.000
# 6   967.30    0.000    0.0  0.000  0.000

# %%
yongdong_CB_TD_cost = CB_Transaction_Functions.CB_TD_cost(yongdong,yongdong_CB_TD,yongdong_date,yongdong_rate)
yongdong_CB_TD_cost
# Out:
#        持仓金额  成交数量  持仓成本         起息日   剩余年限    证券代码    成交金额  买卖数量       交易时间  \
# 永东转债 -50.05   0.0     0  2017-04-17  4年43天  128014  96.749   -10 2019-02-12
#
#        到期本息  到期利率%  到期年化%  锁仓张数
# 永东转债  110.4      0      0   0.0

# %% [markdown]
# ### 众兴转债128026

# %%
zhongxing = u'众兴转债'
zhongxing_date = '2017-12-13'
zhongxing_rate = [6.0, 1.8, 1.5, 1.0, 0.6, 0.4]

# %%
zhongxing_CB_TD = CB_Transaction_Functions.CB_Transaction_Data(zhongxing,zhongxing_date,zhongxing_rate)
zhongxing_CB_TD
# Out:
#         发生日期    业务名称    证券代码  证券名称   成交均价  成交数量   成交金额  股份余额   手续费    发生金额  \
# 0 2018-02-06  证券买入清算  128026  众兴转债  95.56    10  955.6    10  0.19 -955.79
# 1 2018-03-13  证券卖出清算  128026  众兴转债  97.00   -10  970.0     0  0.19  969.81
# 2 2018-04-20  证券买入清算  128026  众兴转债  95.00    10  950.0    10  0.19 -950.19
# 3 2018-12-12    债券兑息  128026  众兴转债   0.00     0    4.0    10  0.00    4.00
#
#        成本    到期本息   到期利率%  到期年化%
# 0  95.579  109.04  14.106  2.412
# 1   0.000    0.00   0.000  0.000
# 2  93.617  109.04  14.779  2.616
# 3  93.217    0.00   0.000  0.000

# %%
zhongxing_CB_TD_cost = CB_Transaction_Functions.CB_TD_cost(zhongxing,zhongxing_CB_TD,zhongxing_date,zhongxing_rate)
zhongxing_CB_TD_cost
# Out:
#         持仓金额  成交数量    持仓成本         起息日    剩余年限    证券代码  成交金额  买卖数量       交易时间  \
# 众兴转债  932.17  10.0  93.217  2017-12-13  4年283天  128026   0.0     0 2018-12-12
#
#         到期本息   到期利率%  到期年化%  锁仓张数
# 众兴转债  109.04  16.974  3.393   0.0

# %% [markdown]
# ### 水晶转债128020

# %%
shuijing = u'水晶转债'
shuijing_date = '2017-11-17'
shuijing_rate = [8.0, 1.3, 1.0, 0.8, 0.5, 0.3]

# %%
shuijing_CB_TD = CB_Transaction_Functions.CB_Transaction_Data(shuijing,shuijing_date,shuijing_rate)
shuijing_CB_TD
# Out:
#         发生日期    业务名称    证券代码  证券名称    成交均价  成交数量    成交金额  股份余额   手续费    发生金额  \
# 0 2018-02-06  证券买入清算  128020  水晶转债  97.001    10  970.01    10  0.19 -970.20
# 1 2018-02-08  证券买入清算  128020  水晶转债  95.062    10  950.62    20  0.19 -950.81
# 2 2018-02-22  证券卖出清算  128020  水晶转债  96.526   -10  965.26    10  0.19  965.07
# 3 2018-03-13  证券卖出清算  128020  水晶转债  99.620   -10  996.20     0  0.20  996.00
# 4 2018-04-23  证券买入清算  128020  水晶转债  94.201    10  942.01    10  0.19 -942.20
# 5 2018-05-02  证券卖出清算  128020  水晶转债  96.400   -10  964.00     0  0.19  963.81
#
#        成本    到期本息   到期利率%  到期年化%
# 0  97.020  109.52  12.906  2.234
# 1  96.050  109.52  15.209  2.635
# 2  95.594    0.00   0.000  0.000
# 3   0.000    0.00   0.000  0.000
# 4  90.214  109.52  16.262  2.920
# 5   0.000    0.00   0.000  0.000

# %%
shuijing_CB_TD_cost = CB_Transaction_Functions.CB_TD_cost(shuijing,shuijing_CB_TD,shuijing_date,shuijing_rate)
shuijing_CB_TD_cost
# Out:
#        持仓金额  成交数量  持仓成本         起息日    剩余年限    证券代码  成交金额  买卖数量       交易时间  \
# 水晶转债 -61.67   0.0     0  2017-11-17  4年258天  128020  96.4   -10 2018-05-02
#
#         到期本息  到期利率%  到期年化%  锁仓张数
# 水晶转债  109.52      0      0   0.0

# %% [markdown]
# ### 亚太转债128023

# %%
yatai = u'亚太转债'
yatai_date = '2017-12-04'
yatai_rate = [8.0, 1.8, 1.5, 1.0, 0.5, 0.3]

# %%
yatai_CB_TD = CB_Transaction_Functions.CB_Transaction_Data(yatai,yatai_date,yatai_rate)
yatai_CB_TD
# Out:
#         发生日期    业务名称    证券代码  证券名称    成交均价  成交数量    成交金额  股份余额   手续费    发生金额  \
# 0 2018-02-08  证券买入清算  128023  亚太转债  94.202    10  942.02    10  0.19 -942.21
# 1 2018-02-09  证券买入清算  128023  亚太转债  93.210    10  932.10    20  0.19 -932.29
# 2 2018-12-03    债券兑息  128023  亚太转债   0.000     0    6.00    20  1.20    4.80
#
#        成本    到期本息   到期利率%  到期年化%
# 0  94.221  110.48  17.280  2.969
# 1  93.725  110.48  18.528  3.185
# 2  93.485    0.00   0.000  0.000

# %%
yatai_CB_TD_cost = CB_Transaction_Functions.CB_TD_cost(yatai,yatai_CB_TD,yatai_date,yatai_rate)
yatai_CB_TD_cost
# Out:
#         持仓金额  成交数量    持仓成本         起息日    剩余年限    证券代码  成交金额  买卖数量       交易时间  \
# 亚太转债  1869.7  20.0  93.485  2017-12-04  4年274天  128023   0.0     0 2018-12-03
#
#         到期本息   到期利率%  到期年化%  锁仓张数
# 亚太转债  110.48  18.179  3.634   0.0

# %% [markdown]
# ### 久立转2128019

# %%
jiuli = u'久立转2'
jiuli_date = '2017-11-08'
jiuli_rate = [6.0, 1.5, 1.3, 1.0, 0.5, 0.3]

# %%
jiuli_CB_TD = CB_Transaction_Functions.CB_Transaction_Data(jiuli,jiuli_date,jiuli_rate)
jiuli_CB_TD
# Out:
#         发生日期    业务名称    证券代码  证券名称    成交均价  成交数量    成交金额  股份余额   手续费   发生金额  \
# 0 2018-02-09  证券买入清算  128019  久立转2  94.911    10  949.11    10  0.19 -949.3
# 1 2018-03-13  证券卖出清算  128019  久立转2  99.000   -10  990.00     0  0.20  989.8
#
#       成本    到期本息   到期利率%  到期年化%
# 0  94.93  108.48  14.297  2.488
# 1   0.00    0.00   0.000  0.000

# %%
jiuli_CB_TD_cost = CB_Transaction_Functions.CB_TD_cost(jiuli,jiuli_CB_TD,jiuli_date,jiuli_rate)
jiuli_CB_TD_cost
# Out:
#       持仓金额  成交数量  持仓成本         起息日    剩余年限    证券代码  成交金额  买卖数量       交易时间  \
# 久立转2 -40.5   0.0     0  2017-11-08  4年249天  128019  99.0   -10 2018-03-13
#
#         到期本息  到期利率%  到期年化%  锁仓张数
# 久立转2  108.48      0      0   0.0

# %% [markdown]
# ### 双环转债128032

# %%
shuanghuan = u'双环转债'
shuanghuan_date = '2017-12-25'
shuanghuan_rate = [6.0, 1.8, 1.5, 1.0, 0.5, 0.3]

# %%
shuanghuan_CB_TD = CB_Transaction_Functions.CB_Transaction_Data(shuanghuan,shuanghuan_date,shuanghuan_rate)
shuanghuan_CB_TD
# Out:
#         发生日期    业务名称    证券代码  证券名称     成交均价  成交数量     成交金额  股份余额   手续费  \
# 0 2018-02-09  证券买入清算  128032  双环转债   97.348    10   973.48    10  0.19
# 1 2018-03-13  证券卖出清算  128032  双环转债  104.610   -10  1046.10     0  0.21
#
#       发生金额      成本    到期本息   到期利率%  到期年化%
# 0  -973.67  97.367  108.88  11.846  2.017
# 1  1045.89   0.000    0.00   0.000  0.000

# %%
shuanghuan_CB_TD_cost = CB_Transaction_Functions.CB_TD_cost(shuanghuan,shuanghuan_CB_TD,shuanghuan_date,shuanghuan_rate)
shuanghuan_CB_TD_cost
# Out:
#        持仓金额  成交数量  持仓成本         起息日    剩余年限    证券代码    成交金额  买卖数量       交易时间  \
# 双环转债 -72.22   0.0     0  2017-12-25  4年296天  128032  104.61   -10 2018-03-13
#
#         到期本息  到期利率%  到期年化%  锁仓张数
# 双环转债  108.88      0      0   0.0

# %% [markdown]
# ### 江银转债128034

# %%
jiangyin = u'江银转债'
jiangyin_date = '2018-01-26'
jiangyin_rate = [6.0, 1.3, 1.0, 0.8, 0.5, 0.3]

# %%
jiangyin_CB_TD = CB_Transaction_Functions.CB_Transaction_Data(jiangyin,jiangyin_date,jiangyin_rate)
jiangyin_CB_TD
# Out:
#         发生日期      业务名称    证券代码  证券名称     成交均价  成交数量     成交金额  股份余额   手续费  \
# 0 2018-01-30  市值认购资金扣收  128034  江银转债  100.000    10  1000.00    10  0.00
# 1 2018-03-15    证券买入清算  128034  江银转债   96.880    10   968.80    20  0.19
# 2 2018-03-15    证券买入清算  128034  江银转债   95.547    10   968.80    30  0.19
# 3 2018-03-23    证券买入清算  128034  江银转债   94.082    10   940.82    40  0.19
# 4 2018-03-26    证券买入清算  128034  江银转债   93.165    10   931.65    50  0.19
# 5 2018-04-17    证券卖出清算  128034  江银转债   97.150   -10   971.50    40  0.19
# 6 2018-04-17    证券卖出清算  128034  江银转债   98.001   -10   980.01    30  0.20
# 7 2018-04-19    证券卖出清算  128034  江银转债   98.205   -10   982.05    20  0.20
# 8 2018-05-03    证券卖出清算  128034  江银转债   98.980   -10   989.80    10  0.20
# 9 2018-08-30    证券卖出清算  128034  江银转债  100.963   -10  1009.63     0  0.20
#
#       发生金额       成本    到期本息   到期利率%  到期年化%
# 0 -1000.00  100.000  107.92   7.920  1.322
# 1  -968.99   98.450  107.92  11.396  1.942
# ...

# %%
jiangyin_CB_TD_cost = CB_Transaction_Functions.CB_TD_cost(jiangyin,jiangyin_CB_TD,jiangyin_date,jiangyin_rate)
jiangyin_CB_TD_cost
# Out:
#        持仓金额  成交数量  持仓成本         起息日    剩余年限    证券代码     成交金额  买卖数量       交易时间  \
# 江银转债 -134.5   0.0     0  2018-01-26  4年327天  128034  100.963   -10 2018-08-30
#
#         到期本息  到期利率%  到期年化%  锁仓张数
# 江银转债  107.92      0      0   0.0

# %% [markdown]
# ### 无锡转债110043

# %%
wuxi = u'无锡转债'
wuxi_date = '2018-01-30'
wuxi_rate = [6.0, 1.3, 1.0, 0.8, 0.5, 0.3]

# %%
wuxi_CB_TD = CB_Transaction_Functions.CB_Transaction_Data(wuxi,wuxi_date,wuxi_rate)
wuxi_CB_TD
# Out:
#         发生日期      业务名称    证券代码  证券名称    成交均价  成交数量    成交金额  股份余额  手续费    发生金额  \
# 0 2018-02-01  市值认购资金扣收  110043  无锡转债  100.00    20  2000.0    20  0.0 -2000.0
# 1 2018-03-15    证券买入清算  110043  无锡转债   96.97    10   969.7    30  1.0  -970.7
# 2 2018-03-23    证券买入清算  110043  无锡转债   94.74    10   947.4    40  1.0  -948.4
# 3 2018-05-03    证券卖出清算  110043  无锡转债   97.50   -10   975.0    30  1.0   974.0
# 4 2018-05-07    证券卖出清算  110043  无锡转债   98.14   -10   981.4    20  1.0   980.4
# 5 2018-05-21    证券卖出清算  110043  无锡转债  101.50   -10  1015.0    10  1.0  1014.0
# 6 2018-11-19    证券卖出清算  110043  无锡转债  100.42   -10  1004.2     0  1.0  1003.2
#
#         成本    到期本息   到期利率%  到期年化%
# 0  100.000  107.92   7.920  1.321
# 1   99.023  107.92  11.292  1.921
# 2   97.977  107.92  13.912  2.375
# 3   98.170    0.00   0.000  0.000
# 4   98.235    0.00   0.000  0.000
# 5   95.070    0.00   0.000  0.000
# 6    0.000    0.00   0.000  0.000

# %%
wuxi_CB_TD_cost = CB_Transaction_Functions.CB_TD_cost(wuxi,wuxi_CB_TD,wuxi_date,wuxi_rate)
wuxi_CB_TD_cost
# Out:
#       持仓金额  成交数量  持仓成本         起息日    剩余年限    证券代码    成交金额  买卖数量       交易时间  \
# 无锡转债 -52.5   0.0     0  2018-01-30  4年332天  110043  100.42   -10 2018-11-19
#
#         到期本息  到期利率%  到期年化%  锁仓张数
# 无锡转债  107.92      0      0   0.0

# %% [markdown]
# ### 金农转债128036

# %%
jinnong = u'金农转债'
jinnong_date = '2018-03-09'
jinnong_rate = [6.0, 1.8, 1.5, 1.0, 0.6, 0.4]

# %%
jinnong_CB_TD = CB_Transaction_Functions.CB_Transaction_Data(jinnong,jinnong_date,jinnong_rate)
jinnong_CB_TD
# Out:
#         发生日期    业务名称    证券代码  证券名称    成交均价  成交数量    成交金额  股份余额   手续费    发生金额  \
# 0 2018-04-20  证券买入清算  128036  金农转债  96.000    10  960.00    10  0.19 -960.19
# 1 2018-05-07  证券卖出清算  128036  金农转债  97.353   -10  973.53     0  0.19  973.34
#
#        成本    到期本息   到期利率%  到期年化%
# 0  96.019  109.04  13.583  2.308
# 1   0.000    0.00   0.000  0.000

# %%
jinnong_CB_TD_cost = CB_Transaction_Functions.CB_TD_cost(jinnong,jinnong_CB_TD,jinnong_date,jinnong_rate)
jinnong_CB_TD_cost
# Out:
#        持仓金额  成交数量  持仓成本         起息日  剩余年限    证券代码    成交金额  买卖数量       交易时间  \
# 金农转债 -13.15   0.0     0  2018-03-09  5年4天  128036  97.353   -10 2018-05-07
#
#         到期本息  到期利率%  到期年化%  锁仓张数
# 金农转债  109.04      0      0   0.0

# %% [markdown]
# ### 岩土转债128037

# %%
yantu = u'岩土转债'
yantu_date = '2018-03-15'
yantu_rate = [8.0, 1.8, 1.5, 1.0, 0.5, 0.3]

# %%
yantu_CB_TD = CB_Transaction_Functions.CB_Transaction_Data(yantu,yantu_date,yantu_rate)
yantu_CB_TD
# Out:
#         发生日期    业务名称    证券代码  证券名称    成交均价  成交数量    成交金额  股份余额   手续费    发生金额  \
# 0 2018-05-30  证券买入清算  128037  岩土转债  91.920    10  919.20    10  0.18 -919.38
# 1 2019-02-25  证券卖出清算  128037  岩土转债  94.014   -10  940.14     0  0.19  939.95
#
#        成本    到期本息   到期利率%  到期年化%
# 0  91.938  110.48  20.191  3.486
# 1   0.000    0.00   0.000  0.000

# %%
yantu_CB_TD_cost = CB_Transaction_Functions.CB_TD_cost(yantu,yantu_CB_TD,yantu_date,yantu_rate)
yantu_CB_TD_cost
# Out:
#        持仓金额  成交数量  持仓成本         起息日   剩余年限    证券代码    成交金额  买卖数量       交易时间  \
# 岩土转债 -20.57   0.0     0  2018-03-15  5年11天  128037  94.014   -10 2019-02-25
#
#         到期本息  到期利率%  到期年化%  锁仓张数
# 岩土转债  110.48      0      0   0.0

# %% [markdown]
# ## 【数据集合与画图】

# %%
CB_Transaction_Data_Cost_T = pd.concat([lanbiao_CB_TD_cost.T,huifeng_CB_TD_cost.T,hongtao_CB_TD_cost.T,hangxin_CB_TD_cost.T,
                                        haiyin_CB_TD_cost.T,guangda_CB_TD_cost.T,mosu_CB_TD_cost.T,jiangnan_CB_TD_cost.T,
                                        dianqi_CB_TD_cost.T,geli_CB_TD_cost.T,jiuqi_CB_TD_cost.T,jiaao_CB_TD_cost.T,
                                        xiaokang_CB_TD_cost.T,shida_CB_TD_cost.T,luotuo_CB_TD_cost.T,mengdian_CB_TD_cost.T,
                                        jishi_CB_TD_cost.T,dilong_CB_TD_cost.T,yongdong_CB_TD_cost.T,zhongxing_CB_TD_cost.T,
                                        shuijing_CB_TD_cost.T,yatai_CB_TD_cost.T,jiuli_CB_TD_cost.T,shuanghuan_CB_TD_cost.T,
                                        jiangyin_CB_TD_cost.T,wuxi_CB_TD_cost.T,jinnong_CB_TD_cost.T,yantu_CB_TD_cost.T], axis=1)
CB_Transaction_Data_Cost = CB_Transaction_Data_Cost_T.T
CB_Transaction_Data_Cost[u'总成本'] = CB_Transaction_Data_Cost[u'成交数量']*CB_Transaction_Data_Cost[u'持仓成本']
CB_Transaction_Data_Cost = CB_Transaction_Data_Cost.loc[CB_Transaction_Data_Cost[u'成交数量']>0]

# %%
plt.figure(3,figsize=(24,6), dpi=80)
ax3 = plt.subplot(111)

# %%
Yahei = matplotlib.font_manager.FontProperties(fname='C:\Windows\Fonts\msyh.ttf')
k = len(CB_Transaction_Data_Cost)
x_ticks_num = np.arange(0,k)
x_ticks_name = CB_Transaction_Data_Cost.index
y_ticks_values = CB_Transaction_Data_Cost[u'持仓成本'].values
y_ticks_num = CB_Transaction_Data_Cost[u'成交数量'].values
total_width = 0.7
num_bar = 2
w = total_width/num_bar
x_ticks_b = x_ticks_num - (total_width - w)/2
af = 0.8
x_ticks_num
# Out:
# array([0, 1, 2, 3, 4, 5, 6, 7])

# %%
ax3.bar(x_ticks_num+w, y_ticks_values, facecolor='orange', width=w, label=u'持仓成本', alpha=af)
plt.axhline(y=100, color='red', linewidth='1.0')
plt.legend(prop={'family':'Microsoft YaHei','size':12}, loc=(0.02,0.9))
plt.ylim(85,110,1)
plt.xticks(x_ticks_num+1.5*w, x_ticks_name, fontproperties=Yahei)
plt.grid(linestyle=':', alpha=0.5)

# %%
ax4 = ax3.twinx()
ax4.bar(x_ticks_num+2.1*w, y_ticks_num, facecolor='FireBrick', width=w, label=u'持仓数量', alpha=af)
plt.legend(prop={'family':'Microsoft YaHei','size':12}, loc=(0.02,0.8))
plt.ylim(0,450,1)
# Out:
# (0, 450)

# %%
for a,b in zip(x_ticks_num,y_ticks_values):
    ax3.text(a+w, b+0.2, '%.3f' % b, ha='center', va= 'bottom')

# %%
for c,d in zip(x_ticks_num,y_ticks_num):
    ax4.text(c+2.1*w, d+1, '%.0f' % d, ha='center', va= 'bottom')

# %%
CB_Transaction_Data_Cost[u'交易时间'] = pd.to_datetime(CB_Transaction_Data_Cost[u'交易时间'].values)
CB_Transaction_Data_Cost_R = CB_Transaction_Data_Cost.sort_values(by=u'持仓成本', ascending=True)
CB_Transaction_Data_Cost_R[u'可转债'] = CB_Transaction_Data_Cost_R.index
CB_Transaction_Data_Cost_R = CB_Transaction_Data_Cost_R.reset_index(drop=True)
CB_Transaction_Data_Cost_R = CB_Transaction_Data_Cost_R[[u'证券代码',u'可转债',u'持仓成本',u'成交数量',u'总成本',u'交易时间',u'成交金额',u'买卖数量',u'起息日',u'剩余年限',u'到期利率%',u'到期年化%',u'锁仓张数']]

# %% [markdown]
# ### 持仓明细表

# %%
CB_Transaction_Data_Cost_R
# Out:
#      证券代码   可转债     持仓成本 成交数量      总成本       交易时间    成交金额 买卖数量         起息日  \
# 0  128018  时达转债   90.213   30  2706.39 2018-11-05       0    0  2017-11-06
# 1  128026  众兴转债   93.217   10   932.17 2018-12-12       0    0  2017-12-13
# 2  128023  亚太转债   93.485   20   1869.7 2018-12-03       0    0  2017-12-04
# 3  128012  辉丰转债   95.828  120  11499.4 2019-02-12   92.88  -20  2016-04-21
# 4  127003  海印转债   99.517  140  13932.4 2019-03-01   97.98  -20  2016-06-08
# 5  127004  模塑转债   100.46  120  12055.2 2018-06-01       0    0  2017-06-02
# 6  128013  洪涛转债  101.241  410  41508.8 2019-02-12  92.158  -10  2016-07-29
# 7  110030  格力转债  103.207   30  3096.21 2018-12-28       0    0  2014-12-25
#
#      剩余年限   到期利率%  到期年化% 锁仓张数
# 0  4年246天  20.692  4.136    0
# 1  4年283天  16.974  3.393    0
# 2  4年274天  18.179  3.634    0
# 3   3年47天   9.863  3.095   20
# 4   3年95天  11.981  3.663   20
# 5   4年90天  11.886  2.376    0
# 6  3年147天   8.493  2.456   20
# 7  1年295天   1.544  1.561    0

# %%
CB_Transaction_Data_Cost_R.to_csv('cbcsv/CB_Transaction_Data_Cost.csv',encoding='gbk',index=False)

# %%
plt.savefig('D:/Python/iPython/CB/CB_TD.png', dpi=600)

# %%
plt.show()

# %% [markdown]
# [蓝标转债](#蓝标转债123001)、[辉丰转债](#辉丰转债128012)、[洪涛转债](#洪涛转债128013)、[航信转债](#航信转债110031)、[海印转债](#海印转债127003)、[光大转债](#光大转债113011)、[模塑转债](#模塑转债127004)、[江南转债](#江南转债113010)、[电气转债](#电气转债113008)、[格力转债](#格力转债110030)、[久其转债](#久其转债128015)、[嘉澳转债](#嘉澳转债113502)、[小康转债](#小康转债113016)、[时达转债](#时达转债128018)、[骆驼转债](#骆驼转债113012)、[蒙电转债](#蒙电转债110041)、[吉视转债](#吉视转债113017)、[迪龙转债](#迪龙转债128033)、[永东转债](#永东转债128014)、[众兴转债](#众兴转债128026)、[水晶转债](#水晶转债128020)、[亚太转债](#亚太转债128023)、[久立转2](#久立转2128019)、[双环转债](#双环转债128032)、[江银转债](#江银转债128034)、[无锡转债](#无锡转债110043)、[金农转债](#金农转债128036)、[岩土转债](#岩土转债128037)

# %%
ALL_Cost = CB_Transaction_Data_Cost.loc[:,[u'总成本']]
# 行合计，形成最后一行合计值
ALL_Cost.loc[u'合计'] = ALL_Cost.apply(lambda x: x.sum())
# ALL_Cost.sort_values(by=u'总成本', ascending=True).T
ALL_Cost.T[[u'合计']]
# Out:
#           合计
# 总成本  87600.2

# %%
CB_Transaction_Data = pd.read_csv('cbcsv/CB_Transaction_Data.csv', encoding='gbk')
CB_Transaction_Data[u'发生日期'] = pd.to_datetime(CB_Transaction_Data[u'发生日期'].values)
CB_Transaction_Data.tail(10)
# Out:
#           发生日期    业务名称    证券代码  证券名称     成交均价  成交数量      成交金额  股份余额   手续费  \
# 370 2019-01-31  证券卖出清算  123001  蓝标转债  100.200  -100  10020.00     0  2.00
# 371 2019-02-12  证券卖出清算  128012  辉丰转债   92.880   -30   2786.40   140  0.56
# 372 2019-02-12  证券卖出清算  128012  辉丰转债   92.880   -20   1857.60   120  0.37
# 373 2019-02-12  证券卖出清算  128014  永东转债   96.749   -10    967.49     0  0.19
# 374 2019-02-12  证券卖出清算  113017  吉视转债   96.860   -20   1937.20     0  1.00
# 375 2019-02-12  证券卖出清算  113502  嘉澳转债   96.200   -20   1924.00     0  1.00
# 376 2019-02-12  证券卖出清算  128013  洪涛转债   92.158   -10    921.58   410  0.18
# 377 2019-02-19  证券卖出清算  127003  海印转债   95.382   -10    953.82   160  0.19
# 378 2019-02-25  证券卖出清算  128037  岩土转债   94.014   -10    940.14     0  0.19
# 379 2019-03-01  证券卖出清算  127003  海印转债   97.980   -20   1959.60   140  0.39
#
#          发生金额
# 370  10018.00
# 371   2785.84
# 372   1857.23
# 373    967.30
# 374   1936.20
# 375   1923.00
# 376    921.40
# 377    953.63
# ...
