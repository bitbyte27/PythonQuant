# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
import CB_Transaction_Functions

# %%
CB_CSV = 'CB_Transaction_Data.csv'

# %% [markdown]
# ### 辉丰转债128012

# %%
huifeng = u'辉丰转债'
huifeng_date = '2016-04-21'
huifeng_rate = [3.0, 1.3, 1.3, 1.0, 0.7, 0.5]

# %%
huifeng_CB_TD = CB_Transaction_Functions.CB_Transaction_Data(CB_CSV,huifeng,huifeng_date,huifeng_rate)

# %%
huifeng_CB_TD.iloc[[41,42,45,43,44,46,47,48]]
# 99元以上30张。
# Out:
#          发生日期    业务名称    证券代码  证券名称     成交均价  成交数量     成交金额  股份余额   手续费  \
# 41 2017-11-24  证券买入清算  128012  辉丰转债   99.492    10   994.92   100  0.20
# 42 2017-11-29  证券买入清算  128012  辉丰转债   98.118    10   981.18   110  0.20
# 45 2018-01-25  证券卖出清算  128012  辉丰转债  102.448   -20  2048.96    90  0.41
# 43 2017-12-07  证券买入清算  128012  辉丰转债   94.900    20  1898.00   130  0.38
# 44 2018-01-04  证券卖出清算  128012  辉丰转债   97.060   -20  1941.20   110  0.39
# 46 2018-02-08  证券买入清算  128012  辉丰转债   97.332    10   973.32   100  0.19
# 47 2018-02-09  证券买入清算  128012  辉丰转债   96.086    10   960.86   110  0.19
# 48 2018-03-29  证券买入清算  128012  辉丰转债   94.570    10   945.70   120  0.19
#
#        发生金额       成本    到期本息   到期利率%  到期年化%
# 41  -995.12  100.376  105.84   6.380  1.448
# 42  -981.38  100.172  105.84   7.870  1.792
# 45  2048.55   99.200    0.00   0.000  0.000
# 43 -1898.38   99.364  105.84  11.528  2.638
# 44  1940.81   99.786    0.00   0.000  0.000
# 46  -973.51   99.015  105.84   8.741  2.083
# ...

# %%
huifeng_CB_TD.iloc[[49,50,51,52,55,53,54,56]]
# 91元以上卖出50张（2019年2月12日）。
# Out:
#          发生日期    业务名称    证券代码  证券名称   成交均价  成交数量    成交金额  股份余额    手续费  \
# 49 2018-04-20    债券兑息  128012  辉丰转债   0.00     0    84.0   120  16.80
# 50 2018-04-23  证券买入清算  128012  辉丰转债  86.88    10   868.8   160   0.17
# 51 2018-04-23  证券买入清算  128012  辉丰转债  90.80    10   908.0   130   0.18
# 52 2018-04-23  证券买入清算  128012  辉丰转债  90.60    10   906.0   140   0.18
# 55 2019-02-12  证券卖出清算  128012  辉丰转债  92.88   -30  2786.4   140   0.56
# 53 2018-04-23  证券买入清算  128012  辉丰转债  88.21    10   882.1   150   0.18
# 54 2018-04-24  证券买入清算  128012  辉丰转债  83.55    10   835.5   170   0.17
# 56 2019-02-12  证券卖出清算  128012  辉丰转债  92.88   -20  1857.6   120   0.37
#
#        发生金额       成本    到期本息   到期利率%  到期年化%
# 49    67.20   97.843    0.00   0.000  0.000
# 50  -868.97   78.814  105.28  21.179  5.302
# 51  -908.18  103.987  105.28  15.947  3.992
# 52  -906.18  103.032  105.28  16.203  4.056
# 55  2785.84   95.405    0.00   0.000  0.000
# 53  -882.28  102.045  105.28  19.352  4.845
# ...

# %%
huifeng_CB_TD_cost = CB_Transaction_Functions.CB_TD_cost(huifeng,huifeng_CB_TD,huifeng_date,huifeng_rate)
huifeng_CB_TD_cost
# Out:
#           持仓金额   成交数量    持仓成本         起息日   剩余年限    证券代码   成交金额  买卖数量  \
# 辉丰转债  11499.42  120.0  95.828  2016-04-21  3年28天  128012  92.88   -20
#
#            交易时间    到期本息  到期利率%  到期年化%  锁仓张数
# 辉丰转债 2019-02-12  105.28  9.863  3.095    20

# %% [markdown]
# ### 洪涛转债128013

# %%
hongtao = u'洪涛转债'
hongtao_date = '2016-07-29'
hongtao_rate = [8.0, 1.8, 1.5, 1.0, 0.6, 0.4]

# %%
hongtao_CB_TD = CB_Transaction_Functions.CB_Transaction_Data(CB_CSV,hongtao,hongtao_date,hongtao_rate)

# %%
hongtao_CB_TD.iloc[[1,2,7,3,4,5,6,18,19,20,21]] # 2017-04-11
# Out:
#          发生日期    业务名称    证券代码  证券名称     成交均价  成交数量     成交金额  股份余额   手续费  \
# 1  2017-01-17  证券买入清算  128013  洪涛转债  108.000    10  1080.00    20  0.22
# 2  2017-01-17  证券买入清算  128013  洪涛转债  108.350    10  1083.50    30  0.22
# 7  2017-02-10  证券卖出清算  128013  洪涛转债  108.199   -20  2163.98    10  0.43
# 3  2017-01-18  证券买入清算  128013  洪涛转债  107.500    20  2150.00    50  0.43
# 4  2017-01-18  证券买入清算  128013  洪涛转债  107.000    20  2140.00    70  0.43
# 5  2017-01-18  证券买入清算  128013  洪涛转债  106.320    20  2126.40    90  0.43
# 6  2017-01-23  证券卖出清算  128013  洪涛转债  107.771   -60  6466.26    30  1.29
# 18 2017-03-23  证券买入清算  128013  洪涛转债  103.798    10  1037.98   210  0.21
# 19 2017-03-27  证券卖出清算  128013  洪涛转债  104.390   -10  1043.90   200  0.21
# 20 2017-03-31  证券买入清算  128013  洪涛转债  103.600    20  2072.00   220  0.41
# 21 2017-04-11  证券卖出清算  128013  洪涛转债  104.400   -20  2088.00   200  0.42
#
#        发生金额       成本    到期本息  到期利率%  到期年化%
# 1  -1080.22  108.522  110.64  2.444  0.442
# ...

# %%
hongtao_CB_TD.iloc[[17,32,22,23,28,24,27,25,29,26,30]] # 2017-08-03
# Out:
#          发生日期    业务名称    证券代码  证券名称     成交均价  成交数量     成交金额  股份余额   手续费  \
# 17 2017-03-16  证券买入清算  128013  洪涛转债  105.000    20  2100.00   200  0.42
# 32 2017-08-03  证券卖出清算  128013  洪涛转债  105.510   -20  2110.20   180  0.42
# 22 2017-04-18  证券买入清算  128013  洪涛转债  102.891    20  2057.82   220  0.41
# 23 2017-04-19  证券买入清算  128013  洪涛转债  101.903    20  2038.06   240  0.41
# 28 2017-06-28  证券卖出清算  128013  洪涛转债  103.880   -40  4155.20   250  0.83
# 24 2017-05-08  证券买入清算  128013  洪涛转债  101.110    10  1011.10   250  0.20
# 27 2017-06-28  证券卖出清算  128013  洪涛转债  103.560   -10  1035.60   240  0.21
# 25 2017-05-16  证券买入清算  128013  洪涛转债   99.999    20  1999.98   270  0.40
# 29 2017-07-24  证券卖出清算  128013  洪涛转债  103.421   -20  2068.42   220  0.41
# 26 2017-05-31  证券买入清算  128013  洪涛转债   99.003    20  1980.06   290  0.40
# 30 2017-07-28  证券卖出清算  128013  洪涛转债  103.701   -20  2074.02   200  0.41
#
#        发生金额       成本    到期本息   到期利率%  到期年化%
# 17 -2100.42  106.311  110.64   5.371  1.000
# ...

# %%
hongtao_CB_TD[8:17]
# Out:
#          发生日期    业务名称    证券代码  证券名称     成交均价  成交数量     成交金额  股份余
生日期    业务名称    证券代码  证券名称    成交均价  成交数量    成交金额  股份余额   手续费    发生金额  \
# 45 2017-11-29  证券买入清算  128013  洪涛转债  95.954    10  959.54   390  0.19 -959.73
# 54 2019-03-19  证券卖出清算  128013  洪涛转债  98.440   -10  984.40   380  0.20  984.20
#
#          成本    到期本息   到期利率%  到期年化%
# 45  102.301  110.32  14.972  3.211
# 54  101.642    0.00   0.000  0.000

# %%
hongtao_CB_TD.iloc[[46,47,53,48,52,49,50]]
# Out:
#          发生日期    业务名称    证券代码  证券名称    成交均价  成交数量     成交金额  股份余额   手续费  \
# 46 2017-12-07  证券买入清算  128013  洪涛转债  93.279    10   932.79   400  0.19
# 47 2018-05-03  证券买入清算  128013  洪涛转债  91.800    10   918.00   410  0.18
# 53 2019-03-04  证券卖出清算  128013  洪涛转债  95.064   -20  1901.28   390  0.38
# 48 2018-05-28  证券买入清算  128013  洪涛转债  89.991    10   899.91   420  0.18
# 52 2019-02-12  证券卖出清算  128013  洪涛转债  92.158   -10   921.58   410  0.18
# 49 2018-05-30  证券买入清算  128013  洪涛转债  88.010    10   880.10   430  0.18
# 50 2018-07-25  证券卖出清算  128013  洪涛转债  89.720   -10   897.20   420  0.18
#
#        发生金额       成本    到期本息   到期利率%  到期年化%
# 46  -932.98  102.076  110.32  18.269  3.936
# 47  -918.18  101.826  110.32  20.174  4.760
# 53  1900.90  101.559    0.00   0.000  0.000
# 48  -900.09  101.545  110.32  22.590  5.417
# 52   921.40  101.241    0.00   0.000  0.000
# 49  -880.28  101.230  110.32  25.349  6.087
# 50   897.02  101.505    0.00   0.000  0.000

# %%
hongtao_CB_TD_cost = CB_Transaction_Functions.CB_TD_cost(hongtao,hongtao_CB_TD,hongtao_date,hongtao_rate)
hongtao_CB_TD_cost
# Out:
#           持仓金额   成交数量     持仓成本         起息日    剩余年限    证券代码   成交金额  买卖数量  \
# 洪涛转债  38623.87  380.0  101.642  2016-07-29  3年127天  128013  98.44   -10
#
#            交易时间    到期本息  到期利率%  到期年化%  锁仓张数
# 洪涛转债 2019-03-19  109.84  8.066  2.399    20

# %% [markdown]
# ### 海印转债127003

# %%
haiyin = u'海印转债'
haiyin_date = '2016-06-08'
haiyin_rate = [10.0, 1.8, 1.5, 1.0, 0.7, 0.5]

# %%
haiyin_CB_TD = CB_Transaction_Functions.CB_Transaction_Data(CB_CSV,haiyin,haiyin_date,haiyin_rate)

# %%
haiyin_CB_TD[0:2]
# Out:
#         发生日期    业务名称    证券代码  证券名称     成交均价  成交数量     成交金额  股份余额   手续费  \
# 0 2017-03-23  证券买入清算  127003  海印转债  107.011    10  1070.11    10  0.21
# 1 2017-04-07  证券买入清算  127003  海印转债  106.410    10  1064.10    20  0.21
#
#       发生金额       成本   到期本息  到期利率%  到期年化%
# 0 -1070.32  107.032  112.4  5.036  0.966
# 1 -1064.31  106.732  112.4  5.629  1.089

# %%
haiyin_CB_TD[10:14]
# Out:
#          发生日期    业务名称    证券代码  证券名称     成交均价  成交数量     成交金额  股份余
生日期    业务名称    证券代码  证券名称     成交均价  成交数量     成交金额  股份余额    手续费  \
# 20 2017-11-17  证券买入清算  127003  海印转债   98.400    10   984.00   130   0.20
# 21 2017-11-21  证券买入清算  127003  海印转债   97.010    10   970.10   140   0.19
# 34 2019-03-05  证券卖出清算  127003  海印转债  100.350   -20  2007.00   120   0.40
# 22 2017-11-21  证券买入清算  127003  海印转债   96.135    10   961.35   150   0.19
# 23 2017-11-24  证券买入清算  127003  海印转债   95.788    10   957.88   160   0.19
# 33 2019-03-01  证券卖出清算  127003  海印转债   97.980   -20  1959.60   140   0.39
# 24 2017-12-07  证券买入清算  127003  海印转债   93.730    10   937.30   170   0.19
# 25 2018-01-25  证券卖出清算  127003  海印转债   94.265   -10   942.65   160   0.19
# 26 2018-02-09  证券买入清算  127003  海印转债   93.000    10   930.00   170   0.19
# 32 2019-02-19  证券卖出清算  127003  海印转债   95.382   -10   953.82   160   0.19
# 27 2018-05-14  证券买入清算  127003  海印转债   91.800    10   918.00   180   0.18
# 31 2018-07-26  证券卖出清算  127003  海印转债   92.362   -10   923.62   170   0.18
# ...

# %%
haiyin_CB_TD_cost = CB_Transaction_Functions.CB_TD_cost(haiyin,haiyin_CB_TD,haiyin_date,haiyin_rate)
haiyin_CB_TD_cost
# Out:
#          持仓金额  成交数量    持仓成本         起息日   剩余年限    证券代码    成交金额  买卖数量  \
# 海印转债  1393.08  20.0  69.654  2016-06-08  3年77天  127003  108.24   -20
#
#            交易时间    到期本息   到期利率%  到期年化%  锁仓张数
# 海印转债 2019-03-19  111.44  59.991  18.62    20

# %% [markdown]
# ### 模塑转债127004

# %%
mosu = u'模塑转债'
mosu_date = '2017-06-02'
mosu_rate = [10.0, 1.8, 1.5, 1.0, 0.7, 0.5]

# %%
mosu_CB_TD = CB_Transaction_Functions.CB_Transaction_Data(CB_CSV,mosu,mosu_date,mosu_rate)
mosu_CB_TD[0:9]
# Out:
#         发生日期    业务名称    证券代码  证券名称     成交均价  成交数量     成交金额  股份余额   手续费  \
# 0 2017-10-30  证券买入清算  127004  模塑转债  106.201    10  1062.01    10  0.21
# 1 2017-10-31  证券买入清算  127004  模塑转债  105.861    10  1058.61    20  0.21
# 2 2017-11-02  证券买入清算  127004  模塑转债  105.015    10  1050.15    30  0.21
# 3 2017-11-03  证券买入清算  127004  模塑转债  104.301    10  1043.01    40  0.21
# 4 2017-11-06  证券买入清算  127004  模塑转债  103.467    10  1034.67    50  0.21
# 5 2017-11-07  证券买入清算  127004  模塑转债  101.920    20  2038.40    70  0.41
# 6 2017-11-24  证券买入清算  127004  模塑转债   99.974    10   999.74    80  0.20
# 7 2017-11-27  证券买入清算  127004  模塑转债   98.972    10   989.72    90  0.20
# 8 2017-11-29  证券买入清算  127004  模塑转债   97.050    20  1941.00   110  0.39
#
#       发生金额       成本   到期本息   到期利率%  到期年化%
# 0 -1062.22  106.222  112.4   5.837  1.044
# 1 -1058.82  106.052  112.4   6.177  1.106
# 2 -1050.36  105.713  112.4   7.032  1.260
# 3 -1043.22  105.366  112.4   7.765  1.392
# 4 -1034.88  104.990  112.4   8.634  1.550
# ...

# %%
mosu_CB_TD[9:]
# Out:
#          发生日期    业务名称    证券代码  证券名称    成交均价  成交数量    成交金额  股份余额    手续费  \
# 9  2017-12-07  证券买入清算  127004  模塑转债  93.988    10  939.88   120   0.19
# 10 2018-01-25  证券卖出清算  127004  模塑转债  96.582   -10  965.82   110   0.19
# 11 2018-05-28  证券买入清算  127004  模塑转债  90.900    10  909.00   120   0.18
# 12 2018-06-01    债券兑息  127004  模塑转债   0.000     0   60.00   120  12.00
# 13 2019-03-06  证券卖出清算  127004  模塑转债  94.255   -10  942.55   110   0.19
#
#       发生金额       成本   到期本息   到期利率%  到期年化%
# 9  -940.07  101.330  112.4  19.590  3.572
# 10  965.63  101.764    0.0   0.000  0.000
# 11 -909.18  100.860  112.4  23.652  4.718
# 12   48.00  100.460    0.0   0.000  0.000
# 13  942.36  101.026    0.0   0.000  0.000

# %%
mosu_CB_TD_cost = CB_Transaction_Functions.CB_TD_cost(mosu,mosu_CB_TD,mosu_date,mosu_rate)
mosu_CB_TD_cost
# Out:
#           持仓金额   成交数量     持仓成本         起息日   剩余年限    证券代码    成交金额  买卖数量  \
# 模塑转债  11112.82  110.0  101.026  2017-06-02  4年70天  127004  94.255   -10
#
#            交易时间   到期本息   到期利率%  到期年化%  锁仓张数
# 模塑转债 2019-03-06  112.0  10.863  2.561   0.0

# %% [markdown]
# ### 格力转债110030

# %%
geli = u'格力转债'
geli_date = '2014-12-25'
geli_rate = [6.0, 1.5, 1.0, 0.8, 0.6]

# %%
geli_CB_TD = CB_Transaction_Functions.CB_Transaction_Data(CB_CSV,geli,geli_date,geli_rate)
geli_CB_TD.iloc[[0,4,1,2,3,5,6]]
# 107以上
# Out:
#         发生日期    业务名称    证券代码  证券名称    成交均价  成交数量    成交金额  股份余额  手续费    发生金额  \
# 0 2017-11-21  证券买入清算  110030  格力转债  107.35    10  1073.5    10  1.0 -1074.5
# 4 2018-01-25  证券卖出清算  110030  格力转债  111.03   -10  1110.3    20  1.0  1109.3
# 1 2017-11-21  证券买入清算  110030  格力转债  106.61    10  1066.1    20  1.0 -1067.1
# 2 2017-12-27  证券买入清算  110030  格力转债  104.89    10  1048.9    30  1.0 -1049.9
# 3 2017-12-28    债券兑息  110030  格力转债    0.00     0    20.0    30  4.0    16.0
# 5 2018-02-07  证券买入清算  110030  格力转债  106.50    10  1065.0    30  1.0 -1066.0
# 6 2018-12-28    债券兑息  110030  格力转债    0.00     0    45.0    30  9.0    36.0
#
#         成本   到期本息  到期利率%  到期年化%
# 0  107.450  106.8 -0.512 -0.245
# 4  103.310    0.0  0.000  0.000
# 1  107.080  106.8  0.178  0.085
# 2  106.383  106.0  1.058  0.531
# 3  105.850    0.0  0.000  0.000
# 5  104.407  106.0 -0.469 -0.250
# 6  103.207    0.0  0.000  0.000

# %%
geli_CB_TD_cost = CB_Transaction_Functions.CB_TD_cost(geli,geli_CB_TD,geli_date,geli_rate)
geli_CB_TD_cost
# Out:
#         持仓金额  成交数量     持仓成本         起息日    剩余年限    证券代码  成交金额  买卖数量  \
# 格力转债  3096.2  30.0  103.207  2014-12-25  1年276天  110030   0.0     0
#
#            交易时间   到期本息  到期利率%  到期年化%  锁仓张数
# 格力转债 2018-12-28  104.8  1.544  1.561   0.0

# %% [markdown]
# ## 【数据集合与画图】

# %%
CB_Transaction_Data_Cost_T = pd.concat([huifeng_CB_TD_cost.T,hongtao_CB_TD_cost.T,
                                        haiyin_CB_TD_cost.T,mosu_CB_TD_cost.T,
                                        geli_CB_TD_cost.T], axis=1)
CB_Transaction_Data_Cost = CB_Transaction_Data_Cost_T.T
CB_Transaction_Data_Cost[u'总成本'] = CB_Transaction_Data_Cost[u'成交数量']*CB_Transaction_Data_Cost[u'持仓成本']
CB_Transaction_Data_Cost = CB_Transaction_Data_Cost.loc[CB_Transaction_Data_Cost[u'成交数量']>0]

# %%
plt.figure(3,figsize=(14,6), dpi=80)
ax3 = plt.subplot(111)

# %%
Yahei = matplotlib.font_manager.FontProperties(fname='C:\Windows\Fonts\msyh.ttf')
k = len(CB_Transaction_Data_Cost)
x_ticks_num = np.arange(0,k)
x_ticks_name = CB_Transaction_Data_Cost.index
y_ticks_values = CB_Transaction_Data_Cost[u'持仓成本'].values
y_ticks_num = CB_Transaction_Data_Cost[u'成交数量'].values
total_width = 0.7
num_bar = 2
w = total_width/num_bar
x_ticks_b = x_ticks_num - (total_width - w)/2
af = 0.8
x_ticks_num
# Out:
# array([0, 1, 2, 3, 4])

# %%
ax3.bar(x_ticks_num+w, y_ticks_values, facecolor='orange', width=w, label=u'持仓成本', alpha=af)
plt.axhline(y=100, color='red', linewidth='1.0')
plt.legend(prop={'family':'Microsoft YaHei','size':12}, loc=(0.02,0.9))
plt.ylim(60,110,1)
plt.xticks(x_ticks_num+1.5*w, x_ticks_name, fontproperties=Yahei)
plt.grid(linestyle=':', alpha=0.5)

# %%
ax4 = ax3.twinx()
ax4.bar(x_ticks_num+2.1*w, y_ticks_num, facecolor='FireBrick', width=w, label=u'持仓数量', alpha=af)
plt.legend(prop={'family':'Microsoft YaHei','size':12}, loc=(0.02,0.8))
plt.ylim(0,400,1)
# Out:
# (0, 400)

# %%
for a,b in zip(x_ticks_num,y_ticks_values):
    ax3.text(a+w, b+0.2, '%.3f' % b, ha='center', va= 'bottom')

# %%
for c,d in zip(x_ticks_num,y_ticks_num):
    ax4.text(c+2.1*w, d+1, '%.0f' % d, ha='center', va= 'bottom')

# %%
CB_Transaction_Data_Cost[u'交易时间'] = pd.to_datetime(CB_Transaction_Data_Cost[u'交易时间'].values)
CB_Transaction_Data_Cost_R = CB_Transaction_Data_Cost.sort_values(by=u'持仓成本', ascending=True)
CB_Transaction_Data_Cost_R[u'可转债'] = CB_Transaction_Data_Cost_R.index
CB_Transaction_Data_Cost_R = CB_Transaction_Data_Cost_R.reset_index(drop=True)
CB_Transaction_Data_Cost_R = CB_Transaction_Data_Cost_R[[u'证券代码',u'可转债',u'持仓成本',u'成交数量',u'总成本',u'交易时间',u'成交金额',u'买卖数量',u'起息日',u'剩余年限',u'到期利率%',u'到期年化%',u'锁仓张数']]

# %% [markdown]
# ### 持仓明细表

# %%
CB_Transaction_Data_Cost_R
# Out:
#      证券代码   可转债     持仓成本 成交数量      总成本       交易时间    成交金额 买卖数量         起息日  \
# 0  127003  海印转债   69.654   20  1393.08 2019-03-19  108.24  -20  2016-06-08
# 1  128012  辉丰转债   95.828  120  11499.4 2019-02-12   92.88  -20  2016-04-21
# 2  127004  模塑转债  101.026  110  11112.9 2019-03-06  94.255  -10  2017-06-02
# 3  128013  洪涛转债  101.642  380    38624 2019-03-19   98.44  -10  2016-07-29
# 4  110030  格力转债  103.207   30  3096.21 2018-12-28       0    0  2014-12-25
#
#      剩余年限   到期利率%  到期年化% 锁仓张数
# 0   3年77天  59.991  18.62   20
# 1   3年28天   9.863  3.095   20
# 2   4年70天  10.863  2.561    0
# 3  3年127天   8.066  2.399   20
# 4  1年276天   1.544  1.561    0

# %%
# CB_Transaction_Data_Cost_R.to_csv('cbcsv/CB_Transaction_Data_Cost.csv',encoding='gbk',index=False)

# %%
# plt.savefig('D:/Python/iPython/CB/CB_TD.png', dpi=600)

# %%
plt.show()

# %%
ALL_Cost = CB_Transaction_Data_Cost.loc[:,[u'总成本']]
# 行合计，形成最后一行合计值
ALL_Cost.loc[u'合计'] = ALL_Cost.apply(lambda x: x.sum())
# ALL_Cost.sort_values(by=u'总成本', ascending=True).T
ALL_Cost.T[[u'合计']]
# Out:
#           合计
# 总成本  65725.5

# %%
CB_Transaction_Data = pd.read_csv('cbcsv/CB_Transaction_Data.csv', encoding='gbk')
CB_Transaction_Data[u'发生日期'] = pd.to_datetime(CB_Transaction_Data[u'发生日期'].values)
CB_Transaction_Data.tail(10)
# Out:
#           发生日期    业务名称    证券代码  证券名称      成交均价  成交数量     成交金额  股份余额   手续费  \
# 383 2019-03-06  证券卖出清算  128026  众兴转债   96.1700   -10   961.70     0  0.19
# 384 2019-03-06  证券卖出清算  128023  亚太转债   95.2600   -20  1905.20     0  0.38
# 385 2019-03-06  证券卖出清算  127004  模塑转债   94.2550   -10   942.55   110  0.19
# 386 2019-03-06  证券卖出清算  127003  海印转债  102.2135   -20  2044.27   100  0.41
# 387 2019-03-06  证券卖出清算  127003  海印转债  103.9600   -20  2079.20    80  0.42
# 388 2019-03-07  证券卖出清算  127003  海印转债  105.8800   -10  1058.80    70  0.21
# 389 2019-03-07  证券卖出清算  127003  海印转债  104.5700   -10  1045.70    60  0.21
# 390 2019-03-14  证券卖出清算  127003  海印转债  107.1000   -20  2142.00    40  0.43
# 391 2019-03-19  证券卖出清算  127003  海印转债  108.2400   -20  2164.80    20  0.43
# 392 2019-03-19  证券卖出清算  128013  洪涛转债   98.4400   -10   984.40   380  0.20
#
#         发生金额
# 383   961.51
# 384  1904.82
# 385   942.36
# 386  2043.86
# 387  2078.78
# 388  1058.59
# 389  1045.49
# 390  2141.57
# 391  2164.37
# ...
