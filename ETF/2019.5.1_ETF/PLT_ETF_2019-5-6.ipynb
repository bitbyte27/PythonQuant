# %% [markdown]
# * [沪深300ETF](http://finance.sina.com.cn/fund/quotesold/510300/bc.shtml)

# %%
Candle_300_ETF = Candle_Plus.Candle_plot(ETF300, stadate, endate, title1, line1, half_line_date1, half_line_price1)

# %% [markdown]
# * [证券ETF](http://finance.sina.com.cn/fund/quotes/512880/bc.shtml)

# %%
Candle_ZQ_ETF = Candle_Plus.Candle_plot(ETF_ZQ, stadate, endate, title2, line2, half_line_date2, half_line_price2)
