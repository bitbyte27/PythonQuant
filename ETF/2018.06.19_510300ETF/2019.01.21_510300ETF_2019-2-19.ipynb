# %%
import pandas as pd
import tushare as ts
import Candle_XR as CandleXR
import time
cons = ts.get_apis()

# %%
stadate = '2019-1-16'
Now_Date = time.strftime('%Y-%m-%d',time.localtime(time.time()))
enddate = pd.to_datetime(Now_Date)

# %%
trade_dates = ['2019-1-21','2019-2-11']
trade_prices = [3.193, 3.281]

# %%
buy_dates = []
buy_prices = []
sell_dates = []
sell_prices = []

# %%
T_sell_dates = []
T_sell_prices = []
T_buy_dates = []
T_buy_prices = []

# %%
ETF300 = ts.bar('510300', conn=cons)
ETF300['volume'] = ETF300['vol']*100
ETF300['date'] = ETF300.index
ETF300.head()
# Out:
#               code   open  close   high    low        vol        amount  \
# datetime
# 2019-02-19  510300  3.445  3.429  3.471  3.411  6782305.0  2.336312e+09
# 2019-02-18  510300  3.363  3.438  3.440  3.363  4711063.0  1.605205e+09
# 2019-02-15  510300  3.381  3.341  3.395  3.336  4479468.0  1.507132e+09
# 2019-02-14  510300  3.389  3.397  3.414  3.380  3797560.0  1.288823e+09
# 2019-02-13  510300  3.329  3.393  3.410  3.323  4278016.0  1.439017e+09
#
#                  volume       date
# datetime
# 2019-02-19  678230500.0 2019-02-19
# 2019-02-18  471106300.0 2019-02-18
# 2019-02-15  447946800.0 2019-02-15
# 2019-02-14  379756000.0 2019-02-14
# 2019-02-13  427801600.0 2019-02-13

# %%
# ETF300 = pd.read_csv('510300_20190121.csv')
# ETF300 = ETF300.set_index('datetime')
# ETF300['date'] = ETF300.index
# ETF300.tail()

# %% [markdown]
# #### [雪球：300ETF510300](https://xueqiu.com/S/SH510300)

# %%
Candle_ETF300_Trade = CandleXR.Candle_plot(ETF300,stadate,enddate,trade_dates,trade_prices,
                                           buy_dates,buy_prices,sell_dates,sell_prices,
                                           T_buy_dates, T_buy_prices, T_sell_dates, T_sell_prices)

# %%
#关闭连接
ts.close_apis(cons)
