# %%
import pandas as pd
import tushare as ts
import Candle_XR as CandleXR
import time
cons = ts.get_apis()

# %%
stadate = '2018-08-08'
Now_Date = time.strftime('%Y-%m-%d',time.localtime(time.time()))
enddate = pd.to_datetime(Now_Date)

# %%
trade_dates = ['2018-08-17','2018-08-27','2018-09-06','2018-09-21','2018-09-26','2018-10-08','2018-10-11','2018-10-16','2018-10-22']
# '2018-06-19', '2018-07-04','2018-07-20',
trade_prices = [3.322, 3.468, 3.333, 3.431, 3.515, 3.392, 3.246, 3.174, 3.339]
# 3.670, 3.420, 3.561,

# %%
buy_dates = ['2018-08-17','2018-09-06','2018-10-16']  # '2018-07-04',
buy_prices = [3.322, 3.333, 3.174]  # 3.420, 
sell_dates = ['2018-08-27','2018-09-21','2018-10-22']  # '2018-07-20',
sell_prices = [3.468, 3.431, 3.339]  # 3.561,

# %%
T_sell_dates = ['2018-09-26']
T_sell_prices = [3.515]
T_buy_dates = ['2018-10-08']
T_buy_prices = [3.392]

# %%
ETF300 = ts.bar('510300', conn=cons)
ETF300.head()
# Out:
#               code   open  close   high    low        vol        amount
# datetime
# 2018-10-22  510300  3.250  3.353  3.370  3.200  9341864.0  3.089535e+09
# 2018-10-19  510300  3.090  3.185  3.200  3.073  6731053.0  2.107742e+09
# 2018-10-18  510300  3.155  3.106  3.165  3.105  5932914.0  1.856470e+09
# 2018-10-17  510300  3.205  3.176  3.215  3.125  6437365.0  2.044128e+09
# 2018-10-16  510300  3.190  3.165  3.228  3.153  4938840.0  1.573220e+09

# %% [markdown]
# #### [雪球：300ETF510300](https://xueqiu.com/S/SH510300)

# %%
ETF300['date'] = ETF300.index
ETF300['volume'] = ETF300['vol']*100
ETF300.head()
# Out:
#               code   open  close   high    low        vol        amount  \
# datetime
# 2018-10-22  510300  3.250  3.353  3.370  3.200  9341864.0  3.089535e+09
# 2018-10-19  510300  3.090  3.185  3.200  3.073  6731053.0  2.107742e+09
# 2018-10-18  510300  3.155  3.106  3.165  3.105  5932914.0  1.856470e+09
# 2018-10-17  510300  3.205  3.176  3.215  3.125  6437365.0  2.044128e+09
# 2018-10-16  510300  3.190  3.165  3.228  3.153  4938840.0  1.573220e+09
#
#                  date       volume
# datetime
# 2018-10-22 2018-10-22  934186400.0
# 2018-10-19 2018-10-19  673105300.0
# 2018-10-18 2018-10-18  593291400.0
# 2018-10-17 2018-10-17  643736500.0
# 2018-10-16 2018-10-16  493884000.0

# %%
Candle_ETF300_Trade = CandleXR.Candle_plot(ETF300,stadate,enddate,trade_dates,trade_prices,
                                           buy_dates,buy_prices,sell_dates,sell_prices,
                                           T_buy_dates, T_buy_prices, T_sell_dates, T_sell_prices)

# %%
#关闭连接
ts.close_apis(cons)
