# %%
import pandas as pd
import tushare as ts
import Candle_XR as CandleXR
import time
cons = ts.get_apis()

# %%
stadate = '2018-11-21'
Now_Date = time.strftime('%Y-%m-%d',time.localtime(time.time()))
enddate = pd.to_datetime(Now_Date)

# %%
trade_dates = ['2018-11-27','2018-12-3','2018-12-17','2018-12-20','2018-12-25','2019-1-7','2019-1-9']
# '2018-06-19', '2018-07-04','2018-07-20','2018-08-17','2018-08-27','2018-09-06','2018-09-21','2018-09-26',
# '2018-10-08','2018-10-11','2018-10-16','2018-10-22',
trade_prices = [3.183, 3.289,3.198, 3.123, 3.043, 3.100, 3.171]
# 3.670, 3.420, 3.561, 3.322, 3.468, 3.333, 3.431, 3.515, 3.392, 3.246, 3.174, 3.339,

# %%
buy_dates = ['2018-11-27','2018-12-25','2018-12-20']
# '2018-07-04','2018-08-17','2018-09-06','2018-10-16','2018-10-11'
buy_prices = [3.183, 3.043, 3.123]
# 3.420, 3.322, 3.333, 3.174, 3.246
sell_dates = ['2018-12-3','2019-1-7','2019-1-9']
# '2018-07-20','2018-08-27','2018-09-21','2018-10-22','2018-11-2'
sell_prices = [3.289, 3.100, 3.171]
# 3.561, 3.468, 3.431, 3.339, 3.343

# %%
T_sell_dates = []
# '2018-09-26'
T_sell_prices = []
# 3.515
T_buy_dates = []
# '2018-10-08'
T_buy_prices = []
# 3.392

# %%
ETF300 = ts.bar('510300', conn=cons)
ETF300.head()
# Out:
#               code   open  close   high    low        vol        amount
# datetime
# 2019-01-14  510300  3.155  3.129  3.155  3.122  2039120.0  6.386967e+08
# 2019-01-11  510300  3.131  3.156  3.165  3.129  2513682.0  7.910531e+08
# 2019-01-10  510300  3.129  3.133  3.154  3.114  2476923.0  7.763761e+08
# 2019-01-09  510300  3.119  3.130  3.179  3.118  4396881.0  1.385615e+09
# 2019-01-08  510300  3.107  3.107  3.110  3.094  1970848.0  6.117187e+08

# %% [markdown]
# #### [雪球：300ETF510300](https://xueqiu.com/S/SH510300)

# %%
ETF300['date'] = ETF300.index
ETF300['volume'] = ETF300['vol']*100
ETF300.head()
# Out:
#               code   open  close   high    low        vol        amount  \
# datetime
# 2019-01-14  510300  3.155  3.129  3.155  3.122  2039120.0  6.386967e+08
# 2019-01-11  510300  3.131  3.156  3.165  3.129  2513682.0  7.910531e+08
# 2019-01-10  510300  3.129  3.133  3.154  3.114  2476923.0  7.763761e+08
# 2019-01-09  510300  3.119  3.130  3.179  3.118  4396881.0  1.385615e+09
# 2019-01-08  510300  3.107  3.107  3.110  3.094  1970848.0  6.117187e+08
#
#                  date       volume
# datetime
# 2019-01-14 2019-01-14  203912000.0
# 2019-01-11 2019-01-11  251368200.0
# 2019-01-10 2019-01-10  247692300.0
# 2019-01-09 2019-01-09  439688100.0
# 2019-01-08 2019-01-08  197084800.0

# %%
Candle_ETF300_Trade = CandleXR.Candle_plot(ETF300,stadate,enddate,trade_dates,trade_prices,
                                           buy_dates,buy_prices,sell_dates,sell_prices,
                                           T_buy_dates, T_buy_prices, T_sell_dates, T_sell_prices)

# %%
#关闭连接
ts.close_apis(cons)
