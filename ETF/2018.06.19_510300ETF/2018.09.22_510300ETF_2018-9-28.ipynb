# %%
import pandas as pd
import tushare as ts
import Candle_XR as CandleXR
import time
cons = ts.get_apis()

# %%
stadate = '2018-08-08'
Now_Date = time.strftime('%Y-%m-%d',time.localtime(time.time()))
enddate = pd.to_datetime(Now_Date)

# %%
trade_dates = ['2018-08-17','2018-08-27','2018-09-06','2018-09-21','2018-09-26']  # '2018-06-19', '2018-07-04','2018-07-20',
trade_prices = [3.322, 3.468, 3.333, 3.431, 3.515]  # 3.670, 3.420, 3.561,

# %%
buy_dates = ['2018-08-17','2018-09-06']  # '2018-07-04',
buy_prices = [3.322, 3.333]  # 3.420, 
sell_dates = ['2018-08-27','2018-09-21']  # '2018-07-20',
sell_prices = [3.468, 3.431]  # 3.561,

# %%
ETF300 = ts.bar('510300', conn=cons)
ETF300.head()
# Out:
#               code   open  close   high    low        vol        amount
# datetime
# 2018-09-28  510300  3.477  3.508  3.512  3.473  3022668.0  1.056784e+09
# 2018-09-27  510300  3.475  3.472  3.487  3.460  2312028.0  8.025837e+08
# 2018-09-26  510300  3.450  3.487  3.516  3.448  3015784.0  1.051660e+09
# 2018-09-25  510300  3.447  3.449  3.458  3.430  2089806.0  7.200380e+08
# 2018-09-21  510300  3.388  3.484  3.486  3.377  4773660.0  1.638859e+09

# %% [markdown]
# #### [雪球：300ETF510300](https://xueqiu.com/S/SH510300)

# %%
ETF300['date'] = ETF300.index
ETF300['volume'] = ETF300['vol']*100
Candle_ETF300_Trade = CandleXR.Candle_plot(ETF300,stadate,enddate,trade_dates,trade_prices,buy_dates,buy_prices,sell_dates,sell_prices)

# %%
#关闭连接
ts.close_apis(cons)
