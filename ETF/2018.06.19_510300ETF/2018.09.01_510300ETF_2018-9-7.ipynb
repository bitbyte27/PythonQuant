# %%
import pandas as pd
import tushare as ts
import Candle_PlusX_SEx as CandleXSEx
import time
cons = ts.get_apis()

# %%
stadate = '2018-06-14'
Now_Date = time.strftime('%Y-%m-%d',time.localtime(time.time()))
enddate = pd.to_datetime(Now_Date)

# %%
trade_dates = ['2018-06-19', '2018-07-04','2018-07-20','2018-08-17','2018-08-27','2018-09-06']
trade_prices = [3.670, 3.420, 3.561, 3.322, 3.468, 3.333]

# %%
buy_dates = ['2018-07-04','2018-08-17']
buy_prices = [3.420, 3.322]
sell_dates = ['2018-07-20','2018-08-27']
sell_prices = [3.561, 3.468]

# %%
ETF300 = ts.bar('510300', conn=cons)
ETF300.head()
# Out:
#               code   open  close   high    low        vol       amount
# datetime
# 2018-09-07  510300  3.334  3.346  3.384  3.313  1850577.0  620163712.0
# 2018-09-06  510300  3.351  3.324  3.378  3.314  2133340.0  713999168.0
# 2018-09-05  510300  3.410  3.353  3.416  3.352  1952639.0  661947200.0
# 2018-09-04  510300  3.382  3.423  3.438  3.370  1749978.0  596721024.0
# 2018-09-03  510300  3.386  3.383  3.395  3.351  1405627.0  474050720.0

# %% [markdown]
# #### [雪球：300ETF510300](https://xueqiu.com/S/SH510300)

# %%
ETF300['date'] = ETF300.index
ETF300['volume'] = ETF300['vol']*100
Candle_ETF300_Trade = CandleXSEx.Candle_plot(ETF300,stadate,enddate,trade_dates,trade_prices,buy_dates,buy_prices,sell_dates,sell_prices)

# %%
#关闭连接
ts.close_apis(cons)
