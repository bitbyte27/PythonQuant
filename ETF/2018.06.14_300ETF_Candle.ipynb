# %%
import pandas as pd
import Candle

# %%
Stock_300_ETF = pd.read_csv('ETF/data/510300.csv')
stadate = '2018-04-01'
enddate = '2018-06-08'

# %%
Candle_300_ETF = Candle.Candle_plot(Stock_300_ETF, stadate, enddate)
